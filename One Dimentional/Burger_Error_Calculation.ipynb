# %% [markdown]
# # Burgers Equation
#
# $$u_t+uu_x=0.1u_{xx}$$

# %%
import os
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
import torch
import tensorflow as tf

import csv
from torch.autograd import grad
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ExponentialLR
from pylab import figure, text, scatter, show
from pdefind import *

from Model_Identification.PDE_Equation import pde_matrix_mul, sparse_coeff, normalized_xi_threshold, pde_Recover
from Model_Identification.build_Library import construct_Dictonary

# %% [markdown]
# ## Data Setup

# %%
data = sio.loadmat(os.path.join(os.getcwd(), "../data", "burgers.mat"))
u = data["usol"]
x = data["x"][0]
t = np.squeeze(data["t"], axis=1)

print("u shape", u.shape)
print("x shape", x.shape)
print("t shape", t.shape)

im = plt.imshow(u.real, cmap="seismic", aspect=0.4)
plt.colorbar(im)
plt.title("Burgers Equation")
plt.xlabel("t")
plt.ylabel("x")


xpos  = np.arange(len(t), step=25)
ypos  = np.where(x%4==0)[0].tolist()
ytick = x[ypos].tolist()
ypos  += [len(x)-1]
ytick += [8.0]

plt.xticks(xpos, t[xpos])
plt.yticks(ypos, ytick)
plt.gcf().set_size_inches(6,5)
plt.show()
# Out:
# u shape (256, 101)
# x shape (256,)
# t shape (101,)

# %%
# Add noise
np.random.seed(0)
noise_level = 0.1
u = u.real + noise_level*np.std(u.real)*np.random.randn(u.shape[0],u.shape[1])

im = plt.imshow(u.real, cmap="seismic", aspect=0.4)
plt.colorbar(im)
plt.title("Noisy Data")
plt.xlabel("t")
plt.ylabel("x")

plt.xticks(xpos, t[xpos])
plt.yticks(ypos, ytick)
plt.gcf().set_size_inches(6,5)
plt.show()

# %%
# Prepare Training Data
xx, tt = np.meshgrid(x,t)
X = np.vstack([xx.ravel(), tt.ravel()]).T
print("X shape", X.shape)
print(X)
# Out:
# X shape (25856, 2)
# [[-8.      0.    ]
#  [-7.9375  0.    ]
#  [-7.875   0.    ]
#  ...
#  [ 7.8125 10.    ]
#  [ 7.875  10.    ]
#  [ 7.9375 10.    ]]

# %%
y = np.zeros((u.size, 1), dtype=np.float)
for i,_x in enumerate(u.real.T):
    y[i*len(x):(i+1)*len(x)] = _x.reshape(len(x),1)
    
print("y shape", y.shape)
# Out:
# y shape (25856, 1)

# %%
# Setup Network
net = PINN(sizes=[2,20,20,20,20,20,1], activation=torch.nn.Tanh())
print(net)
# Out:
# PINN(
#   (net): Sequential(
#     (0): Linear(in_features=2, out_features=20, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=20, out_features=20, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=20, out_features=20, bias=True)
#     (7): Tanh()
#     (8): Linear(in_features=20, out_features=20, bias=True)
#     (9): Tanh()
#     (10): Linear(in_features=20, out_features=1, bias=True)
#   )
# )

# %%
polynm = ['1', 'u', 'uˆ2']
spa_der = ['1', 'u_{x}', 'u_{xx}']
library_coeffs = pde_matrix_mul(polynm, spa_der)
print('library_coeffs:', library_coeffs)

tot_items = len(library_coeffs)
print('tot_items:', tot_items)

mask = torch.ones(tot_items, 1)
epochs = 8000

xi = nn.Parameter(torch.randn((tot_items, 1), requires_grad=True, device="cpu", dtype=torch.float32))
params = [{'params': net.parameters(), 'lr': 3e-3}, {'params': xi, 'lr': 3e-2}]

optimizer = Adam(params)
scheduler = ExponentialLR(optimizer, .9998)
# Out:
# library_coeffs: ['1', 'u_{x}', 'u_{xx}', 'u', 'uu_{x}', 'uu_{xx}', 'uˆ2', 'uˆ2u_{x}', 'uˆ2u_{xx}']
# tot_items: 9

# %%
def model_identification(features, label, mask, poly_order, deriv_order):
    
    xi1 = []
    xi2 = []
    xi1_error_app = []
    xi2_error_app = []
    xi_update_app = []
    
    numbers = [0, 2, 13, 37, 5, 6, 20, 10, 43, 28]
    #numbers = [13, 0]
    #print('numbers:', len(numbers))
    
    f1 = open("../Results/Value_of_xi.txt", "w+", encoding="utf-8")
    f2 = open("../Results/errors.txt", "w+", encoding="utf-8")
    correct_prediction = 0
    # Using for loop
    for i in numbers:
        np.random.seed(i)
        print('seed:', i)
        idxs = np.random.choice(y.size, 1000, replace=False)
        X_train = torch.tensor(features[idxs], dtype=torch.float32, requires_grad=True)
        y_train = torch.tensor(label[idxs], dtype=torch.float32)
    
        lamb   = 0
        tolerance = 1e-6
        mask = torch.ones(tot_items, 1)
        #print('xi', xi)
        print('mask:', mask.shape)
        lambd  = 1e-6
    
        for epoch in range(epochs):
            optimizer.zero_grad()
            uhat = net(X_train)
    
            if epoch == 1000:
                lamb = 1
               
            dudt, theta = construct_Dictonary(X_train, uhat, poly_order=2, deriv_order=2)
            #print('dudt:', dudt.shape)
            dudt_norm = torch.norm(dudt, dim=0)
    
            theta_scaling = (torch.norm(theta, dim=0))
            #Returns a new tensor with a dimension of size one inserted at the specified position. from 9 it will be 9,1
            theta_norm = torch.unsqueeze(theta_scaling, dim = 1) 
            xi_normalized = xi * (theta_norm / dudt_norm) 
            L1 = lambd * torch.sum(torch.abs(xi_normalized[1:, :]))
        
            l_u   = nn.MSELoss()(uhat, y_train)
            l_reg = lamb * torch.mean((dudt - theta @ xi)**2)
            #l_reg = torch.mean((dudt - theta @ xi)**2)

            loss = l_u + l_reg + L1

            gradient_loss = torch.max(torch.abs(grad(outputs=loss, inputs=xi, 
                  grad_outputs=torch.ones_like(loss), create_graph=True)[0]) / (theta_norm / dudt_norm))


            loss.backward(retain_graph=True)
            optimizer.step()
        
            if epoch % 1000 == 0:
                print('loss:', epoch, loss)
                if gradient_loss < tolerance:
                    print('Optimizer converged.')
                    break
 
        xi_list = sparse_coeff(mask, xi.detach().numpy())
        xi_normalized = sparse_coeff(mask, xi_normalized.detach().numpy())
        print('xi_normalized:', xi_normalized)
    

        sparsity = normalized_xi_threshold( xi_normalized, mode='auto')
        print('sparsity:', sparsity)
    
        xi_thresholded = np.expand_dims(xi_list[sparsity], axis=1) 
        print('xi_thresholded:', xi_thresholded)
        
        print('Coefficient xi:')
        xi_update = sparse_coeff(sparsity, xi_thresholded)
        print('xi_update:', xi_update)
        
    
        # Calculate Error in xi    
        #if len(xi_thresholded) > 1 and len(xi_thresholded) < 3:
        if xi_update[2] != 0 and xi_update[4] != 0 and len(xi_thresholded) < 3:
            xi_update_app.append(xi_update)
            print('xi_update_app:', xi_update_app)
            print('xi_update:', xi_update[2], xi_update[4])
            error_1 = np.subtract(np.array([0.10000]),xi_update[2])
            #print('error_1', error_1)
            xi1_error = np.append(xi1, error_1)
            print('xi1_error', xi1_error)
            error_2 = np.subtract(np.array([1.00000]),np.abs(xi_update[4]))
            xi2_error = np.append(xi2, error_2)
            print('xi2_error', xi2_error)
            f1.write(str(xi_update[2]) + " " + str(xi_update[4]) + "\n")
            f2.write(str(xi1_error) + " " + str(xi2_error) + "\n")
            xi1_error_app.append(xi1_error)
            print('xi1_error_app:', xi1_error_app)
            xi2_error_app.append(xi2_error)
            print('xi2_error_app:', xi2_error_app)
            correct_prediction += 1
            
        else:
            print('Error: Index out of bound')
            
            
    print('correct_prediction:', correct_prediction)
    xi1_error_avg = np.sum(xi1_error_app, axis = 0) / correct_prediction  
    print('xi1_error_avg:', xi1_error_avg)
    xi2_error_avg = np.sum(xi2_error_app, axis = 0) / correct_prediction 
    print('xi2_error_avg:', xi2_error_avg)
    xi_updated = np.sum(xi_update_app, axis = 0) / correct_prediction  
    print('xi_updated:', xi_updated)
    print('Finished')
    return xi_updated

# %%
xi_updated = model_identification(X, y, mask, poly_order=2, deriv_order=2)
# Out:
# seed: 0
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0301, grad_fn=<AddBackward0>)
# loss: 1000 tensor(1.1223, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0004, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 7000 tensor(0.0003, grad_fn=<AddBackward0>)
# xi_normalized: [[-6.05246983e-03]
#  [-3.18483375e-02]
#  [ 4.49622750e-01]
#  [ 2.11855937e-02]
#  [-9.53960121e-01]
#  [ 6.12214426e-05]
#  [-2.00055912e-02]
#  [-9.74159539e-02]
#  [ 3.19622792e-02]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09227746]
#  [-0.90646207]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.09227746]
#  [ 0.        ]
#  [-0.90646207]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09227746],
#        [ 0.        ],
#        [-0.90646207],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi_update: [0.09227746] [-0.90646207]
# xi1_error [0.00772254]
# xi2_error [0.09353793]
# xi1_error_app: [array([0.00772254])]
# xi2_error_app: [array([0.09353793])]
# seed: 2
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0019, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0003, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 2.70702597e-03]
#  [-3.93156260e-02]
#  [ 3.94616216e-01]
#  [-3.69876157e-03]
#  [-8.49392295e-01]
#  [ 8.71087834e-02]
#  [ 2.42097431e-05]
#  [-1.49625808e-01]
#  [-7.76484981e-02]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09323446]
#  [-0.84606928]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.09323446]
#  [ 0.        ]
#  [-0.84606928]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09227746],
#        [ 0.        ],
#        [-0.90646207],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09323446],
#        [ 0.        ],
#        [-0.84606928],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi_update: [0.09323446] [-0.84606928]
# xi1_error [0.00676554]
# xi2_error [0.15393072]
# xi1_error_app: [array([0.00772254]), array([0.00676554])]
# xi2_error_app: [array([0.09353793]), array([0.15393072])]
# seed: 13
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0027, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.00527216]
#  [-0.06618466]
#  [ 0.44543192]
#  [-0.01991869]
#  [-0.75901693]
#  [-0.04032546]
#  [ 0.01276496]
#  [-0.14723921]
#  [ 0.00653485]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.1032431 ]
#  [-0.77512318]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.1032431 ]
#  [ 0.        ]
#  [-0.77512318]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09227746],
#        [ 0.        ],
#        [-0.90646207],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09323446],
#        [ 0.        ],
#        [-0.84606928],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.1032431 ],
#        [ 0.        ],
#        [-0.77512318],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi_update: [0.1032431] [-0.77512318]
# xi1_error [-0.0032431]
# xi2_error [0.22487682]
# xi1_error_app: [array([0.00772254]), array([0.00676554]), array([-0.0032431])]
# xi2_error_app: [array([0.09353793]), array([0.15393072]), array([0.22487682])]
# seed: 37
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0019, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.00900761]
#  [-0.08606027]
#  [ 0.31535295]
#  [ 0.02924168]
#  [-0.81582308]
#  [ 0.03091932]
#  [-0.06140307]
#  [-0.11161221]
#  [-0.02474073]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.08848957]
#  [-0.79384714]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.08848957]
#  [ 0.        ]
#  [-0.79384714]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09227746],
#        [ 0.        ],
#        [-0.90646207],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09323446],
#        [ 0.        ],
#        [-0.84606928],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.1032431 ],
#        [ 0.        ],
#        [-0.77512318],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08848957],
#        [ 0.        ],
#        [-0.79384714],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi_update: [0.08848957] [-0.79384714]
# xi1_error [0.01151043]
# xi2_error [0.20615286]
# xi1_error_app: [array([0.00772254]), array([0.00676554]), array([-0.0032431]), array([0.01151043])]
# xi2_error_app: [array([0.09353793]), array([0.15393072]), array([0.22487682]), array([0.20615286])]
# seed: 5
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0018, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 7000 tensor(0.0003, grad_fn=<AddBackward0>)
# xi_normalized: [[ 1.02175716e-02]
#  [-5.66626946e-03]
#  [ 4.72502559e-01]
#  [ 3.31994356e-03]
#  [-9.00158226e-01]
#  [ 2.79022534e-05]
#  [-1.29628554e-02]
#  [-5.58710564e-03]
#  [-5.80201447e-02]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.10150839]
#  [-0.97915184]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.10150839]
#  [ 0.        ]
#  [-0.97915184]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09227746],
#        [ 0.        ],
#        [-0.90646207],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09323446],
#        [ 0.        ],
#        [-0.84606928],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.1032431 ],
#        [ 0.        ],
#        [-0.77512318],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08848957],
#        [ 0.        ],
#        [-0.79384714],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.10150839],
#        [ 0.        ],
#        [-0.97915184],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi_update: [0.10150839] [-0.97915184]
# xi1_error [-0.00150839]
# xi2_error [0.02084816]
# xi1_error_app: [array([0.00772254]), array([0.00676554]), array([-0.0032431]), array([0.01151043]), array([-0.00150839])]
# xi2_error_app: [array([0.09353793]), array([0.15393072]), array([0.22487682]), array([0.20615286]), array([0.02084816])]
# seed: 6
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0030, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 2.09992006e-03]
#  [-5.06162830e-02]
#  [ 3.89592141e-01]
#  [ 4.66705719e-03]
#  [-8.35124314e-01]
#  [ 4.43699025e-02]
#  [-4.81294410e-05]
#  [-1.88066393e-01]
#  [-1.82543416e-02]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09263732]
#  [-0.8314268 ]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.09263732]
#  [ 0.        ]
#  [-0.8314268 ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09227746],
#        [ 0.        ],
#        [-0.90646207],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09323446],
#        [ 0.        ],
#        [-0.84606928],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.1032431 ],
#        [ 0.        ],
#        [-0.77512318],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08848957],
#        [ 0.        ],
#        [-0.79384714],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.10150839],
#        [ 0.        ],
#        [-0.97915184],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09263732],
#        [ 0.        ],
#        [-0.8314268 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi_update: [0.09263732] [-0.8314268]
# xi1_error [0.00736268]
# xi2_error [0.1685732]
# xi1_error_app: [array([0.00772254]), array([0.00676554]), array([-0.0032431]), array([0.01151043]), array([-0.00150839]), array([0.00736268])]
# xi2_error_app: [array([0.09353793]), array([0.15393072]), array([0.22487682]), array([0.20615286]), array([0.02084816]), array([0.1685732])]
# seed: 20
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0015, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[-5.76522015e-03]
#  [-3.65527682e-02]
#  [ 3.83377165e-01]
#  [-6.17452270e-06]
#  [-8.44873607e-01]
#  [ 1.84054542e-02]
#  [ 9.95198451e-03]
#  [-1.07313924e-01]
#  [ 4.67907451e-03]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09856696]
#  [-0.87316221]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.09856696]
#  [ 0.        ]
#  [-0.87316221]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09227746],
#        [ 0.        ],
#        [-0.90646207],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09323446],
#        [ 0.        ],
#        [-0.84606928],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.1032431 ],
#        [ 0.        ],
#        [-0.77512318],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08848957],
#        [ 0.        ],
#        [-0.79384714],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.10150839],
#        [ 0.        ],
#        [-0.97915184],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09263732],
#        [ 0.        ],
#        [-0.8314268 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09856696],
#        [ 0.        ],
#        [-0.87316221],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi_update: [0.09856696] [-0.87316221]
# xi1_error [0.00143304]
# xi2_error [0.12683779]
# xi1_error_app: [array([0.00772254]), array([0.00676554]), array([-0.0032431]), array([0.01151043]), array([-0.00150839]), array([0.00736268]), array([0.00143304])]
# xi2_error_app: [array([0.09353793]), array([0.15393072]), array([0.22487682]), array([0.20615286]), array([0.02084816]), array([0.1685732]), array([0.12683779])]
# seed: 10
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0004, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0022, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 7000 tensor(0.0003, grad_fn=<AddBackward0>)
# xi_normalized: [[ 1.97328255e-03]
#  [-3.94081175e-02]
#  [ 3.74844372e-01]
#  [-5.76100778e-03]
#  [-9.27948892e-01]
#  [ 1.26091223e-02]
#  [-6.12764852e-03]
#  [-6.34823814e-02]
#  [-5.13170904e-04]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09756873]
#  [-0.90105498]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.09756873]
#  [ 0.        ]
#  [-0.90105498]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09227746],
#        [ 0.        ],
#        [-0.90646207],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09323446],
#        [ 0.        ],
#        [-0.84606928],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.1032431 ],
#        [ 0.        ],
#        [-0.77512318],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08848957],
#        [ 0.        ],
#        [-0.79384714],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.10150839],
#        [ 0.        ],
#        [-0.97915184],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09263732],
#        [ 0.        ],
#        [-0.8314268 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09856696],
#        [ 0.        ],
#        [-0.87316221],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09756873],
#        [ 0.        ],
#        [-0.90105498],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi_update: [0.09756873] [-0.90105498]
# xi1_error [0.00243127]
# xi2_error [0.09894502]
# xi1_error_app: [array([0.00772254]), array([0.00676554]), array([-0.0032431]), array([0.01151043]), array([-0.00150839]), array([0.00736268]), array([0.00143304]), array([0.00243127])]
# xi2_error_app: [array([0.09353793]), array([0.15393072]), array([0.22487682]), array([0.20615286]), array([0.02084816]), array([0.1685732]), array([0.12683779]), array([0.09894502])]
# seed: 43
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0004, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0026, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 6.54987851e-03]
#  [-6.09467253e-02]
#  [ 3.66348118e-01]
#  [ 3.76279987e-02]
#  [-7.93390095e-01]
#  [ 3.91578469e-05]
#  [-7.65281394e-02]
#  [-5.24211079e-02]
#  [ 7.27410754e-03]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.08674878]
#  [-0.8485043 ]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.08674878]
#  [ 0.        ]
#  [-0.8485043 ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09227746],
#        [ 0.        ],
#        [-0.90646207],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09323446],
#        [ 0.        ],
#        [-0.84606928],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.1032431 ],
#        [ 0.        ],
#        [-0.77512318],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08848957],
#        [ 0.        ],
#        [-0.79384714],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.10150839],
#        [ 0.        ],
#        [-0.97915184],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09263732],
#        [ 0.        ],
#        [-0.8314268 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09856696],
#        [ 0.        ],
#        [-0.87316221],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09756873],
#        [ 0.        ],
#        [-0.90105498],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08674878],
#        [ 0.        ],
#        [-0.8485043 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi_update: [0.08674878] [-0.8485043]
# xi1_error [0.01325122]
# xi2_error [0.1514957]
# xi1_error_app: [array([0.00772254]), array([0.00676554]), array([-0.0032431]), array([0.01151043]), array([-0.00150839]), array([0.00736268]), array([0.00143304]), array([0.00243127]), array([0.01325122])]
# xi2_error_app: [array([0.09353793]), array([0.15393072]), array([0.22487682]), array([0.20615286]), array([0.02084816]), array([0.1685732]), array([0.12683779]), array([0.09894502]), array([0.1514957])]
# seed: 28
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0026, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 4.29622689e-03]
#  [-7.87593797e-02]
#  [ 3.86400610e-01]
#  [ 1.00069670e-02]
#  [-7.31113076e-01]
#  [ 9.48893648e-05]
#  [-3.27303708e-02]
#  [-1.82121709e-01]
#  [-1.43220168e-04]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09134188]
#  [-0.74707907]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.09134188]
#  [ 0.        ]
#  [-0.74707907]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09227746],
#        [ 0.        ],
#        [-0.90646207],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09323446],
#        [ 0.        ],
#        [-0.84606928],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.1032431 ],
#        [ 0.        ],
#        [-0.77512318],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08848957],
#        [ 0.        ],
#        [-0.79384714],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.10150839],
#        [ 0.        ],
#        [-0.97915184],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09263732],
#        [ 0.        ],
#        [-0.8314268 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09856696],
#        [ 0.        ],
#        [-0.87316221],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09756873],
#        [ 0.        ],
#        [-0.90105498],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08674878],
#        [ 0.        ],
#        [-0.8485043 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09134188],
#        [ 0.        ],
#        [-0.74707907],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi_update: [0.09134188] [-0.74707907]
# xi1_error [0.00865812]
# xi2_error [0.25292093]
# xi1_error_app: [array([0.00772254]), array([0.00676554]), array([-0.0032431]), array([0.01151043]), array([-0.00150839]), array([0.00736268]), array([0.00143304]), array([0.00243127]), array([0.01325122]), array([0.00865812])]
# xi2_error_app: [array([0.09353793]), array([0.15393072]), array([0.22487682]), array([0.20615286]), array([0.02084816]), array([0.1685732]), array([0.12683779]), array([0.09894502]), array([0.1514957]), array([0.25292093])]
# correct_prediction: 10
# xi1_error_avg: [0.00543834]
# xi2_error_avg: [0.14981191]
# xi_updated: [[ 0.        ]
#  [ 0.        ]
#  [ 0.09456166]
#  [ 0.        ]
#  [-0.85018809]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# Finished

# %%
pde_Recover(xi_updated, library_coeffs, equation_form='u_t')
#print('Process Completed')
# Out:
# Burger equation:
# u_t = 0.0946u_{xx} - 0.8502uu_{x}
