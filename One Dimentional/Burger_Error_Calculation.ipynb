# %% [markdown]
# # Burgers Equation
#
# $$u_t+uu_x=0.1u_{xx}$$

# %%
import os
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
import torch
import tensorflow as tf

import csv
from torch.autograd import grad
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ExponentialLR
from pylab import figure, text, scatter, show
from pdefind import *

from Model_Identification.PDE_Equation import pde_matrix_mul, sparse_coeff, normalized_xi_threshold, pde_Recover
from Model_Identification.build_Library import construct_Dictonary

# %% [markdown]
# ## Data Setup

# %%
data = sio.loadmat(os.path.join(os.getcwd(), "../data", "burgers.mat"))
u = data["usol"]
x = data["x"][0]
t = np.squeeze(data["t"], axis=1)

print("u shape", u.shape)
print("x shape", x.shape)
print("t shape", t.shape)

im = plt.imshow(u.real, cmap="seismic", aspect=0.4)
plt.colorbar(im)
plt.title("Burgers Equation")
plt.xlabel("t")
plt.ylabel("x")


xpos  = np.arange(len(t), step=25)
ypos  = np.where(x%4==0)[0].tolist()
ytick = x[ypos].tolist()
ypos  += [len(x)-1]
ytick += [8.0]

plt.xticks(xpos, t[xpos])
plt.yticks(ypos, ytick)
plt.gcf().set_size_inches(6,5)
plt.show()
# Out:
# u shape (256, 101)
# x shape (256,)
# t shape (101,)

# %%
# Add noise
#np.random.seed(8)
noise_level = 0.1
u = u.real + noise_level*np.std(u.real)*np.random.randn(u.shape[0],u.shape[1])

im = plt.imshow(u.real, cmap="seismic", aspect=0.4)
plt.colorbar(im)
plt.title("Noisy Data")
plt.xlabel("t")
plt.ylabel("x")

plt.xticks(xpos, t[xpos])
plt.yticks(ypos, ytick)
plt.gcf().set_size_inches(6,5)
plt.show()

# %%
# Prepare Training Data
xx, tt = np.meshgrid(x,t)
X = np.vstack([xx.ravel(), tt.ravel()]).T
print("X shape", X.shape)
print(X)
# Out:
# X shape (25856, 2)
# [[-8.      0.    ]
#  [-7.9375  0.    ]
#  [-7.875   0.    ]
#  ...
#  [ 7.8125 10.    ]
#  [ 7.875  10.    ]
#  [ 7.9375 10.    ]]

# %%
y = np.zeros((u.size, 1), dtype=np.float)
for i,_x in enumerate(u.real.T):
    y[i*len(x):(i+1)*len(x)] = _x.reshape(len(x),1)
    
print("y shape", y.shape)
# Out:
# y shape (25856, 1)

# %%
# Setup Network
net = PINN(sizes=[2,20,20,20,20,20,1], activation=torch.nn.Tanh())
print(net)
# Out:
# PINN(
#   (net): Sequential(
#     (0): Linear(in_features=2, out_features=20, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=20, out_features=20, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=20, out_features=20, bias=True)
#     (7): Tanh()
#     (8): Linear(in_features=20, out_features=20, bias=True)
#     (9): Tanh()
#     (10): Linear(in_features=20, out_features=1, bias=True)
#   )
# )

# %%
polynm = ['1', 'u', 'uˆ2']
spa_der = ['1', 'u_{x}', 'u_{xx}']
library_coeffs = pde_matrix_mul(polynm, spa_der)
print('library_coeffs:', library_coeffs)

tot_items = len(library_coeffs)
print('tot_items:', tot_items)

mask = torch.ones(tot_items, 1)
epochs = 8000

xi = nn.Parameter(torch.randn((tot_items, 1), requires_grad=True, device="cpu", dtype=torch.float32))
params = [{'params': net.parameters(), 'lr': 3e-3}, {'params': xi, 'lr': 3e-2}]

optimizer = Adam(params)
scheduler = ExponentialLR(optimizer, .9998)
# Out:
# library_coeffs: ['1', 'u_{x}', 'u_{xx}', 'u', 'uu_{x}', 'uu_{xx}', 'uˆ2', 'uˆ2u_{x}', 'uˆ2u_{xx}']
# tot_items: 9

# %%
def model_identification(features, label, mask, poly_order, deriv_order):
    
    xi1 = []
    xi2 = []
    xi1_error_app = []
    xi2_error_app = []
    xi_update_app = []
    
    numbers = [0, 2, 13, 37, 5, 6, 20, 10, 43, 28]
    #numbers = [13, 0]
    #print('numbers:', len(numbers))
    
    f1 = open("../Results/Value_of_xi.txt", "w+", encoding="utf-8")
    f2 = open("../Results/errors.txt", "w+", encoding="utf-8")
    correct_prediction = 0
    # Using for loop
    for i in numbers:
        np.random.seed(i)
        print('seed:', i)
        idxs = np.random.choice(y.size, 1000, replace=False)
        X_train = torch.tensor(features[idxs], dtype=torch.float32, requires_grad=True)
        y_train = torch.tensor(label[idxs], dtype=torch.float32)
    
        lamb   = 0
        tolerance = 1e-6
        mask = torch.ones(tot_items, 1)
        #print('xi', xi)
        print('mask:', mask.shape)
        lambd  = 1e-6
    
        for epoch in range(epochs):
            optimizer.zero_grad()
            uhat = net(X_train)
    
            if epoch == 1000:
                lamb = 1
               
            dudt, theta = construct_Dictonary(X_train, uhat, poly_order=2, deriv_order=2)
            #print('dudt:', dudt.shape)
            dudt_norm = torch.norm(dudt, dim=0)
    
            theta_scaling = (torch.norm(theta, dim=0))
            #Returns a new tensor with a dimension of size one inserted at the specified position. from 9 it will be 9,1
            theta_norm = torch.unsqueeze(theta_scaling, dim = 1) 
            xi_normalized = xi * (theta_norm / dudt_norm) 
            L1 = lambd * torch.sum(torch.abs(xi_normalized[1:, :]))
        
            l_u   = nn.MSELoss()(uhat, y_train)
            l_reg = lamb * torch.mean((dudt - theta @ xi)**2)
            #l_reg = torch.mean((dudt - theta @ xi)**2)

            loss = l_u + l_reg + L1

            gradient_loss = torch.max(torch.abs(grad(outputs=loss, inputs=xi, 
                  grad_outputs=torch.ones_like(loss), create_graph=True)[0]) / (theta_norm / dudt_norm))


            loss.backward(retain_graph=True)
            optimizer.step()
        
            if epoch % 1000 == 0:
                print('loss:', epoch, loss)
                if gradient_loss < tolerance:
                    print('Optimizer converged.')
                    break
 
        xi_list = sparse_coeff(mask, xi.detach().numpy())
        xi_normalized = sparse_coeff(mask, xi_normalized.detach().numpy())
        print('xi_normalized:', xi_normalized)
    

        sparsity = normalized_xi_threshold( xi_normalized, mode='auto')
        print('sparsity:', sparsity)
    
        xi_thresholded = np.expand_dims(xi_list[sparsity], axis=1) 
        print('xi_thresholded:', xi_thresholded)
        
        print('Coefficient xi:')
        xi_update = sparse_coeff(sparsity, xi_thresholded)
        #xi_add = np.add(xi_th, xi_update)
        xi_update_app.append(xi_update)
        print('xi_update_app:', xi_update_app)
    
        # Calculate Error in xi    
        if len(xi_thresholded) > 1 and len(xi_thresholded) < 3:
            error_1 = np.subtract(np.array([0.10000]),xi_thresholded[0])
            #print('error_1', error_1)
            xi1_error = np.append(xi1, error_1)
            print('xi1_error', xi1_error)
            error_2 = np.subtract(np.array([1.00000]),np.abs(xi_thresholded[1]))
            xi2_error = np.append(xi2, error_2)
            #xi2_error.append(error_2)
            print('xi2_error', xi2_error)
            f1.write(str(xi_thresholded[0]) + " " + str(xi_thresholded[1]) + "\n")
            f2.write(str(xi1_error) + " " + str(xi2_error) + "\n")
            xi1_error_app.append(xi1_error)
            print('xi1_error_app:', xi1_error_app)
            xi2_error_app.append(xi2_error)
            print('xi2_error_app:', xi2_error_app)
            correct_prediction += 1
            
        else:
            print('Error: Index out of bound')
            
            
    print('correct_prediction:', correct_prediction)
    xi1_error_avg = np.sum(xi1_error_app, axis = 0) / correct_prediction  
    print('xi1_error_avg:', xi1_error_avg)
    xi2_error_avg = np.sum(xi2_error_app, axis = 0) / correct_prediction 
    print('xi2_error_avg:', xi2_error_avg)
    xi_updated = np.sum(xi_update_app, axis = 0) / correct_prediction  
    print('xi_updated:', xi_updated)
    print('Finished')
    return xi_updated

# %%
xi_updated = model_identification(X, y, mask, poly_order=2, deriv_order=2)
# Out:
# seed: 0
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.1185, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.1739, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0003, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.00566811]
#  [-0.08349103]
#  [ 0.42764208]
#  [ 0.05863567]
#  [-0.95687824]
#  [ 0.03347482]
#  [-0.11023816]
#  [-0.00191588]
#  [-0.08534542]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.08955778]
#  [-0.89380163]]
# Coefficient xi:
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08955778],
#        [ 0.        ],
#        [-0.89380163],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi1_error [0.01044222]
# xi2_error [0.10619837]
# xi1_error_app: [array([0.01044222])]
# xi2_error_app: [array([0.10619837])]
# seed: 2
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0017, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0004, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 7000 tensor(0.0003, grad_fn=<AddBackward0>)
# xi_normalized: [[ 6.30765455e-03]
#  [-4.70122322e-02]
#  [ 4.02418941e-01]
#  [-1.31577253e-02]
#  [-8.39613497e-01]
#  [ 2.27706507e-04]
#  [ 1.04336739e-02]
#  [-1.41324028e-01]
#  [ 1.08250984e-04]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09678864]
#  [-0.8343395 ]]
# Coefficient xi:
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08955778],
#        [ 0.        ],
#        [-0.89380163],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09678864],
#        [ 0.        ],
#        [-0.8343395 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi1_error [0.00321136]
# xi2_error [0.1656605]
# xi1_error_app: [array([0.01044222]), array([0.00321136])]
# xi2_error_app: [array([0.10619837]), array([0.1656605])]
# seed: 13
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0037, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0004, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 7000 tensor(0.0003, grad_fn=<AddBackward0>)
# xi_normalized: [[ 1.55850751e-02]
#  [-7.20699877e-02]
#  [ 4.10986543e-01]
#  [ 3.89178917e-02]
#  [-8.25939238e-01]
#  [-4.54906113e-02]
#  [-7.98920318e-02]
#  [-6.69442862e-02]
#  [-2.35067855e-04]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09589587]
#  [-0.84641296]]
# Coefficient xi:
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08955778],
#        [ 0.        ],
#        [-0.89380163],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09678864],
#        [ 0.        ],
#        [-0.8343395 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09589587],
#        [ 0.        ],
#        [-0.84641296],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi1_error [0.00410413]
# xi2_error [0.15358704]
# xi1_error_app: [array([0.01044222]), array([0.00321136]), array([0.00410413])]
# xi2_error_app: [array([0.10619837]), array([0.1656605]), array([0.15358704])]
# seed: 37
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0004, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0081, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 7000 tensor(0.0003, grad_fn=<AddBackward0>)
# xi_normalized: [[ 0.01822407]
#  [-0.11166536]
#  [ 0.31430236]
#  [ 0.04861091]
#  [-0.68012911]
#  [-0.01426872]
#  [-0.0821214 ]
#  [-0.19235064]
#  [-0.00308718]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09140695]
#  [-0.6895622 ]]
# Coefficient xi:
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08955778],
#        [ 0.        ],
#        [-0.89380163],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09678864],
#        [ 0.        ],
#        [-0.8343395 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09589587],
#        [ 0.        ],
#        [-0.84641296],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09140695],
#        [ 0.        ],
#        [-0.6895622 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi1_error [0.00859305]
# xi2_error [0.3104378]
# xi1_error_app: [array([0.01044222]), array([0.00321136]), array([0.00410413]), array([0.00859305])]
# xi2_error_app: [array([0.10619837]), array([0.1656605]), array([0.15358704]), array([0.3104378])]
# seed: 5
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0004, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0030, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0004, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 7000 tensor(0.0003, grad_fn=<AddBackward0>)
# xi_normalized: [[ 0.01069293]
#  [-0.11700933]
#  [ 0.43726546]
#  [ 0.04835897]
#  [-0.81671321]
#  [-0.00164966]
#  [-0.11469828]
#  [ 0.00214537]
#  [-0.02708029]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.08551355]
#  [-0.81926155]]
# Coefficient xi:
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08955778],
#        [ 0.        ],
#        [-0.89380163],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09678864],
#        [ 0.        ],
#        [-0.8343395 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09589587],
#        [ 0.        ],
#        [-0.84641296],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09140695],
#        [ 0.        ],
#        [-0.6895622 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08551355],
#        [ 0.        ],
#        [-0.81926155],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi1_error [0.01448645]
# xi2_error [0.18073845]
# xi1_error_app: [array([0.01044222]), array([0.00321136]), array([0.00410413]), array([0.00859305]), array([0.01448645])]
# xi2_error_app: [array([0.10619837]), array([0.1656605]), array([0.15358704]), array([0.3104378]), array([0.18073845])]
# seed: 6
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0058, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 7000 tensor(0.0003, grad_fn=<AddBackward0>)
# xi_normalized: [[ 0.01798958]
#  [-0.07592088]
#  [ 0.39407337]
#  [ 0.05677235]
#  [-0.93299842]
#  [-0.01818493]
#  [-0.09039413]
#  [ 0.02530093]
#  [-0.04632473]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09446564]
#  [-0.90089667]]
# Coefficient xi:
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08955778],
#        [ 0.        ],
#        [-0.89380163],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09678864],
#        [ 0.        ],
#        [-0.8343395 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09589587],
#        [ 0.        ],
#        [-0.84641296],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09140695],
#        [ 0.        ],
#        [-0.6895622 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08551355],
#        [ 0.        ],
#        [-0.81926155],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09446564],
#        [ 0.        ],
#        [-0.90089667],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi1_error [0.00553436]
# xi2_error [0.09910333]
# xi1_error_app: [array([0.01044222]), array([0.00321136]), array([0.00410413]), array([0.00859305]), array([0.01448645]), array([0.00553436])]
# xi2_error_app: [array([0.10619837]), array([0.1656605]), array([0.15358704]), array([0.3104378]), array([0.18073845]), array([0.09910333])]
# seed: 20
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0004, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0046, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 8.78136884e-03]
#  [-1.41456276e-01]
#  [ 3.26286495e-01]
#  [ 8.90116394e-02]
#  [-6.71465755e-01]
#  [ 1.53022309e-04]
#  [-1.79868296e-01]
#  [-1.08677641e-01]
#  [-2.40241978e-02]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.07136085]
#  [-0.69671035]]
# Coefficient xi:
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08955778],
#        [ 0.        ],
#        [-0.89380163],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09678864],
#        [ 0.        ],
#        [-0.8343395 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09589587],
#        [ 0.        ],
#        [-0.84641296],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09140695],
#        [ 0.        ],
#        [-0.6895622 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08551355],
#        [ 0.        ],
#        [-0.81926155],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09446564],
#        [ 0.        ],
#        [-0.90089667],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.07136085],
#        [ 0.        ],
#        [-0.69671035],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi1_error [0.02863915]
# xi2_error [0.30328965]
# xi1_error_app: [array([0.01044222]), array([0.00321136]), array([0.00410413]), array([0.00859305]), array([0.01448645]), array([0.00553436]), array([0.02863915])]
# xi2_error_app: [array([0.10619837]), array([0.1656605]), array([0.15358704]), array([0.3104378]), array([0.18073845]), array([0.09910333]), array([0.30328965])]
# seed: 10
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0004, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0022, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 7000 tensor(0.0003, grad_fn=<AddBackward0>)
# xi_normalized: [[-7.39448331e-03]
#  [-3.75054851e-02]
#  [ 3.98863256e-01]
#  [ 3.38342711e-02]
#  [-1.00690854e+00]
#  [ 6.72957860e-04]
#  [-4.53711227e-02]
#  [ 5.26700984e-04]
#  [-7.10568810e-03]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.08869128]
#  [-0.92289841]]
# Coefficient xi:
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08955778],
#        [ 0.        ],
#        [-0.89380163],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09678864],
#        [ 0.        ],
#        [-0.8343395 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09589587],
#        [ 0.        ],
#        [-0.84641296],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09140695],
#        [ 0.        ],
#        [-0.6895622 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08551355],
#        [ 0.        ],
#        [-0.81926155],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09446564],
#        [ 0.        ],
#        [-0.90089667],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.07136085],
#        [ 0.        ],
#        [-0.69671035],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08869128],
#        [ 0.        ],
#        [-0.92289841],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi1_error [0.01130872]
# xi2_error [0.07710159]
# xi1_error_app: [array([0.01044222]), array([0.00321136]), array([0.00410413]), array([0.00859305]), array([0.01448645]), array([0.00553436]), array([0.02863915]), array([0.01130872])]
# xi2_error_app: [array([0.10619837]), array([0.1656605]), array([0.15358704]), array([0.3104378]), array([0.18073845]), array([0.09910333]), array([0.30328965]), array([0.07710159])]
# seed: 43
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0036, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 7000 tensor(0.0003, grad_fn=<AddBackward0>)
# xi_normalized: [[ 2.12280788e-02]
#  [-2.51581147e-02]
#  [ 3.85360330e-01]
#  [ 9.11110938e-02]
#  [-9.20288205e-01]
#  [ 5.01740906e-05]
#  [-1.60322592e-01]
#  [ 1.45550564e-01]
#  [-1.72266236e-03]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.07948596]
#  [-1.04481483]]
# Coefficient xi:
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08955778],
#        [ 0.        ],
#        [-0.89380163],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09678864],
#        [ 0.        ],
#        [-0.8343395 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09589587],
#        [ 0.        ],
#        [-0.84641296],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09140695],
#        [ 0.        ],
#        [-0.6895622 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08551355],
#        [ 0.        ],
#        [-0.81926155],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09446564],
#        [ 0.        ],
#        [-0.90089667],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.07136085],
#        [ 0.        ],
#        [-0.69671035],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08869128],
#        [ 0.        ],
#        [-0.92289841],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.07948596],
#        [ 0.        ],
#        [-1.04481483],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi1_error [0.02051404]
# xi2_error [-0.04481483]
# xi1_error_app: [array([0.01044222]), array([0.00321136]), array([0.00410413]), array([0.00859305]), array([0.01448645]), array([0.00553436]), array([0.02863915]), array([0.01130872]), array([0.02051404])]
# xi2_error_app: [array([0.10619837]), array([0.1656605]), array([0.15358704]), array([0.3104378]), array([0.18073845]), array([0.09910333]), array([0.30328965]), array([0.07710159]), array([-0.04481483])]
# seed: 28
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0004, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0035, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 7000 tensor(0.0003, grad_fn=<AddBackward0>)
# xi_normalized: [[ 0.01912481]
#  [-0.12943456]
#  [ 0.42941672]
#  [ 0.02084719]
#  [-0.69252592]
#  [-0.00508354]
#  [-0.09167889]
#  [-0.10357922]
#  [-0.07578649]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.08629956]
#  [-0.71506953]]
# Coefficient xi:
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08955778],
#        [ 0.        ],
#        [-0.89380163],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09678864],
#        [ 0.        ],
#        [-0.8343395 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09589587],
#        [ 0.        ],
#        [-0.84641296],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09140695],
#        [ 0.        ],
#        [-0.6895622 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08551355],
#        [ 0.        ],
#        [-0.81926155],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09446564],
#        [ 0.        ],
#        [-0.90089667],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.07136085],
#        [ 0.        ],
#        [-0.69671035],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08869128],
#        [ 0.        ],
#        [-0.92289841],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.07948596],
#        [ 0.        ],
#        [-1.04481483],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08629956],
#        [ 0.        ],
#        [-0.71506953],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi1_error [0.01370044]
# xi2_error [0.28493047]
# xi1_error_app: [array([0.01044222]), array([0.00321136]), array([0.00410413]), array([0.00859305]), array([0.01448645]), array([0.00553436]), array([0.02863915]), array([0.01130872]), array([0.02051404]), array([0.01370044])]
# xi2_error_app: [array([0.10619837]), array([0.1656605]), array([0.15358704]), array([0.3104378]), array([0.18073845]), array([0.09910333]), array([0.30328965]), array([0.07710159]), array([-0.04481483]), array([0.28493047])]
# correct_prediction: 10
# xi1_error_avg: [0.01205339]
# xi2_error_avg: [0.16362324]
# xi_updated: [[ 0.        ]
#  [ 0.        ]
#  [ 0.08794661]
#  [ 0.        ]
#  [-0.83637676]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# Finished

# %%
pde_Recover(xi_updated, library_coeffs, equation_form='u_t')
#print('Process Completed')
# Out:
# Burger equation:
# u_t = 0.0879u_{xx} - 0.8364uu_{x}
