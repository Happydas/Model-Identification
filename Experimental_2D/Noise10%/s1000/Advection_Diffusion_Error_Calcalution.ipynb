# %% [markdown]
# # 2D Advection-Diffusion Equation
#
# $$u_t = 0.25u_{x} + 0.5 u_{y} + 0.5u_{xx} + 0.5 u_{yy}$$

# %%
import os
import numpy as np
import pandas as pd 
import scipy.io as sio
import matplotlib.pyplot as plt
import torch
import tensorflow as tf

from torch.autograd import grad
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ExponentialLR

from pdefind import *
from Model_Identification.PDE_Equation import pde_matrix_mul, sparse_coeff, normalized_xi_threshold, pde_Recover
from Model_Identification.build_Library import construct_Dictonary_2D
from datetime import datetime
import numba.cuda

# %%
start_time = datetime.now()

# Prepare dataset
data = sio.loadmat(os.path.join(os.getcwd(), "../data", "Advection_diffusion.mat"))
usol = np.real(data['Expression1'])
print('u.shape', usol.shape)
usol= usol.reshape((51,51,61,4))
#u = data["usol"]
x = usol[:,:,:,0]
y = usol[:,:,:,1]
t = usol[:,:,:,2]
u = usol[:,:,:,3]
print('u.shape', u.shape)
print('x.shape', x.shape)
print('t.shape', t.shape)
print('y.shape', y.shape)
print(x[:,:,10].shape)
# Out:
# u.shape (634644, 1)
# u.shape (51, 51, 61)
# x.shape (51, 51, 61)
# t.shape (51, 51, 61)
# y.shape (51, 51, 61)
# (51, 51)

# %%
fig, ax = plt.subplots()

im = ax.contourf(x[:,:,10], y[:,:,10], u[:,:,10], cmap='seismic')
ax.set_xlabel('x')
ax.set_ylabel('y')

fig.colorbar(mappable=im)

plt.show()

# %%
X = np.transpose((t.flatten(),x.flatten(), y.flatten()))
Y = u.reshape((u.size, 1))
print(X.shape, Y.shape)
print('X:', X)
# Out:
# (158661, 3) (158661, 1)
# X: [[ 3.  -5.  -5. ]
#  [ 3.1 -5.  -5. ]
#  [ 3.2 -5.  -5. ]
#  ...
#  [ 8.8  5.   5. ]
#  [ 8.9  5.   5. ]
#  [ 9.   5.   5. ]]

# %%
# Add noise
np.random.seed(0)
noise_level = 0.1
y = Y + noise_level * np.std(Y) * np.random.randn(Y.size, 1)

# %%
# Setup Network
net = PINN(sizes=[3,20,20,20,20,20,1], activation=torch.nn.Tanh())
print(net)
# Out:
# PINN(
#   (net): Sequential(
#     (0): Linear(in_features=3, out_features=20, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=20, out_features=20, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=20, out_features=20, bias=True)
#     (7): Tanh()
#     (8): Linear(in_features=20, out_features=20, bias=True)
#     (9): Tanh()
#     (10): Linear(in_features=20, out_features=1, bias=True)
#   )
# )

# %%
polynm = ['1', 'u']
spa_der = ['1', 'u_{x}', 'u_{y}','u_{xx}', 'u_{yy}','u_{xy}']
library_coeffs = pde_matrix_mul(polynm, spa_der)
print('library_coeffs:', library_coeffs)

tot_items = len(library_coeffs)
print('tot_items:', tot_items)

mask = torch.ones(tot_items, 1)
epochs = 10000
xi = nn.Parameter(torch.randn((tot_items, 1), requires_grad=True, device="cpu", dtype=torch.float32))
#params = [{'params': net.parameters(), 'lr': 3e-3}, {'params': xi, 'lr': 3e-2}]
params = [{'params': net.parameters(), 'lr': 1e-3}, {'params': xi, 'lr': 1e-2}]

optimizer = Adam(params)
scheduler = ExponentialLR(optimizer, .9998)
# Out:
# library_coeffs: ['1', 'u_{x}', 'u_{y}', 'u_{xx}', 'u_{yy}', 'u_{xy}', 'u', 'uu_{x}', 'uu_{y}', 'uu_{xx}', 'uu_{yy}', 'uu_{xy}']
# tot_items: 12

# %%
def model_identification(features, label, mask, poly_order, deriv_order):
    
    xi1 = []
    xi2 = []
    xi3 = []
    xi4 = []
    xi1_error_app = []
    xi2_error_app = []
    xi3_error_app = []
    xi4_error_app = []
    xi_update_app = []
    
    numbers = [0, 5, 26, 57, 73, 80, 95, 104, 129, 151]
    
    f1 = open("Results/Average_errors.txt", "w+", encoding="utf-8")
    f2 = open("Results/Average_xi.txt", "w+", encoding="utf-8")

    correct_prediction = 0
    # Using for loop
    for i in numbers:
        np.random.seed(i)
        print('seed:', i)
        idxs = np.random.choice(y.size, 1000, replace=False)
        X_train = torch.tensor(features[idxs], dtype=torch.float32, requires_grad=True)
        y_train = torch.tensor(label[idxs], dtype=torch.float32)
    
        lamb   = 0
        tolerance = 1e-6
        mask = torch.ones(tot_items, 1)
        #print('xi', xi)
        print('mask:', mask.shape)
        lambd  = 1e-6
    
        for epoch in range(epochs):
            optimizer.zero_grad()
            uhat = net(X_train)
    
            if epoch == 1000:
                lamb = 1
               
            dudt, theta = construct_Dictonary_2D(X_train, uhat, poly_order=1, deriv_order=2)
            #print('dudt:', dudt.shape)
            dudt_norm = torch.norm(dudt, dim=0)
    
            theta_scaling = (torch.norm(theta, dim=0))
            #Returns a new tensor with a dimension of size one inserted at the specified position. from 9 it will be 9,1
            theta_norm = torch.unsqueeze(theta_scaling, dim = 1) 
            xi_normalized = xi * (theta_norm / dudt_norm) 
            L1 = lambd * torch.sum(torch.abs(xi_normalized[1:, :]))
        
            l_u   = nn.MSELoss()(uhat, y_train)
            l_reg = lamb * torch.mean((dudt - theta @ xi)**2)
            #l_reg = torch.mean((dudt - theta @ xi)**2)

            loss = l_u + l_reg + L1

            gradient_loss = torch.max(torch.abs(grad(outputs=loss, inputs=xi, 
                  grad_outputs=torch.ones_like(loss), create_graph=True)[0]) / (theta_norm / dudt_norm))


            loss.backward(retain_graph=True)
            optimizer.step()
        
            if epoch % 1000 == 0:
                print('loss:', epoch, loss)
                if gradient_loss < tolerance:
                    print('Optimizer converged.')
                    break
 
        xi_list = sparse_coeff(mask, xi.detach().numpy())
        xi_normalized = sparse_coeff(mask, xi_normalized.detach().numpy())
        print('xi_normalized:', xi_normalized)
    

        sparsity = normalized_xi_threshold( xi_normalized, mode='auto')
        print('sparsity:', sparsity)
    
        xi_thresholded = np.expand_dims(xi_list[sparsity], axis=1) 
        print('xi_thresholded:', xi_thresholded)
        
        print('Coefficient xi:')
        xi_update = sparse_coeff(sparsity, xi_thresholded)
        print('xi_update:', xi_update)
        
    
        # Calculate Error in xi    
        if xi_update[1] != 0 and xi_update[2] != 0 and xi_update[3] != 0 and xi_update[4] != 0 and len(xi_thresholded) < 5:
            xi_update_app.append(xi_update)
            #print('xi_update_app:', xi_update_app)
            print('xi_update:', xi_update[1], xi_update[2], xi_update[3], xi_update[4])
            error_1 = np.subtract(np.array([0.25000]),xi_update[1])
            xi1_error = np.append(xi1, error_1)
            print('xi1_error', xi1_error)
            error_2 = np.subtract(np.array([0.50000]),xi_update[2])
            xi2_error = np.append(xi2, error_2)
            print('xi2_error', xi2_error)
            error_3 = np.subtract(np.array([0.50000]),xi_update[3])
            xi3_error = np.append(xi3, error_3)
            print('xi3_error', xi3_error)
            error_4 = np.subtract(np.array([0.50000]),xi_update[4])
            xi4_error = np.append(xi4, error_4)
            print('xi4_error', xi4_error)
            xi1_error_app.append(xi1_error)
            print('xi1_error_app:', xi1_error_app)
            xi2_error_app.append(xi2_error)
            print('xi2_error_app:', xi2_error_app)
            xi3_error_app.append(xi3_error)
            print('xi3_error_app:', xi3_error_app)
            xi4_error_app.append(xi4_error)
            print('xi4_error_app:', xi4_error_app)
            correct_prediction += 1
            
        else:
            print('PDE prediction not correct')
            
            
    print('correct_prediction:', correct_prediction)
    Accuracy = correct_prediction / len(numbers) * 100
    print('Accuracy:', Accuracy)
    xi1_error_avg = np.sum(xi1_error_app, axis = 0) / correct_prediction  
    print('xi1_error_avg:', xi1_error_avg)
    xi2_error_avg = np.sum(xi2_error_app, axis = 0) / correct_prediction 
    print('xi2_error_avg:', xi2_error_avg)
    xi3_error_avg = np.sum(xi3_error_app, axis = 0) / correct_prediction  
    print('xi3_error_avg:', xi3_error_avg)
    xi4_error_avg = np.sum(xi4_error_app, axis = 0) / correct_prediction 
    print('xi4_error_avg:', xi4_error_avg)
    f1.write(str(xi1_error_avg) + " " + str(xi2_error_avg) + " " + str(xi3_error_avg) + " " + str(xi4_error_avg) +  "\n")
    xi_updated = np.sum(xi_update_app, axis = 0) / correct_prediction  
    print('xi_updated:', xi_updated)
    f2.write(str(xi_updated[1]) + " " + str(xi_updated[2]) + " " + str(xi_updated[3]) + " " + str(xi_updated[4]) +  "\n")
    print('Finished')
    return xi_updated

# %%
xi_updated = model_identification(X, y, mask, poly_order=1, deriv_order=2)
# Out:
# seed: 0
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.4875, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0668, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0026, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0024, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0024, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0023, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0023, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 3.21370997e-02]
#  [ 4.13826704e-01]
#  [ 6.75131440e-01]
#  [ 3.56611818e-01]
#  [ 2.32735157e-01]
#  [ 1.08428241e-03]
#  [-9.56754237e-02]
#  [-4.34419885e-02]
#  [ 6.14619702e-02]
#  [ 4.01919298e-02]
#  [ 8.32164809e-02]
#  [-3.28383350e-04]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.27422726]
#  [0.45448723]
#  [0.42485797]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.27422726]
#  [0.45448723]
#  [0.42485797]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# PDE prediction not correct
# seed: 5
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0025, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0053, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0023, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0023, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0023, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0023, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0023, grad_fn=<AddBackward0>)
# loss: 7000 tensor(0.0022, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.01220794]
#  [ 0.31357476]
#  [ 0.69292915]
#  [ 0.3054646 ]
#  [ 0.35653943]
#  [ 0.00569319]
#  [-0.03914177]
#  [ 0.04473797]
#  [ 0.01874213]
#  [ 0.0806236 ]
#  [-0.05044486]
#  [ 0.00758676]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.22260913]
#  [0.49484736]
#  [0.41158184]
#  [0.48506388]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.22260913]
#  [0.49484736]
#  [0.41158184]
#  [0.48506388]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.22260913] [0.49484736] [0.41158184] [0.48506388]
# xi1_error [0.02739087]
# xi2_error [0.00515264]
# xi3_error [0.08841816]
# xi4_error [0.01493612]
# xi1_error_app: [array([0.02739087])]
# xi2_error_app: [array([0.00515264])]
# xi3_error_app: [array([0.08841816])]
# xi4_error_app: [array([0.01493612])]
# seed: 26
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0023, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0083, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0020, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0020, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0020, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[-0.00584441]
#  [ 0.25512877]
#  [ 0.54196852]
#  [ 0.33261627]
#  [ 0.30691057]
#  [ 0.00445251]
#  [-0.04759791]
#  [ 0.09393331]
#  [ 0.07444929]
#  [ 0.08131246]
#  [-0.00554695]
#  [ 0.00796746]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.19422179]
#  [0.42925674]
#  [0.43205339]
#  [0.4117083 ]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.19422179]
#  [0.42925674]
#  [0.43205339]
#  [0.4117083 ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.19422179] [0.42925674] [0.43205339] [0.4117083]
# xi1_error [0.05577821]
# xi2_error [0.07074326]
# xi3_error [0.06794661]
# xi4_error [0.0882917]
# xi1_error_app: [array([0.02739087]), array([0.05577821])]
# xi2_error_app: [array([0.00515264]), array([0.07074326])]
# xi3_error_app: [array([0.08841816]), array([0.06794661])]
# xi4_error_app: [array([0.01493612]), array([0.0882917])]
# seed: 57
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0027, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0055, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0023, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.02002445]
#  [ 0.34074599]
#  [ 0.66465628]
#  [ 0.3669112 ]
#  [ 0.34026363]
#  [-0.01659108]
#  [-0.02991525]
#  [ 0.00600016]
#  [-0.02036002]
#  [ 0.02712965]
#  [-0.01388271]
#  [ 0.04347996]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.2504063 ]
#  [0.50629544]
#  [0.48402739]
#  [0.4700481 ]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.2504063 ]
#  [0.50629544]
#  [0.48402739]
#  [0.4700481 ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.2504063] [0.50629544] [0.48402739] [0.4700481]
# xi1_error [-0.0004063]
# xi2_error [-0.00629544]
# xi3_error [0.01597261]
# xi4_error [0.0299519]
# xi1_error_app: [array([0.02739087]), array([0.05577821]), array([-0.0004063])]
# xi2_error_app: [array([0.00515264]), array([0.07074326]), array([-0.00629544])]
# xi3_error_app: [array([0.08841816]), array([0.06794661]), array([0.01597261])]
# xi4_error_app: [array([0.01493612]), array([0.0882917]), array([0.0299519])]
# seed: 73
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0025, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0030, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0022, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.02327263]
#  [ 0.33480081]
#  [ 0.64143491]
#  [ 0.41560704]
#  [ 0.35532117]
#  [-0.00863734]
#  [-0.03548846]
#  [ 0.00914962]
#  [ 0.04851385]
#  [-0.02534636]
#  [ 0.06281485]
#  [ 0.0258672 ]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.24397276]
#  [0.46717039]
#  [0.47343516]
#  [0.43170062]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.24397276]
#  [0.46717039]
#  [0.47343516]
#  [0.43170062]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.24397276] [0.46717039] [0.47343516] [0.43170062]
# xi1_error [0.00602724]
# xi2_error [0.03282961]
# xi3_error [0.02656484]
# xi4_error [0.06829938]
# xi1_error_app: [array([0.02739087]), array([0.05577821]), array([-0.0004063]), array([0.00602724])]
# xi2_error_app: [array([0.00515264]), array([0.07074326]), array([-0.00629544]), array([0.03282961])]
# xi3_error_app: [array([0.08841816]), array([0.06794661]), array([0.01597261]), array([0.02656484])]
# xi4_error_app: [array([0.01493612]), array([0.0882917]), array([0.0299519]), array([0.06829938])]
# seed: 80
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0025, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0045, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0023, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0023, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 1.33838961e-02]
#  [ 3.46575111e-01]
#  [ 5.98547935e-01]
#  [ 3.98842514e-01]
#  [ 2.91472226e-01]
#  [ 6.10708585e-03]
#  [-6.15915731e-02]
#  [-5.78549982e-04]
#  [ 6.90291151e-02]
#  [-5.39085753e-02]
#  [ 9.95255187e-02]
#  [-1.63777240e-05]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.25798079]
#  [0.45597547]
#  [0.49372503]
#  [0.36410972]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.25798079]
#  [0.45597547]
#  [0.49372503]
#  [0.36410972]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.25798079] [0.45597547] [0.49372503] [0.36410972]
# xi1_error [-0.00798079]
# xi2_error [0.04402453]
# xi3_error [0.00627497]
# xi4_error [0.13589028]
# xi1_error_app: [array([0.02739087]), array([0.05577821]), array([-0.0004063]), array([0.00602724]), array([-0.00798079])]
# xi2_error_app: [array([0.00515264]), array([0.07074326]), array([-0.00629544]), array([0.03282961]), array([0.04402453])]
# xi3_error_app: [array([0.08841816]), array([0.06794661]), array([0.01597261]), array([0.02656484]), array([0.00627497])]
# xi4_error_app: [array([0.01493612]), array([0.0882917]), array([0.0299519]), array([0.06829938]), array([0.13589028])]
# seed: 95
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0026, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0046, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0023, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.02504455]
#  [ 0.35826492]
#  [ 0.72502518]
#  [ 0.33198574]
#  [ 0.28958932]
#  [-0.02035926]
#  [-0.04853478]
#  [-0.00114705]
#  [-0.00986299]
#  [ 0.01803998]
#  [ 0.07193475]
#  [ 0.01528247]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.25784779]
#  [0.50343448]
#  [0.4292877 ]
#  [0.37974083]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.25784779]
#  [0.50343448]
#  [0.4292877 ]
#  [0.37974083]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.25784779] [0.50343448] [0.4292877] [0.37974083]
# xi1_error [-0.00784779]
# xi2_error [-0.00343448]
# xi3_error [0.0707123]
# xi4_error [0.12025917]
# xi1_error_app: [array([0.02739087]), array([0.05577821]), array([-0.0004063]), array([0.00602724]), array([-0.00798079]), array([-0.00784779])]
# xi2_error_app: [array([0.00515264]), array([0.07074326]), array([-0.00629544]), array([0.03282961]), array([0.04402453]), array([-0.00343448])]
# xi3_error_app: [array([0.08841816]), array([0.06794661]), array([0.01597261]), array([0.02656484]), array([0.00627497]), array([0.0707123])]
# xi4_error_app: [array([0.01493612]), array([0.0882917]), array([0.0299519]), array([0.06829938]), array([0.13589028]), array([0.12025917])]
# seed: 104
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0025, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0035, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0022, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.03014895]
#  [ 0.30460876]
#  [ 0.52271259]
#  [ 0.34420168]
#  [ 0.2362197 ]
#  [-0.0021309 ]
#  [-0.10264897]
#  [ 0.04178273]
#  [ 0.1351267 ]
#  [-0.01674037]
#  [ 0.10667023]
#  [-0.00423128]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.21247478]
#  [ 0.40157428]
#  [ 0.43820608]
#  [-0.02146363]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.21247478]
#  [ 0.40157428]
#  [ 0.43820608]
#  [ 0.        ]
#  [ 0.        ]
#  [-0.02146363]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# PDE prediction not correct
# seed: 129
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0025, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0056, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0023, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 5.60181998e-02]
#  [ 3.30476284e-01]
#  [ 6.97231591e-01]
#  [ 3.23507339e-01]
#  [ 3.16928387e-01]
#  [ 3.68817784e-02]
#  [-6.27478138e-02]
#  [ 1.05056269e-02]
#  [-1.65533173e-04]
#  [ 9.53162462e-02]
#  [ 2.21687481e-02]
#  [-5.19266501e-02]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.23870847]
#  [0.5004403 ]
#  [0.39226428]
#  [0.39165273]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.23870847]
#  [0.5004403 ]
#  [0.39226428]
#  [0.39165273]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.23870847] [0.5004403] [0.39226428] [0.39165273]
# xi1_error [0.01129153]
# xi2_error [-0.0004403]
# xi3_error [0.10773572]
# xi4_error [0.10834727]
# xi1_error_app: [array([0.02739087]), array([0.05577821]), array([-0.0004063]), array([0.00602724]), array([-0.00798079]), array([-0.00784779]), array([0.01129153])]
# xi2_error_app: [array([0.00515264]), array([0.07074326]), array([-0.00629544]), array([0.03282961]), array([0.04402453]), array([-0.00343448]), array([-0.0004403])]
# xi3_error_app: [array([0.08841816]), array([0.06794661]), array([0.01597261]), array([0.02656484]), array([0.00627497]), array([0.0707123]), array([0.10773572])]
# xi4_error_app: [array([0.01493612]), array([0.0882917]), array([0.0299519]), array([0.06829938]), array([0.13589028]), array([0.12025917]), array([0.10834727])]
# seed: 151
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0029, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0038, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0025, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.01294589]
#  [ 0.34878272]
#  [ 0.69879997]
#  [ 0.45728001]
#  [ 0.41960174]
#  [-0.02993857]
#  [ 0.0230577 ]
#  [-0.02319696]
#  [-0.03183222]
#  [-0.05289058]
#  [ 0.01089253]
#  [ 0.00532255]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.26058248]
#  [0.53247041]
#  [0.53955525]
#  [0.51439756]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.26058248]
#  [0.53247041]
#  [0.53955525]
#  [0.51439756]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.26058248] [0.53247041] [0.53955525] [0.51439756]
# xi1_error [-0.01058248]
# xi2_error [-0.03247041]
# xi3_error [-0.03955525]
# xi4_error [-0.01439756]
# xi1_error_app: [array([0.02739087]), array([0.05577821]), array([-0.0004063]), array([0.00602724]), array([-0.00798079]), array([-0.00784779]), array([0.01129153]), array([-0.01058248])]
# xi2_error_app: [array([0.00515264]), array([0.07074326]), array([-0.00629544]), array([0.03282961]), array([0.04402453]), array([-0.00343448]), array([-0.0004403]), array([-0.03247041])]
# xi3_error_app: [array([0.08841816]), array([0.06794661]), array([0.01597261]), array([0.02656484]), array([0.00627497]), array([0.0707123]), array([0.10773572]), array([-0.03955525])]
# xi4_error_app: [array([0.01493612]), array([0.0882917]), array([0.0299519]), array([0.06829938]), array([0.13589028]), array([0.12025917]), array([0.10834727]), array([-0.01439756])]
# correct_prediction: 8
# Accuracy: 80.0
# xi1_error_avg: [0.00920881]
# xi2_error_avg: [0.01376368]
# xi3_error_avg: [0.04300874]
# xi4_error_avg: [0.06894728]
# xi_updated: [[0.        ]
#  [0.24079119]
#  [0.48623632]
#  [0.45699126]
#  [0.43105272]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# Finished

# %%
pde_Recover(xi_updated, library_coeffs, equation_form='u_t')
end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))
# Out:
# Burger equation:
# u_t = 0.2408u_{x} + 0.4862u_{y} + 0.4570u_{xx} + 0.4311u_{yy}
# Duration: 0:13:45.757950
