# %% [markdown]
# # 2D Advection-Diffusion Equation
#
# $$u_t = 0.25u_{x} + 0.5 u_{y} + 0.5u_{xx} + 0.5 u_{yy}$$

# %%
import os
import numpy as np
import pandas as pd 
import scipy.io as sio
import matplotlib.pyplot as plt
import torch
import tensorflow as tf

from torch.autograd import grad
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ExponentialLR

from pdefind import *
from Model_Identification.PDE_Equation import pde_matrix_mul, sparse_coeff, normalized_xi_threshold, pde_Recover
from Model_Identification.build_Library import construct_Dictonary_2D
from datetime import datetime
import numba.cuda

# %%
start_time = datetime.now()

# Prepare dataset
data = sio.loadmat(os.path.join(os.getcwd(), "../data", "Advection_diffusion.mat"))
usol = np.real(data['Expression1'])
print('u.shape', usol.shape)
usol= usol.reshape((51,51,61,4))
#u = data["usol"]
x = usol[:,:,:,0]
y = usol[:,:,:,1]
t = usol[:,:,:,2]
u = usol[:,:,:,3]
print('u.shape', u.shape)
print('x.shape', x.shape)
print('t.shape', t.shape)
print('y.shape', y.shape)
print(x[:,:,10].shape)
# Out:
# u.shape (634644, 1)
# u.shape (51, 51, 61)
# x.shape (51, 51, 61)
# t.shape (51, 51, 61)
# y.shape (51, 51, 61)
# (51, 51)

# %%
fig, ax = plt.subplots()

im = ax.contourf(x[:,:,10], y[:,:,10], u[:,:,10], cmap='seismic')
ax.set_xlabel('x')
ax.set_ylabel('y')

fig.colorbar(mappable=im)

plt.show()

# %%
X = np.transpose((t.flatten(),x.flatten(), y.flatten()))
Y = u.reshape((u.size, 1))
print(X.shape, Y.shape)
print('X:', X)
# Out:
# (158661, 3) (158661, 1)
# X: [[ 3.  -5.  -5. ]
#  [ 3.1 -5.  -5. ]
#  [ 3.2 -5.  -5. ]
#  ...
#  [ 8.8  5.   5. ]
#  [ 8.9  5.   5. ]
#  [ 9.   5.   5. ]]

# %%
# Add noise
np.random.seed(0)
noise_level = 0.1
y = Y + noise_level * np.std(Y) * np.random.randn(Y.size, 1)

# %%
# Setup Network
net = PINN(sizes=[3,20,20,1], activation=torch.nn.Tanh())
print(net)
# Out:
# PINN(
#   (net): Sequential(
#     (0): Linear(in_features=3, out_features=20, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=20, out_features=1, bias=True)
#   )
# )

# %%
polynm = ['1', 'u']
spa_der = ['1', 'u_{x}', 'u_{y}','u_{xx}', 'u_{yy}','u_{xy}']
library_coeffs = pde_matrix_mul(polynm, spa_der)
print('library_coeffs:', library_coeffs)

tot_items = len(library_coeffs)
print('tot_items:', tot_items)

mask = torch.ones(tot_items, 1)
epochs = 10000
xi = nn.Parameter(torch.randn((tot_items, 1), requires_grad=True, device="cpu", dtype=torch.float32))
#params = [{'params': net.parameters(), 'lr': 3e-3}, {'params': xi, 'lr': 3e-2}]
params = [{'params': net.parameters(), 'lr': 1e-3}, {'params': xi, 'lr': 1e-2}]

optimizer = Adam(params)
scheduler = ExponentialLR(optimizer, .9998)
# Out:
# library_coeffs: ['1', 'u_{x}', 'u_{y}', 'u_{xx}', 'u_{yy}', 'u_{xy}', 'u', 'uu_{x}', 'uu_{y}', 'uu_{xx}', 'uu_{yy}', 'uu_{xy}']
# tot_items: 12

# %%
def model_identification(features, label, mask, poly_order, deriv_order):
    
    xi1 = []
    xi2 = []
    xi3 = []
    xi4 = []
    xi1_error_app = []
    xi2_error_app = []
    xi3_error_app = []
    xi4_error_app = []
    xi_update_app = []
    
    numbers = [0, 5, 26, 57, 73, 80, 95, 104, 129, 151]
    
    #f1 = open("Results/Average_errors.txt", "a+", encoding="utf-8")
    #f2 = open("Results/Average_xi.txt", "a+", encoding="utf-8")

    correct_prediction = 0
    # Using for loop
    for i in numbers:
        np.random.seed(i)
        print('seed:', i)
        idxs = np.random.choice(y.size, 2000, replace=False)
        X_train = torch.tensor(features[idxs], dtype=torch.float32, requires_grad=True)
        y_train = torch.tensor(label[idxs], dtype=torch.float32)
    
        lamb   = 0
        tolerance = 1e-6
        mask = torch.ones(tot_items, 1)
        #print('xi', xi)
        print('mask:', mask.shape)
        lambd  = 1e-6
    
        for epoch in range(epochs):
            optimizer.zero_grad()
            uhat = net(X_train)
    
            if epoch == 1000:
                lamb = 1
               
            dudt, theta = construct_Dictonary_2D(X_train, uhat, poly_order=1, deriv_order=2)
            #print('dudt:', dudt.shape)
            dudt_norm = torch.norm(dudt, dim=0)
    
            theta_scaling = (torch.norm(theta, dim=0))
            #Returns a new tensor with a dimension of size one inserted at the specified position. from 9 it will be 9,1
            theta_norm = torch.unsqueeze(theta_scaling, dim = 1) 
            xi_normalized = xi * (theta_norm / dudt_norm) 
            L1 = lambd * torch.sum(torch.abs(xi_normalized[1:, :]))
        
            l_u   = nn.MSELoss()(uhat, y_train)
            l_reg = lamb * torch.mean((dudt - theta @ xi)**2)
            #l_reg = torch.mean((dudt - theta @ xi)**2)

            loss = l_u + l_reg + L1

            gradient_loss = torch.max(torch.abs(grad(outputs=loss, inputs=xi, 
                  grad_outputs=torch.ones_like(loss), create_graph=True)[0]) / (theta_norm / dudt_norm))


            loss.backward(retain_graph=True)
            optimizer.step()
        
            if epoch % 1000 == 0:
                print('loss:', epoch, loss)
                if gradient_loss < tolerance:
                    print('Optimizer converged.')
                    break
 
        xi_list = sparse_coeff(mask, xi.detach().numpy())
        xi_normalized = sparse_coeff(mask, xi_normalized.detach().numpy())
        print('xi_normalized:', xi_normalized)
    

        sparsity = normalized_xi_threshold( xi_normalized, mode='auto')
        print('sparsity:', sparsity)
    
        xi_thresholded = np.expand_dims(xi_list[sparsity], axis=1) 
        print('xi_thresholded:', xi_thresholded)
        
        print('Coefficient xi:')
        xi_update = sparse_coeff(sparsity, xi_thresholded)
        print('xi_update:', xi_update)
        
    
        # Calculate Error in xi    
        if xi_update[1] != 0 and xi_update[2] != 0 and xi_update[3] != 0 and xi_update[4] != 0 and len(xi_thresholded) < 5:
            xi_update_app.append(xi_update)
            #print('xi_update_app:', xi_update_app)
            print('xi_update:', xi_update[1], xi_update[2], xi_update[3], xi_update[4])
            error_1 = np.subtract(np.array([0.25000]),xi_update[1])
            xi1_error = np.append(xi1, error_1)
            print('xi1_error', xi1_error)
            error_2 = np.subtract(np.array([0.50000]),xi_update[2])
            xi2_error = np.append(xi2, error_2)
            print('xi2_error', xi2_error)
            error_3 = np.subtract(np.array([0.50000]),xi_update[3])
            xi3_error = np.append(xi3, error_3)
            print('xi3_error', xi3_error)
            error_4 = np.subtract(np.array([0.50000]),xi_update[4])
            xi4_error = np.append(xi4, error_4)
            print('xi4_error', xi4_error)
            xi1_error_app.append(xi1_error)
            print('xi1_error_app:', xi1_error_app)
            xi2_error_app.append(xi2_error)
            print('xi2_error_app:', xi2_error_app)
            xi3_error_app.append(xi3_error)
            print('xi3_error_app:', xi3_error_app)
            xi4_error_app.append(xi4_error)
            print('xi4_error_app:', xi4_error_app)
            correct_prediction += 1
            
        else:
            print('PDE prediction not correct')
            
            
    print('correct_prediction:', correct_prediction)
    Accuracy = correct_prediction / len(numbers) * 100
    print('Accuracy:', Accuracy)
    xi1_error_avg = np.sum(xi1_error_app, axis = 0) / correct_prediction  
    print('xi1_error_avg:', xi1_error_avg)
    xi2_error_avg = np.sum(xi2_error_app, axis = 0) / correct_prediction 
    print('xi2_error_avg:', xi2_error_avg)
    xi3_error_avg = np.sum(xi3_error_app, axis = 0) / correct_prediction  
    print('xi3_error_avg:', xi3_error_avg)
    xi4_error_avg = np.sum(xi4_error_app, axis = 0) / correct_prediction 
    print('xi4_error_avg:', xi4_error_avg)
    #f1.write(str(xi1_error_avg) + " " + str(xi2_error_avg) + " " + str(xi3_error_avg) + " " + str(xi4_error_avg) +  "\n")
    xi_updated = np.sum(xi_update_app, axis = 0) / correct_prediction  
    print('xi_updated:', xi_updated)
    #f2.write(str(xi_updated[1]) + " " + str(xi_updated[2]) + " " + str(xi_updated[3]) + " " + str(xi_updated[4]) +  "\n")
    print('Finished')
    return xi_updated

# %%
xi_updated = model_identification(X, y, mask, poly_order=1, deriv_order=2)
# Out:
# seed: 0
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.6808, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0201, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0039, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0032, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0028, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.12445503]
#  [ 0.34737471]
#  [ 0.61005896]
#  [ 0.28081274]
#  [ 0.1389568 ]
#  [-0.06671858]
#  [-0.30840045]
#  [ 0.04500137]
#  [ 0.08520701]
#  [-0.04530661]
#  [ 0.09690045]
#  [ 0.0591861 ]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.23174627]
#  [ 0.42828003]
#  [-0.06014883]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.23174627]
#  [ 0.42828003]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [-0.06014883]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# PDE prediction not correct
# seed: 5
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0027, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0060, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0025, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0024, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0024, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0023, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0023, grad_fn=<AddBackward0>)
# loss: 7000 tensor(0.0023, grad_fn=<AddBackward0>)
# loss: 8000 tensor(0.0023, grad_fn=<AddBackward0>)
# loss: 9000 tensor(0.0023, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 4.22907583e-02]
#  [ 3.76460195e-01]
#  [ 6.80753171e-01]
#  [ 3.40841502e-01]
#  [ 2.91677833e-01]
#  [-6.44847343e-04]
#  [-6.95441067e-02]
#  [-1.57829206e-02]
#  [ 2.45495290e-02]
#  [ 1.90330707e-02]
#  [ 4.30956371e-02]
#  [ 9.98408347e-03]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.26030645]
#  [0.47632825]
#  [0.44254357]
#  [0.38707846]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.26030645]
#  [0.47632825]
#  [0.44254357]
#  [0.38707846]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.26030645] [0.47632825] [0.44254357] [0.38707846]
# xi1_error [-0.01030645]
# xi2_error [0.02367175]
# xi3_error [0.05745643]
# xi4_error [0.11292154]
# xi1_error_app: [array([-0.01030645])]
# xi2_error_app: [array([0.02367175])]
# xi3_error_app: [array([0.05745643])]
# xi4_error_app: [array([0.11292154])]
# seed: 26
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0023, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0092, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0022, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.02220363]
#  [ 0.3005617 ]
#  [ 0.60399866]
#  [ 0.32121736]
#  [ 0.31976864]
#  [-0.02041815]
#  [-0.06148961]
#  [ 0.05492459]
#  [ 0.04377025]
#  [ 0.04483877]
#  [ 0.02157407]
#  [ 0.02469119]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.22139524]
#  [0.46341053]
#  [0.41212919]
#  [0.41767108]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.22139524]
#  [0.46341053]
#  [0.41212919]
#  [0.41767108]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.22139524] [0.46341053] [0.41212919] [0.41767108]
# xi1_error [0.02860476]
# xi2_error [0.03658947]
# xi3_error [0.08787081]
# xi4_error [0.08232892]
# xi1_error_app: [array([-0.01030645]), array([0.02860476])]
# xi2_error_app: [array([0.02367175]), array([0.03658947])]
# xi3_error_app: [array([0.05745643]), array([0.08787081])]
# xi4_error_app: [array([0.11292154]), array([0.08232892])]
# seed: 57
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0025, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0034, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0023, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0023, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.04780415]
#  [ 0.35089615]
#  [ 0.61441153]
#  [ 0.37593234]
#  [ 0.29501009]
#  [ 0.00184758]
#  [-0.08744418]
#  [-0.01450922]
#  [ 0.04969113]
#  [-0.01952769]
#  [ 0.03541219]
#  [ 0.0013046 ]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.26227632]
#  [0.46111861]
#  [0.4814643 ]
#  [0.3849991 ]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.26227632]
#  [0.46111861]
#  [0.4814643 ]
#  [0.3849991 ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.26227632] [0.46111861] [0.4814643] [0.3849991]
# xi1_error [-0.01227632]
# xi2_error [0.03888139]
# xi3_error [0.0185357]
# xi4_error [0.1150009]
# xi1_error_app: [array([-0.01030645]), array([0.02860476]), array([-0.01227632])]
# xi2_error_app: [array([0.02367175]), array([0.03658947]), array([0.03888139])]
# xi3_error_app: [array([0.05745643]), array([0.08787081]), array([0.0185357])]
# xi4_error_app: [array([0.11292154]), array([0.08232892]), array([0.1150009])]
# seed: 73
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0025, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0049, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0024, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0023, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.03149815]
#  [ 0.37291604]
#  [ 0.62076175]
#  [ 0.42049113]
#  [ 0.32161391]
#  [-0.00508015]
#  [-0.0428219 ]
#  [-0.01206488]
#  [ 0.05960707]
#  [-0.07601786]
#  [ 0.10674819]
#  [ 0.01382905]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.26423392]
#  [0.46311778]
#  [0.51319152]
#  [0.39555213]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.26423392]
#  [0.46311778]
#  [0.51319152]
#  [0.39555213]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.26423392] [0.46311778] [0.51319152] [0.39555213]
# xi1_error [-0.01423392]
# xi2_error [0.03688222]
# xi3_error [-0.01319152]
# xi4_error [0.10444787]
# xi1_error_app: [array([-0.01030645]), array([0.02860476]), array([-0.01227632]), array([-0.01423392])]
# xi2_error_app: [array([0.02367175]), array([0.03658947]), array([0.03888139]), array([0.03688222])]
# xi3_error_app: [array([0.05745643]), array([0.08787081]), array([0.0185357]), array([-0.01319152])]
# xi4_error_app: [array([0.11292154]), array([0.08232892]), array([0.1150009]), array([0.10444787])]
# seed: 80
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0025, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0045, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0024, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0024, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0024, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.0236392 ]
#  [ 0.35058746]
#  [ 0.63871646]
#  [ 0.38726938]
#  [ 0.31055346]
#  [-0.01104169]
#  [-0.07077632]
#  [ 0.00663965]
#  [ 0.03729247]
#  [-0.02465862]
#  [ 0.05556919]
#  [ 0.01440803]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.24807732]
#  [0.47070631]
#  [0.48331004]
#  [0.38919219]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.24807732]
#  [0.47070631]
#  [0.48331004]
#  [0.38919219]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.24807732] [0.47070631] [0.48331004] [0.38919219]
# xi1_error [0.00192268]
# xi2_error [0.02929369]
# xi3_error [0.01668996]
# xi4_error [0.11080781]
# xi1_error_app: [array([-0.01030645]), array([0.02860476]), array([-0.01227632]), array([-0.01423392]), array([0.00192268])]
# xi2_error_app: [array([0.02367175]), array([0.03658947]), array([0.03888139]), array([0.03688222]), array([0.02929369])]
# xi3_error_app: [array([0.05745643]), array([0.08787081]), array([0.0185357]), array([-0.01319152]), array([0.01668996])]
# xi4_error_app: [array([0.11292154]), array([0.08232892]), array([0.1150009]), array([0.10444787]), array([0.11080781])]
# seed: 95
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0026, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0062, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0024, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.02003487]
#  [ 0.31163338]
#  [ 0.67541301]
#  [ 0.32240394]
#  [ 0.32413074]
#  [-0.02442385]
#  [-0.05534562]
#  [ 0.02665023]
#  [ 0.012358  ]
#  [ 0.0591017 ]
#  [ 0.01723033]
#  [ 0.02190721]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.22785132]
#  [0.48776504]
#  [0.40731719]
#  [0.4239918 ]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.22785132]
#  [0.48776504]
#  [0.40731719]
#  [0.4239918 ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.22785132] [0.48776504] [0.40731719] [0.4239918]
# xi1_error [0.02214868]
# xi2_error [0.01223496]
# xi3_error [0.09268281]
# xi4_error [0.0760082]
# xi1_error_app: [array([-0.01030645]), array([0.02860476]), array([-0.01227632]), array([-0.01423392]), array([0.00192268]), array([0.02214868])]
# xi2_error_app: [array([0.02367175]), array([0.03658947]), array([0.03888139]), array([0.03688222]), array([0.02929369]), array([0.01223496])]
# xi3_error_app: [array([0.05745643]), array([0.08787081]), array([0.0185357]), array([-0.01319152]), array([0.01668996]), array([0.09268281])]
# xi4_error_app: [array([0.11292154]), array([0.08232892]), array([0.1150009]), array([0.10444787]), array([0.11080781]), array([0.0760082])]
# seed: 104
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0025, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0035, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0024, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0024, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.02890095]
#  [ 0.36275181]
#  [ 0.58613175]
#  [ 0.35406989]
#  [ 0.29047048]
#  [ 0.00737831]
#  [-0.05778586]
#  [-0.00846615]
#  [ 0.0740085 ]
#  [ 0.00385862]
#  [ 0.07704674]
#  [-0.00800495]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.25548831]
#  [0.45015582]
#  [0.45533755]
#  [0.35818312]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.25548831]
#  [0.45015582]
#  [0.45533755]
#  [0.35818312]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.25548831] [0.45015582] [0.45533755] [0.35818312]
# xi1_error [-0.00548831]
# xi2_error [0.04984418]
# xi3_error [0.04466245]
# xi4_error [0.14181688]
# xi1_error_app: [array([-0.01030645]), array([0.02860476]), array([-0.01227632]), array([-0.01423392]), array([0.00192268]), array([0.02214868]), array([-0.00548831])]
# xi2_error_app: [array([0.02367175]), array([0.03658947]), array([0.03888139]), array([0.03688222]), array([0.02929369]), array([0.01223496]), array([0.04984418])]
# xi3_error_app: [array([0.05745643]), array([0.08787081]), array([0.0185357]), array([-0.01319152]), array([0.01668996]), array([0.09268281]), array([0.04466245])]
# xi4_error_app: [array([0.11292154]), array([0.08232892]), array([0.1150009]), array([0.10444787]), array([0.11080781]), array([0.0760082]), array([0.14181688])]
# seed: 129
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0025, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0059, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0024, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0024, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0024, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0024, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0024, grad_fn=<AddBackward0>)
# loss: 7000 tensor(0.0024, grad_fn=<AddBackward0>)
# loss: 8000 tensor(0.0024, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.04716524]
#  [ 0.30680788]
#  [ 0.74831778]
#  [ 0.36086997]
#  [ 0.35506532]
#  [ 0.02025007]
#  [-0.03578508]
#  [ 0.03257939]
#  [-0.02776632]
#  [ 0.04427056]
#  [ 0.02000163]
#  [-0.03130953]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.21817881]
#  [0.52744979]
#  [0.44202802]
#  [0.44493935]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.21817881]
#  [0.52744979]
#  [0.44202802]
#  [0.44493935]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.21817881] [0.52744979] [0.44202802] [0.44493935]
# xi1_error [0.03182119]
# xi2_error [-0.02744979]
# xi3_error [0.05797198]
# xi4_error [0.05506065]
# xi1_error_app: [array([-0.01030645]), array([0.02860476]), array([-0.01227632]), array([-0.01423392]), array([0.00192268]), array([0.02214868]), array([-0.00548831]), array([0.03182119])]
# xi2_error_app: [array([0.02367175]), array([0.03658947]), array([0.03888139]), array([0.03688222]), array([0.02929369]), array([0.01223496]), array([0.04984418]), array([-0.02744979])]
# xi3_error_app: [array([0.05745643]), array([0.08787081]), array([0.0185357]), array([-0.01319152]), array([0.01668996]), array([0.09268281]), array([0.04466245]), array([0.05797198])]
# xi4_error_app: [array([0.11292154]), array([0.08232892]), array([0.1150009]), array([0.10444787]), array([0.11080781]), array([0.0760082]), array([0.14181688]), array([0.05506065])]
# seed: 151
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0027, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0077, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0025, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.05078186]
#  [ 0.37608382]
#  [ 0.69707584]
#  [ 0.35750732]
#  [ 0.33091438]
#  [-0.02678465]
#  [-0.05112627]
#  [-0.01815072]
#  [-0.01101213]
#  [ 0.03350962]
#  [ 0.03185605]
#  [ 0.01036764]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.26433042]
#  [0.50376004]
#  [0.44437   ]
#  [0.41948831]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.26433042]
#  [0.50376004]
#  [0.44437   ]
#  [0.41948831]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.26433042] [0.50376004] [0.44437] [0.41948831]
# xi1_error [-0.01433042]
# xi2_error [-0.00376004]
# xi3_error [0.05563]
# xi4_error [0.08051169]
# xi1_error_app: [array([-0.01030645]), array([0.02860476]), array([-0.01227632]), array([-0.01423392]), array([0.00192268]), array([0.02214868]), array([-0.00548831]), array([0.03182119]), array([-0.01433042])]
# xi2_error_app: [array([0.02367175]), array([0.03658947]), array([0.03888139]), array([0.03688222]), array([0.02929369]), array([0.01223496]), array([0.04984418]), array([-0.02744979]), array([-0.00376004])]
# xi3_error_app: [array([0.05745643]), array([0.08787081]), array([0.0185357]), array([-0.01319152]), array([0.01668996]), array([0.09268281]), array([0.04466245]), array([0.05797198]), array([0.05563])]
# xi4_error_app: [array([0.11292154]), array([0.08232892]), array([0.1150009]), array([0.10444787]), array([0.11080781]), array([0.0760082]), array([0.14181688]), array([0.05506065]), array([0.08051169])]
# correct_prediction: 9
# Accuracy: 90.0
# xi1_error_avg: [0.00309577]
# xi2_error_avg: [0.02179865]
# xi3_error_avg: [0.04647874]
# xi4_error_avg: [0.09765605]
# xi_updated: [[0.        ]
#  [0.24690423]
#  [0.47820135]
#  [0.45352126]
#  [0.40234395]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# Finished

# %%
pde_Recover(xi_updated, library_coeffs, equation_form='u_t')
end_time = datetime.now()
print('end_time:', end_time)
print('Duration: {}'.format(end_time - start_time))
# Out:
# Burger equation:
# u_t = 0.247u_{x} + 0.478u_{y} + 0.454u_{xx} + 0.402u_{yy}
# end_time: 2020-05-18 18:43:09.965475
# Duration: 0:19:32.187086
