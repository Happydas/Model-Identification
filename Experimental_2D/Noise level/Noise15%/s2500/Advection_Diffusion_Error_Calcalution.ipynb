# %% [markdown]
# # 2D Advection-Diffusion Equation
#
# $$u_t = 0.25u_{x} + 0.5 u_{y} + 0.5u_{xx} + 0.5 u_{yy}$$

# %%
import os
import numpy as np
import pandas as pd 
import scipy.io as sio
import matplotlib.pyplot as plt
import torch
import tensorflow as tf

from torch.autograd import grad
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ExponentialLR

from pdefind import *
from Model_Identification.PDE_Equation import pde_matrix_mul, sparse_coeff, normalized_xi_threshold, pde_Recover
from Model_Identification.build_Library import construct_Dictonary_2D
from datetime import datetime
import numba.cuda

# %%
start_time = datetime.now()

# Prepare dataset
data = sio.loadmat(os.path.join(os.getcwd(), "../data", "Advection_diffusion.mat"))
usol = np.real(data['Expression1'])
print('u.shape', usol.shape)
usol= usol.reshape((51,51,61,4))
#u = data["usol"]
x = usol[:,:,:,0]
y = usol[:,:,:,1]
t = usol[:,:,:,2]
u = usol[:,:,:,3]
print('u.shape', u.shape)
print('x.shape', x.shape)
print('t.shape', t.shape)
print('y.shape', y.shape)
print(x[:,:,10].shape)
# Out:
# u.shape (634644, 1)
# u.shape (51, 51, 61)
# x.shape (51, 51, 61)
# t.shape (51, 51, 61)
# y.shape (51, 51, 61)
# (51, 51)

# %%
fig, ax = plt.subplots()

im = ax.contourf(x[:,:,10], y[:,:,10], u[:,:,10], cmap='seismic')
ax.set_xlabel('x')
ax.set_ylabel('y')

fig.colorbar(mappable=im)

plt.show()

# %%
X = np.transpose((t.flatten(),x.flatten(), y.flatten()))
Y = u.reshape((u.size, 1))
print(X.shape, Y.shape)
print('X:', X)
# Out:
# (158661, 3) (158661, 1)
# X: [[ 3.  -5.  -5. ]
#  [ 3.1 -5.  -5. ]
#  [ 3.2 -5.  -5. ]
#  ...
#  [ 8.8  5.   5. ]
#  [ 8.9  5.   5. ]
#  [ 9.   5.   5. ]]

# %%
# Add noise
np.random.seed(0)
noise_level = 0.15
y = Y + noise_level * np.std(Y) * np.random.randn(Y.size, 1)

# %%
# Setup Network
net = PINN(sizes=[3,20,20,20,20,20,1], activation=torch.nn.Tanh())
print(net)
# Out:
# PINN(
#   (net): Sequential(
#     (0): Linear(in_features=3, out_features=20, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=20, out_features=20, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=20, out_features=20, bias=True)
#     (7): Tanh()
#     (8): Linear(in_features=20, out_features=20, bias=True)
#     (9): Tanh()
#     (10): Linear(in_features=20, out_features=1, bias=True)
#   )
# )

# %%
polynm = ['1', 'u']
spa_der = ['1', 'u_{x}', 'u_{y}','u_{xx}', 'u_{yy}','u_{xy}']
library_coeffs = pde_matrix_mul(polynm, spa_der)
print('library_coeffs:', library_coeffs)

tot_items = len(library_coeffs)
print('tot_items:', tot_items)

mask = torch.ones(tot_items, 1)
epochs = 10000
xi = nn.Parameter(torch.randn((tot_items, 1), requires_grad=True, device="cpu", dtype=torch.float32))
#params = [{'params': net.parameters(), 'lr': 3e-3}, {'params': xi, 'lr': 3e-2}]
params = [{'params': net.parameters(), 'lr': 1e-3}, {'params': xi, 'lr': 1e-2}]

optimizer = Adam(params)
scheduler = ExponentialLR(optimizer, .9998)
# Out:
# library_coeffs: ['1', 'u_{x}', 'u_{y}', 'u_{xx}', 'u_{yy}', 'u_{xy}', 'u', 'uu_{x}', 'uu_{y}', 'uu_{xx}', 'uu_{yy}', 'uu_{xy}']
# tot_items: 12

# %%
def model_identification(features, label, mask, poly_order, deriv_order):
    
    xi1 = []
    xi2 = []
    xi3 = []
    xi4 = []
    xi1_error_app = []
    xi2_error_app = []
    xi3_error_app = []
    xi4_error_app = []
    xi_update_app = []
    
    numbers = [0, 5, 26, 57, 73, 80, 95, 104, 129, 151]
    
    f1 = open("Results/Average_errors.txt", "a+", encoding="utf-8")
    f2 = open("Results/Average_xi.txt", "a+", encoding="utf-8")

    correct_prediction = 0
    # Using for loop
    for i in numbers:
        np.random.seed(i)
        print('seed:', i)
        idxs = np.random.choice(y.size, 2500, replace=False)
        X_train = torch.tensor(features[idxs], dtype=torch.float32, requires_grad=True)
        y_train = torch.tensor(label[idxs], dtype=torch.float32)
    
        lamb   = 0
        tolerance = 1e-6
        mask = torch.ones(tot_items, 1)
        #print('xi', xi)
        print('mask:', mask.shape)
        lambd  = 1e-6
    
        for epoch in range(epochs):
            optimizer.zero_grad()
            uhat = net(X_train)
    
            if epoch == 1000:
                lamb = 1
               
            dudt, theta = construct_Dictonary_2D(X_train, uhat, poly_order=1, deriv_order=2)
            #print('dudt:', dudt.shape)
            dudt_norm = torch.norm(dudt, dim=0)
    
            theta_scaling = (torch.norm(theta, dim=0))
            #Returns a new tensor with a dimension of size one inserted at the specified position. from 9 it will be 9,1
            theta_norm = torch.unsqueeze(theta_scaling, dim = 1) 
            xi_normalized = xi * (theta_norm / dudt_norm) 
            L1 = lambd * torch.sum(torch.abs(xi_normalized[1:, :]))
        
            l_u   = nn.MSELoss()(uhat, y_train)
            l_reg = lamb * torch.mean((dudt - theta @ xi)**2)
            #l_reg = torch.mean((dudt - theta @ xi)**2)

            loss = l_u + l_reg + L1

            gradient_loss = torch.max(torch.abs(grad(outputs=loss, inputs=xi, 
                  grad_outputs=torch.ones_like(loss), create_graph=True)[0]) / (theta_norm / dudt_norm))


            loss.backward(retain_graph=True)
            optimizer.step()
        
            if epoch % 1000 == 0:
                print('loss:', epoch, loss)
                if gradient_loss < tolerance:
                    print('Optimizer converged.')
                    break
 
        xi_list = sparse_coeff(mask, xi.detach().numpy())
        xi_normalized = sparse_coeff(mask, xi_normalized.detach().numpy())
        print('xi_normalized:', xi_normalized)
    

        sparsity = normalized_xi_threshold( xi_normalized, mode='auto')
        print('sparsity:', sparsity)
    
        xi_thresholded = np.expand_dims(xi_list[sparsity], axis=1) 
        print('xi_thresholded:', xi_thresholded)
        
        print('Coefficient xi:')
        xi_update = sparse_coeff(sparsity, xi_thresholded)
        print('xi_update:', xi_update)
        
    
        # Calculate Error in xi    
        if xi_update[1] != 0 and xi_update[2] != 0 and xi_update[3] != 0 and xi_update[4] != 0 and len(xi_thresholded) < 5:
            xi_update_app.append(xi_update)
            #print('xi_update_app:', xi_update_app)
            print('xi_update:', xi_update[1], xi_update[2], xi_update[3], xi_update[4])
            error_1 = np.subtract(np.array([0.25000]),xi_update[1])
            xi1_error = np.append(xi1, error_1)
            print('xi1_error', xi1_error)
            error_2 = np.subtract(np.array([0.50000]),xi_update[2])
            xi2_error = np.append(xi2, error_2)
            print('xi2_error', xi2_error)
            error_3 = np.subtract(np.array([0.50000]),xi_update[3])
            xi3_error = np.append(xi3, error_3)
            print('xi3_error', xi3_error)
            error_4 = np.subtract(np.array([0.50000]),xi_update[4])
            xi4_error = np.append(xi4, error_4)
            print('xi4_error', xi4_error)
            xi1_error_app.append(xi1_error)
            print('xi1_error_app:', xi1_error_app)
            xi2_error_app.append(xi2_error)
            print('xi2_error_app:', xi2_error_app)
            xi3_error_app.append(xi3_error)
            print('xi3_error_app:', xi3_error_app)
            xi4_error_app.append(xi4_error)
            print('xi4_error_app:', xi4_error_app)
            correct_prediction += 1
            
        else:
            print('PDE prediction not correct')
            
            
    print('correct_prediction:', correct_prediction)
    Accuracy = correct_prediction / len(numbers) * 100
    print('Accuracy:', Accuracy)
    xi1_error_avg = np.sum(xi1_error_app, axis = 0) / correct_prediction  
    print('xi1_error_avg:', xi1_error_avg)
    xi2_error_avg = np.sum(xi2_error_app, axis = 0) / correct_prediction 
    print('xi2_error_avg:', xi2_error_avg)
    xi3_error_avg = np.sum(xi3_error_app, axis = 0) / correct_prediction  
    print('xi3_error_avg:', xi3_error_avg)
    xi4_error_avg = np.sum(xi4_error_app, axis = 0) / correct_prediction 
    print('xi4_error_avg:', xi4_error_avg)
    f1.write(str(xi1_error_avg) + " " + str(xi2_error_avg) + " " + str(xi3_error_avg) + " " + str(xi4_error_avg) +  "\n")
    xi_updated = np.sum(xi_update_app, axis = 0) / correct_prediction  
    print('xi_updated:', xi_updated)
    f2.write(str(xi_updated[1]) + " " + str(xi_updated[2]) + " " + str(xi_updated[3]) + " " + str(xi_updated[4]) +  "\n")
    print('Finished')
    return xi_updated

# %%
xi_updated = model_identification(X, y, mask, poly_order=1, deriv_order=2)
# Out:
# seed: 0
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.4048, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.2541, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0058, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0055, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0064, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0053, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0053, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.02041876]
#  [ 0.3294667 ]
#  [ 0.67004901]
#  [ 0.35270777]
#  [ 0.34428117]
#  [-0.0403032 ]
#  [-0.05640092]
#  [ 0.00595977]
#  [-0.00331106]
#  [ 0.05397513]
#  [ 0.00220641]
#  [ 0.03263567]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.2368983 ]
#  [0.49596655]
#  [0.42853606]
#  [0.4417347 ]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.2368983 ]
#  [0.49596655]
#  [0.42853606]
#  [0.4417347 ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.2368983] [0.49596655] [0.42853606] [0.4417347]
# xi1_error [0.0131017]
# xi2_error [0.00403345]
# xi3_error [0.07146394]
# xi4_error [0.0582653]
# xi1_error_app: [array([0.0131017])]
# xi2_error_app: [array([0.00403345])]
# xi3_error_app: [array([0.07146394])]
# xi4_error_app: [array([0.0582653])]
# seed: 5
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0055, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0065, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0053, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.03624773]
#  [ 0.35733825]
#  [ 0.6762867 ]
#  [ 0.34282163]
#  [ 0.31975371]
#  [-0.00149863]
#  [-0.04589516]
#  [-0.00185526]
#  [ 0.03108841]
#  [ 0.03278951]
#  [ 0.01961918]
#  [ 0.01839873]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.24859011]
#  [0.4807882 ]
#  [0.43602031]
#  [0.42295456]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.24859011]
#  [0.4807882 ]
#  [0.43602031]
#  [0.42295456]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.24859011] [0.4807882] [0.43602031] [0.42295456]
# xi1_error [0.00140989]
# xi2_error [0.0192118]
# xi3_error [0.06397969]
# xi4_error [0.07704544]
# xi1_error_app: [array([0.0131017]), array([0.00140989])]
# xi2_error_app: [array([0.00403345]), array([0.0192118])]
# xi3_error_app: [array([0.07146394]), array([0.06397969])]
# xi4_error_app: [array([0.0582653]), array([0.07704544])]
# seed: 26
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0052, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0065, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0049, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0049, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0049, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0049, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0049, grad_fn=<AddBackward0>)
# loss: 7000 tensor(0.0049, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[-0.00161213]
#  [ 0.27807471]
#  [ 0.60201633]
#  [ 0.31408828]
#  [ 0.34797418]
#  [-0.03082326]
#  [-0.02191288]
#  [ 0.08002308]
#  [ 0.05429761]
#  [ 0.07560635]
#  [ 0.01737135]
#  [ 0.04734156]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.20325713]
#  [0.45809981]
#  [0.4004167 ]
#  [0.45635059]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.20325713]
#  [0.45809981]
#  [0.4004167 ]
#  [0.45635059]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.20325713] [0.45809981] [0.4004167] [0.45635059]
# xi1_error [0.04674287]
# xi2_error [0.04190019]
# xi3_error [0.0995833]
# xi4_error [0.04364941]
# xi1_error_app: [array([0.0131017]), array([0.00140989]), array([0.04674287])]
# xi2_error_app: [array([0.00403345]), array([0.0192118]), array([0.04190019])]
# xi3_error_app: [array([0.07146394]), array([0.06397969]), array([0.0995833])]
# xi4_error_app: [array([0.0582653]), array([0.07704544]), array([0.04364941])]
# seed: 57
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0055, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0109, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0052, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0052, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 3.19250934e-02]
#  [ 3.39858949e-01]
#  [ 6.04692400e-01]
#  [ 3.64731312e-01]
#  [ 3.10265034e-01]
#  [ 4.30964254e-04]
#  [-6.35264739e-02]
#  [-6.77611260e-03]
#  [ 5.57960793e-02]
#  [ 2.82625780e-02]
#  [ 1.88683514e-02]
#  [ 2.31234003e-02]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.25410682]
#  [0.4606767 ]
#  [0.46099788]
#  [0.40093926]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.25410682]
#  [0.4606767 ]
#  [0.46099788]
#  [0.40093926]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.25410682] [0.4606767] [0.46099788] [0.40093926]
# xi1_error [-0.00410682]
# xi2_error [0.0393233]
# xi3_error [0.03900212]
# xi4_error [0.09906074]
# xi1_error_app: [array([0.0131017]), array([0.00140989]), array([0.04674287]), array([-0.00410682])]
# xi2_error_app: [array([0.00403345]), array([0.0192118]), array([0.04190019]), array([0.0393233])]
# xi3_error_app: [array([0.07146394]), array([0.06397969]), array([0.0995833]), array([0.03900212])]
# xi4_error_app: [array([0.0582653]), array([0.07704544]), array([0.04364941]), array([0.09906074])]
# seed: 73
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0056, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0068, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0053, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.01310621]
#  [ 0.36288008]
#  [ 0.60417593]
#  [ 0.42803231]
#  [ 0.32683507]
#  [-0.00141042]
#  [-0.00792516]
#  [-0.00575142]
#  [ 0.07117989]
#  [-0.08279154]
#  [ 0.1043977 ]
#  [ 0.0204007 ]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.26367426]
#  [0.46057725]
#  [0.5393613 ]
#  [0.41536117]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.26367426]
#  [0.46057725]
#  [0.5393613 ]
#  [0.41536117]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.26367426] [0.46057725] [0.5393613] [0.41536117]
# xi1_error [-0.01367426]
# xi2_error [0.03942275]
# xi3_error [-0.0393613]
# xi4_error [0.08463883]
# xi1_error_app: [array([0.0131017]), array([0.00140989]), array([0.04674287]), array([-0.00410682]), array([-0.01367426])]
# xi2_error_app: [array([0.00403345]), array([0.0192118]), array([0.04190019]), array([0.0393233]), array([0.03942275])]
# xi3_error_app: [array([0.07146394]), array([0.06397969]), array([0.0995833]), array([0.03900212]), array([-0.0393613])]
# xi4_error_app: [array([0.0582653]), array([0.07704544]), array([0.04364941]), array([0.09906074]), array([0.08463883])]
# seed: 80
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0057, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0067, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0054, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.0162451 ]
#  [ 0.34569085]
#  [ 0.64228791]
#  [ 0.38695276]
#  [ 0.30153516]
#  [ 0.00273404]
#  [-0.06408783]
#  [ 0.00875003]
#  [ 0.05273975]
#  [-0.00932455]
#  [ 0.04874288]
#  [ 0.00245379]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.24452543]
#  [0.46683806]
#  [0.47684625]
#  [0.38014978]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.24452543]
#  [0.46683806]
#  [0.47684625]
#  [0.38014978]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.24452543] [0.46683806] [0.47684625] [0.38014978]
# xi1_error [0.00547457]
# xi2_error [0.03316194]
# xi3_error [0.02315375]
# xi4_error [0.11985022]
# xi1_error_app: [array([0.0131017]), array([0.00140989]), array([0.04674287]), array([-0.00410682]), array([-0.01367426]), array([0.00547457])]
# xi2_error_app: [array([0.00403345]), array([0.0192118]), array([0.04190019]), array([0.0393233]), array([0.03942275]), array([0.03316194])]
# xi3_error_app: [array([0.07146394]), array([0.06397969]), array([0.0995833]), array([0.03900212]), array([-0.0393613]), array([0.02315375])]
# xi4_error_app: [array([0.0582653]), array([0.07704544]), array([0.04364941]), array([0.09906074]), array([0.08463883]), array([0.11985022])]
# seed: 95
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0055, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0067, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0053, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.00618685]
#  [ 0.34654608]
#  [ 0.68183982]
#  [ 0.31758448]
#  [ 0.33659977]
#  [-0.01365334]
#  [-0.00901507]
#  [-0.0091376 ]
#  [ 0.02473844]
#  [ 0.08691178]
#  [ 0.02918379]
#  [ 0.00970822]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.24769893]
#  [0.48928979]
#  [0.39819878]
#  [0.44086641]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.24769893]
#  [0.48928979]
#  [0.39819878]
#  [0.44086641]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.24769893] [0.48928979] [0.39819878] [0.44086641]
# xi1_error [0.00230107]
# xi2_error [0.01071021]
# xi3_error [0.10180122]
# xi4_error [0.05913359]
# xi1_error_app: [array([0.0131017]), array([0.00140989]), array([0.04674287]), array([-0.00410682]), array([-0.01367426]), array([0.00547457]), array([0.00230107])]
# xi2_error_app: [array([0.00403345]), array([0.0192118]), array([0.04190019]), array([0.0393233]), array([0.03942275]), array([0.03316194]), array([0.01071021])]
# xi3_error_app: [array([0.07146394]), array([0.06397969]), array([0.0995833]), array([0.03900212]), array([-0.0393613]), array([0.02315375]), array([0.10180122])]
# xi4_error_app: [array([0.0582653]), array([0.07704544]), array([0.04364941]), array([0.09906074]), array([0.08463883]), array([0.11985022]), array([0.05913359])]
# seed: 104
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0055, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0068, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0053, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0053, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0053, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0053, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.017273  ]
#  [ 0.36180064]
#  [ 0.59864104]
#  [ 0.34680182]
#  [ 0.27482089]
#  [ 0.03863423]
#  [-0.03085101]
#  [-0.00339695]
#  [ 0.06669392]
#  [ 0.017828  ]
#  [ 0.12238034]
#  [-0.03140584]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.25547782]
#  [0.4595615 ]
#  [0.43460321]
#  [0.33970636]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.25547782]
#  [0.4595615 ]
#  [0.43460321]
#  [0.33970636]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.25547782] [0.4595615] [0.43460321] [0.33970636]
# xi1_error [-0.00547782]
# xi2_error [0.0404385]
# xi3_error [0.06539679]
# xi4_error [0.16029364]
# xi1_error_app: [array([0.0131017]), array([0.00140989]), array([0.04674287]), array([-0.00410682]), array([-0.01367426]), array([0.00547457]), array([0.00230107]), array([-0.00547782])]
# xi2_error_app: [array([0.00403345]), array([0.0192118]), array([0.04190019]), array([0.0393233]), array([0.03942275]), array([0.03316194]), array([0.01071021]), array([0.0404385])]
# xi3_error_app: [array([0.07146394]), array([0.06397969]), array([0.0995833]), array([0.03900212]), array([-0.0393613]), array([0.02315375]), array([0.10180122]), array([0.06539679])]
# xi4_error_app: [array([0.0582653]), array([0.07704544]), array([0.04364941]), array([0.09906074]), array([0.08463883]), array([0.11985022]), array([0.05913359]), array([0.16029364])]
# seed: 129
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0056, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0116, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0053, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0053, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.05649677]
#  [ 0.30138409]
#  [ 0.73774177]
#  [ 0.31094384]
#  [ 0.33101138]
#  [ 0.04489949]
#  [-0.06526182]
#  [ 0.03869816]
#  [-0.01992407]
#  [ 0.08160751]
#  [ 0.04392517]
#  [-0.05257252]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.20969845]
#  [0.51932377]
#  [0.37754399]
#  [0.40648377]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.20969845]
#  [0.51932377]
#  [0.37754399]
#  [0.40648377]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.20969845] [0.51932377] [0.37754399] [0.40648377]
# xi1_error [0.04030155]
# xi2_error [-0.01932377]
# xi3_error [0.12245601]
# xi4_error [0.09351623]
# xi1_error_app: [array([0.0131017]), array([0.00140989]), array([0.04674287]), array([-0.00410682]), array([-0.01367426]), array([0.00547457]), array([0.00230107]), array([-0.00547782]), array([0.04030155])]
# xi2_error_app: [array([0.00403345]), array([0.0192118]), array([0.04190019]), array([0.0393233]), array([0.03942275]), array([0.03316194]), array([0.01071021]), array([0.0404385]), array([-0.01932377])]
# xi3_error_app: [array([0.07146394]), array([0.06397969]), array([0.0995833]), array([0.03900212]), array([-0.0393613]), array([0.02315375]), array([0.10180122]), array([0.06539679]), array([0.12245601])]
# xi4_error_app: [array([0.0582653]), array([0.07704544]), array([0.04364941]), array([0.09906074]), array([0.08463883]), array([0.11985022]), array([0.05913359]), array([0.16029364]), array([0.09351623])]
# seed: 151
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0059, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0071, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0056, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 3.97633910e-02]
#  [ 3.75512004e-01]
#  [ 7.15655923e-01]
#  [ 3.24203312e-01]
#  [ 3.64812374e-01]
#  [-7.62858102e-03]
#  [-2.31367685e-02]
#  [-1.63306706e-02]
#  [-4.10982966e-02]
#  [ 8.02357346e-02]
#  [ 8.88062455e-03]
#  [-6.36459445e-04]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.25799951]
#  [0.52740157]
#  [0.40593931]
#  [0.46604928]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.25799951]
#  [0.52740157]
#  [0.40593931]
#  [0.46604928]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.25799951] [0.52740157] [0.40593931] [0.46604928]
# xi1_error [-0.00799951]
# xi2_error [-0.02740157]
# xi3_error [0.09406069]
# xi4_error [0.03395072]
# xi1_error_app: [array([0.0131017]), array([0.00140989]), array([0.04674287]), array([-0.00410682]), array([-0.01367426]), array([0.00547457]), array([0.00230107]), array([-0.00547782]), array([0.04030155]), array([-0.00799951])]
# xi2_error_app: [array([0.00403345]), array([0.0192118]), array([0.04190019]), array([0.0393233]), array([0.03942275]), array([0.03316194]), array([0.01071021]), array([0.0404385]), array([-0.01932377]), array([-0.02740157])]
# xi3_error_app: [array([0.07146394]), array([0.06397969]), array([0.0995833]), array([0.03900212]), array([-0.0393613]), array([0.02315375]), array([0.10180122]), array([0.06539679]), array([0.12245601]), array([0.09406069])]
# xi4_error_app: [array([0.0582653]), array([0.07704544]), array([0.04364941]), array([0.09906074]), array([0.08463883]), array([0.11985022]), array([0.05913359]), array([0.16029364]), array([0.09351623]), array([0.03395072])]
# correct_prediction: 10
# Accuracy: 100.0
# xi1_error_avg: [0.00780732]
# xi2_error_avg: [0.01814768]
# xi3_error_avg: [0.06415362]
# xi4_error_avg: [0.08294041]
# xi_updated: [[0.        ]
#  [0.24219268]
#  [0.48185232]
#  [0.43584638]
#  [0.41705959]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# Finished

# %%
pde_Recover(xi_updated, library_coeffs, equation_form='u_t')
end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))
# Out:
# Burger equation:
# u_t = 0.242u_{x} + 0.482u_{y} + 0.436u_{xx} + 0.417u_{yy}
# Duration: 0:24:17.291652
