# %% [markdown]
# # 2D Advection-Diffusion Equation
#
# $$u_t = 0.25u_{x} + 0.5 u_{y} + 0.5u_{xx} + 0.5 u_{yy}$$

# %%
import os
import numpy as np
import pandas as pd 
import scipy.io as sio
import matplotlib.pyplot as plt
import torch
import tensorflow as tf

from torch.autograd import grad
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ExponentialLR

from pdefind import *
from Model_Identification.PDE_Equation import pde_matrix_mul, sparse_coeff, normalized_xi_threshold, pde_Recover
from Model_Identification.build_Library import construct_Dictonary_2D
from datetime import datetime
import numba.cuda

# %%
start_time = datetime.now()

# Prepare dataset
data = sio.loadmat(os.path.join(os.getcwd(), "../data", "Advection_diffusion.mat"))
usol = np.real(data['Expression1'])
print('u.shape', usol.shape)
usol= usol.reshape((51,51,61,4))
#u = data["usol"]
x = usol[:,:,:,0]
y = usol[:,:,:,1]
t = usol[:,:,:,2]
u = usol[:,:,:,3]
print('u.shape', u.shape)
print('x.shape', x.shape)
print('t.shape', t.shape)
print('y.shape', y.shape)
print(x[:,:,10].shape)
# Out:
# u.shape (634644, 1)
# u.shape (51, 51, 61)
# x.shape (51, 51, 61)
# t.shape (51, 51, 61)
# y.shape (51, 51, 61)
# (51, 51)

# %%
fig, ax = plt.subplots()

im = ax.contourf(x[:,:,10], y[:,:,10], u[:,:,10], cmap='seismic')
ax.set_xlabel('x')
ax.set_ylabel('y')

fig.colorbar(mappable=im)

plt.show()

# %%
X = np.transpose((t.flatten(),x.flatten(), y.flatten()))
Y = u.reshape((u.size, 1))
print(X.shape, Y.shape)
print('X:', X)
# Out:
# (158661, 3) (158661, 1)
# X: [[ 3.  -5.  -5. ]
#  [ 3.1 -5.  -5. ]
#  [ 3.2 -5.  -5. ]
#  ...
#  [ 8.8  5.   5. ]
#  [ 8.9  5.   5. ]
#  [ 9.   5.   5. ]]

# %%
# Add noise
np.random.seed(0)
noise_level = 0.1
y = Y + noise_level * np.std(Y) * np.random.randn(Y.size, 1)

# %%
# Setup Network
net = PINN(sizes=[3,20,20,20,20,20,1], activation=torch.nn.Tanh())
print(net)
# Out:
# PINN(
#   (net): Sequential(
#     (0): Linear(in_features=3, out_features=20, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=20, out_features=20, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=20, out_features=20, bias=True)
#     (7): Tanh()
#     (8): Linear(in_features=20, out_features=20, bias=True)
#     (9): Tanh()
#     (10): Linear(in_features=20, out_features=1, bias=True)
#   )
# )

# %%
polynm = ['1', 'u']
spa_der = ['1', 'u_{x}', 'u_{y}','u_{xx}', 'u_{yy}','u_{xy}']
library_coeffs = pde_matrix_mul(polynm, spa_der)
print('library_coeffs:', library_coeffs)

tot_items = len(library_coeffs)
print('tot_items:', tot_items)

mask = torch.ones(tot_items, 1)
epochs = 10000
xi = nn.Parameter(torch.randn((tot_items, 1), requires_grad=True, device="cpu", dtype=torch.float32))
#params = [{'params': net.parameters(), 'lr': 3e-3}, {'params': xi, 'lr': 3e-2}]
params = [{'params': net.parameters(), 'lr': 1e-3}, {'params': xi, 'lr': 1e-2}]

optimizer = Adam(params)
scheduler = ExponentialLR(optimizer, .9998)
# Out:
# library_coeffs: ['1', 'u_{x}', 'u_{y}', 'u_{xx}', 'u_{yy}', 'u_{xy}', 'u', 'uu_{x}', 'uu_{y}', 'uu_{xx}', 'uu_{yy}', 'uu_{xy}']
# tot_items: 12

# %%
def model_identification(features, label, mask, poly_order, deriv_order):
    
    xi1 = []
    xi2 = []
    xi3 = []
    xi4 = []
    xi1_error_app = []
    xi2_error_app = []
    xi3_error_app = []
    xi4_error_app = []
    xi_update_app = []
    
    numbers = [0, 5, 26, 57, 73, 80, 95, 104, 129, 151]
    
    f1 = open("Results/Average_errors.txt", "a+", encoding="utf-8")
    f2 = open("Results/Average_xi.txt", "a+", encoding="utf-8")

    correct_prediction = 0
    # Using for loop
    for i in numbers:
        np.random.seed(i)
        print('seed:', i)
        idxs = np.random.choice(y.size, 1500, replace=False)
        X_train = torch.tensor(features[idxs], dtype=torch.float32, requires_grad=True)
        y_train = torch.tensor(label[idxs], dtype=torch.float32)
    
        lamb   = 0
        tolerance = 1e-6
        mask = torch.ones(tot_items, 1)
        #print('xi', xi)
        print('mask:', mask.shape)
        lambd  = 1e-6
    
        for epoch in range(epochs):
            optimizer.zero_grad()
            uhat = net(X_train)
    
            if epoch == 1000:
                lamb = 1
               
            dudt, theta = construct_Dictonary_2D(X_train, uhat, poly_order=1, deriv_order=2)
            #print('dudt:', dudt.shape)
            dudt_norm = torch.norm(dudt, dim=0)
    
            theta_scaling = (torch.norm(theta, dim=0))
            #Returns a new tensor with a dimension of size one inserted at the specified position. from 9 it will be 9,1
            theta_norm = torch.unsqueeze(theta_scaling, dim = 1) 
            xi_normalized = xi * (theta_norm / dudt_norm) 
            L1 = lambd * torch.sum(torch.abs(xi_normalized[1:, :]))
        
            l_u   = nn.MSELoss()(uhat, y_train)
            l_reg = lamb * torch.mean((dudt - theta @ xi)**2)
            #l_reg = torch.mean((dudt - theta @ xi)**2)

            loss = l_u + l_reg + L1

            gradient_loss = torch.max(torch.abs(grad(outputs=loss, inputs=xi, 
                  grad_outputs=torch.ones_like(loss), create_graph=True)[0]) / (theta_norm / dudt_norm))


            loss.backward(retain_graph=True)
            optimizer.step()
        
            if epoch % 1000 == 0:
                print('loss:', epoch, loss)
                if gradient_loss < tolerance:
                    print('Optimizer converged.')
                    break
 
        xi_list = sparse_coeff(mask, xi.detach().numpy())
        xi_normalized = sparse_coeff(mask, xi_normalized.detach().numpy())
        print('xi_normalized:', xi_normalized)
    

        sparsity = normalized_xi_threshold( xi_normalized, mode='auto')
        print('sparsity:', sparsity)
    
        xi_thresholded = np.expand_dims(xi_list[sparsity], axis=1) 
        print('xi_thresholded:', xi_thresholded)
        
        print('Coefficient xi:')
        xi_update = sparse_coeff(sparsity, xi_thresholded)
        print('xi_update:', xi_update)
        
    
        # Calculate Error in xi    
        if xi_update[1] != 0 and xi_update[2] != 0 and xi_update[3] != 0 and xi_update[4] != 0 and len(xi_thresholded) < 5:
            xi_update_app.append(xi_update)
            #print('xi_update_app:', xi_update_app)
            print('xi_update:', xi_update[1], xi_update[2], xi_update[3], xi_update[4])
            error_1 = np.subtract(np.array([0.25000]),xi_update[1])
            xi1_error = np.append(xi1, error_1)
            print('xi1_error', xi1_error)
            error_2 = np.subtract(np.array([0.50000]),xi_update[2])
            xi2_error = np.append(xi2, error_2)
            print('xi2_error', xi2_error)
            error_3 = np.subtract(np.array([0.50000]),xi_update[3])
            xi3_error = np.append(xi3, error_3)
            print('xi3_error', xi3_error)
            error_4 = np.subtract(np.array([0.50000]),xi_update[4])
            xi4_error = np.append(xi4, error_4)
            print('xi4_error', xi4_error)
            xi1_error_app.append(xi1_error)
            print('xi1_error_app:', xi1_error_app)
            xi2_error_app.append(xi2_error)
            print('xi2_error_app:', xi2_error_app)
            xi3_error_app.append(xi3_error)
            print('xi3_error_app:', xi3_error_app)
            xi4_error_app.append(xi4_error)
            print('xi4_error_app:', xi4_error_app)
            correct_prediction += 1
            
        else:
            print('PDE prediction not correct')
            
            
    print('correct_prediction:', correct_prediction)
    Accuracy = correct_prediction / len(numbers) * 100
    print('Accuracy:', Accuracy)
    xi1_error_avg = np.sum(xi1_error_app, axis = 0) / correct_prediction  
    print('xi1_error_avg:', xi1_error_avg)
    xi2_error_avg = np.sum(xi2_error_app, axis = 0) / correct_prediction 
    print('xi2_error_avg:', xi2_error_avg)
    xi3_error_avg = np.sum(xi3_error_app, axis = 0) / correct_prediction  
    print('xi3_error_avg:', xi3_error_avg)
    xi4_error_avg = np.sum(xi4_error_app, axis = 0) / correct_prediction 
    print('xi4_error_avg:', xi4_error_avg)
    f1.write(str(xi1_error_avg) + " " + str(xi2_error_avg) + " " + str(xi3_error_avg) + " " + str(xi4_error_avg) +  "\n")
    xi_updated = np.sum(xi_update_app, axis = 0) / correct_prediction  
    print('xi_updated:', xi_updated)
    f2.write(str(xi_updated[1]) + " " + str(xi_updated[2]) + " " + str(xi_updated[3]) + " " + str(xi_updated[4]) +  "\n")
    print('Finished')
    return xi_updated

# %%
xi_updated = model_identification(X, y, mask, poly_order=1, deriv_order=2)
# Out:
# seed: 0
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.6851, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.9930, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0029, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0025, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0024, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0024, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0023, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.04188417]
#  [ 0.37892625]
#  [ 0.68579292]
#  [ 0.35219696]
#  [ 0.29584688]
#  [-0.01748149]
#  [-0.09522782]
#  [-0.02445968]
#  [ 0.00273635]
#  [ 0.02129019]
#  [ 0.05500903]
#  [ 0.01125443]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.2606613 ]
#  [0.48808429]
#  [0.42759919]
#  [0.37241811]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.2606613 ]
#  [0.48808429]
#  [0.42759919]
#  [0.37241811]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.2606613] [0.48808429] [0.42759919] [0.37241811]
# xi1_error [-0.0106613]
# xi2_error [0.01191571]
# xi3_error [0.07240081]
# xi4_error [0.12758189]
# xi1_error_app: [array([-0.0106613])]
# xi2_error_app: [array([0.01191571])]
# xi3_error_app: [array([0.07240081])]
# xi4_error_app: [array([0.12758189])]
# seed: 5
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0025, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0031, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0024, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0023, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 4.06599306e-02]
#  [ 3.61503303e-01]
#  [ 6.67815268e-01]
#  [ 3.46238554e-01]
#  [ 2.90287703e-01]
#  [-1.12165278e-02]
#  [-6.72936291e-02]
#  [-2.40680529e-03]
#  [ 4.23279591e-02]
#  [ 2.35150628e-06]
#  [ 5.32000288e-02]
#  [ 1.15668457e-02]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.24952719]
#  [0.46795824]
#  [0.45194495]
#  [0.38262376]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.24952719]
#  [0.46795824]
#  [0.45194495]
#  [0.38262376]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.24952719] [0.46795824] [0.45194495] [0.38262376]
# xi1_error [0.00047281]
# xi2_error [0.03204176]
# xi3_error [0.04805505]
# xi4_error [0.11737624]
# xi1_error_app: [array([-0.0106613]), array([0.00047281])]
# xi2_error_app: [array([0.01191571]), array([0.03204176])]
# xi3_error_app: [array([0.07240081]), array([0.04805505])]
# xi4_error_app: [array([0.12758189]), array([0.11737624])]
# seed: 26
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0023, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0050, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0021, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.02285328]
#  [ 0.3211329 ]
#  [ 0.57348394]
#  [ 0.36027232]
#  [ 0.2838864 ]
#  [-0.00770307]
#  [-0.04540997]
#  [ 0.02762279]
#  [ 0.06281012]
#  [-0.00434475]
#  [ 0.08291594]
#  [ 0.01370766]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.24209307]
#  [0.44769514]
#  [0.46735436]
#  [0.37025458]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.24209307]
#  [0.44769514]
#  [0.46735436]
#  [0.37025458]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.24209307] [0.44769514] [0.46735436] [0.37025458]
# xi1_error [0.00790693]
# xi2_error [0.05230486]
# xi3_error [0.03264564]
# xi4_error [0.12974542]
# xi1_error_app: [array([-0.0106613]), array([0.00047281]), array([0.00790693])]
# xi2_error_app: [array([0.01191571]), array([0.03204176]), array([0.05230486])]
# xi3_error_app: [array([0.07240081]), array([0.04805505]), array([0.03264564])]
# xi4_error_app: [array([0.12758189]), array([0.11737624]), array([0.12974542])]
# seed: 57
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0025, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0034, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0023, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0023, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.04287965]
#  [ 0.38945675]
#  [ 0.6413554 ]
#  [ 0.39588857]
#  [ 0.3057546 ]
#  [-0.01656014]
#  [-0.04746742]
#  [-0.05133403]
#  [ 0.01683478]
#  [-0.04577199]
#  [ 0.0514614 ]
#  [ 0.02783942]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.28813866]
#  [0.48692968]
#  [0.51554698]
#  [0.41410163]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.28813866]
#  [0.48692968]
#  [0.51554698]
#  [0.41410163]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.28813866] [0.48692968] [0.51554698] [0.41410163]
# xi1_error [-0.03813866]
# xi2_error [0.01307032]
# xi3_error [-0.01554698]
# xi4_error [0.08589837]
# xi1_error_app: [array([-0.0106613]), array([0.00047281]), array([0.00790693]), array([-0.03813866])]
# xi2_error_app: [array([0.01191571]), array([0.03204176]), array([0.05230486]), array([0.01307032])]
# xi3_error_app: [array([0.07240081]), array([0.04805505]), array([0.03264564]), array([-0.01554698])]
# xi4_error_app: [array([0.12758189]), array([0.11737624]), array([0.12974542]), array([0.08589837])]
# seed: 73
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0025, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0041, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0023, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0023, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.02829519]
#  [ 0.37128979]
#  [ 0.61084247]
#  [ 0.43539938]
#  [ 0.31559658]
#  [-0.01287821]
#  [-0.02779151]
#  [-0.02271269]
#  [ 0.0669369 ]
#  [-0.07709613]
#  [ 0.12395331]
#  [ 0.03417952]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.26592994]
#  [0.45755935]
#  [0.52152175]
#  [0.38616452]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.26592994]
#  [0.45755935]
#  [0.52152175]
#  [0.38616452]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.26592994] [0.45755935] [0.52152175] [0.38616452]
# xi1_error [-0.01592994]
# xi2_error [0.04244065]
# xi3_error [-0.02152175]
# xi4_error [0.11383548]
# xi1_error_app: [array([-0.0106613]), array([0.00047281]), array([0.00790693]), array([-0.03813866]), array([-0.01592994])]
# xi2_error_app: [array([0.01191571]), array([0.03204176]), array([0.05230486]), array([0.01307032]), array([0.04244065])]
# xi3_error_app: [array([0.07240081]), array([0.04805505]), array([0.03264564]), array([-0.01554698]), array([-0.02152175])]
# xi4_error_app: [array([0.12758189]), array([0.11737624]), array([0.12974542]), array([0.08589837]), array([0.11383548])]
# seed: 80
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0025, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0048, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0024, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0023, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0023, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.01805406]
#  [ 0.35542899]
#  [ 0.62259364]
#  [ 0.38978299]
#  [ 0.31979418]
#  [-0.00126562]
#  [-0.05625506]
#  [ 0.00356481]
#  [ 0.05098247]
#  [-0.0266207 ]
#  [ 0.06318113]
#  [ 0.01302554]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.25470281]
#  [0.4652665 ]
#  [0.48574942]
#  [0.39898923]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.25470281]
#  [0.4652665 ]
#  [0.48574942]
#  [0.39898923]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.25470281] [0.4652665] [0.48574942] [0.39898923]
# xi1_error [-0.00470281]
# xi2_error [0.0347335]
# xi3_error [0.01425058]
# xi4_error [0.10101077]
# xi1_error_app: [array([-0.0106613]), array([0.00047281]), array([0.00790693]), array([-0.03813866]), array([-0.01592994]), array([-0.00470281])]
# xi2_error_app: [array([0.01191571]), array([0.03204176]), array([0.05230486]), array([0.01307032]), array([0.04244065]), array([0.0347335])]
# xi3_error_app: [array([0.07240081]), array([0.04805505]), array([0.03264564]), array([-0.01554698]), array([-0.02152175]), array([0.01425058])]
# xi4_error_app: [array([0.12758189]), array([0.11737624]), array([0.12974542]), array([0.08589837]), array([0.11383548]), array([0.10101077])]
# seed: 95
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0026, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0053, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0024, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[-0.00214125]
#  [ 0.30450165]
#  [ 0.70425594]
#  [ 0.34568393]
#  [ 0.35887438]
#  [-0.05126378]
#  [-0.01367668]
#  [ 0.02805439]
#  [-0.00432771]
#  [ 0.06111582]
#  [-0.00476858]
#  [ 0.04646154]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.22244997]
#  [0.49961221]
#  [0.43351704]
#  [0.47378463]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.22244997]
#  [0.49961221]
#  [0.43351704]
#  [0.47378463]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.22244997] [0.49961221] [0.43351704] [0.47378463]
# xi1_error [0.02755003]
# xi2_error [0.00038779]
# xi3_error [0.06648296]
# xi4_error [0.02621537]
# xi1_error_app: [array([-0.0106613]), array([0.00047281]), array([0.00790693]), array([-0.03813866]), array([-0.01592994]), array([-0.00470281]), array([0.02755003])]
# xi2_error_app: [array([0.01191571]), array([0.03204176]), array([0.05230486]), array([0.01307032]), array([0.04244065]), array([0.0347335]), array([0.00038779])]
# xi3_error_app: [array([0.07240081]), array([0.04805505]), array([0.03264564]), array([-0.01554698]), array([-0.02152175]), array([0.01425058]), array([0.06648296])]
# xi4_error_app: [array([0.12758189]), array([0.11737624]), array([0.12974542]), array([0.08589837]), array([0.11383548]), array([0.10101077]), array([0.02621537])]
# seed: 104
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0025, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0032, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0023, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.01696921]
#  [ 0.34579277]
#  [ 0.57940811]
#  [ 0.35728374]
#  [ 0.29177719]
#  [ 0.00696295]
#  [-0.03661748]
#  [ 0.00430462]
#  [ 0.0604195 ]
#  [ 0.00702474]
#  [ 0.07711343]
#  [-0.00086162]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.24990779]
#  [0.45493191]
#  [0.46773723]
#  [0.36527744]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.24990779]
#  [0.45493191]
#  [0.46773723]
#  [0.36527744]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.24990779] [0.45493191] [0.46773723] [0.36527744]
# xi1_error [9.22083855e-05]
# xi2_error [0.04506809]
# xi3_error [0.03226277]
# xi4_error [0.13472256]
# xi1_error_app: [array([-0.0106613]), array([0.00047281]), array([0.00790693]), array([-0.03813866]), array([-0.01592994]), array([-0.00470281]), array([0.02755003]), array([9.22083855e-05])]
# xi2_error_app: [array([0.01191571]), array([0.03204176]), array([0.05230486]), array([0.01307032]), array([0.04244065]), array([0.0347335]), array([0.00038779]), array([0.04506809])]
# xi3_error_app: [array([0.07240081]), array([0.04805505]), array([0.03264564]), array([-0.01554698]), array([-0.02152175]), array([0.01425058]), array([0.06648296]), array([0.03226277])]
# xi4_error_app: [array([0.12758189]), array([0.11737624]), array([0.12974542]), array([0.08589837]), array([0.11383548]), array([0.10101077]), array([0.02621537]), array([0.13472256])]
# seed: 129
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0025, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0042, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0024, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0023, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0023, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.04014313]
#  [ 0.34468007]
#  [ 0.750368  ]
#  [ 0.38433829]
#  [ 0.373083  ]
#  [ 0.03334341]
#  [-0.01144198]
#  [-0.00813037]
#  [-0.03650152]
#  [ 0.04663996]
#  [ 0.00835518]
#  [-0.03662637]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.24134792]
#  [0.52705741]
#  [0.47335705]
#  [0.46322346]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.24134792]
#  [0.52705741]
#  [0.47335705]
#  [0.46322346]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.24134792] [0.52705741] [0.47335705] [0.46322346]
# xi1_error [0.00865208]
# xi2_error [-0.02705741]
# xi3_error [0.02664295]
# xi4_error [0.03677654]
# xi1_error_app: [array([-0.0106613]), array([0.00047281]), array([0.00790693]), array([-0.03813866]), array([-0.01592994]), array([-0.00470281]), array([0.02755003]), array([9.22083855e-05]), array([0.00865208])]
# xi2_error_app: [array([0.01191571]), array([0.03204176]), array([0.05230486]), array([0.01307032]), array([0.04244065]), array([0.0347335]), array([0.00038779]), array([0.04506809]), array([-0.02705741])]
# xi3_error_app: [array([0.07240081]), array([0.04805505]), array([0.03264564]), array([-0.01554698]), array([-0.02152175]), array([0.01425058]), array([0.06648296]), array([0.03226277]), array([0.02664295])]
# xi4_error_app: [array([0.12758189]), array([0.11737624]), array([0.12974542]), array([0.08589837]), array([0.11383548]), array([0.10101077]), array([0.02621537]), array([0.13472256]), array([0.03677654])]
# seed: 151
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.0028, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0065, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0025, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.0307747 ]
#  [ 0.34881708]
#  [ 0.70663357]
#  [ 0.38301235]
#  [ 0.39592034]
#  [-0.03702526]
#  [-0.00736556]
#  [-0.01263335]
#  [-0.03029313]
#  [ 0.030606  ]
#  [-0.01353067]
#  [ 0.01898812]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.25795081]
#  [0.52622181]
#  [0.4756999 ]
#  [0.49947754]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.25795081]
#  [0.52622181]
#  [0.4756999 ]
#  [0.49947754]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.25795081] [0.52622181] [0.4756999] [0.49947754]
# xi1_error [-0.00795081]
# xi2_error [-0.02622181]
# xi3_error [0.0243001]
# xi4_error [0.00052246]
# xi1_error_app: [array([-0.0106613]), array([0.00047281]), array([0.00790693]), array([-0.03813866]), array([-0.01592994]), array([-0.00470281]), array([0.02755003]), array([9.22083855e-05]), array([0.00865208]), array([-0.00795081])]
# xi2_error_app: [array([0.01191571]), array([0.03204176]), array([0.05230486]), array([0.01307032]), array([0.04244065]), array([0.0347335]), array([0.00038779]), array([0.04506809]), array([-0.02705741]), array([-0.02622181])]
# xi3_error_app: [array([0.07240081]), array([0.04805505]), array([0.03264564]), array([-0.01554698]), array([-0.02152175]), array([0.01425058]), array([0.06648296]), array([0.03226277]), array([0.02664295]), array([0.0243001])]
# xi4_error_app: [array([0.12758189]), array([0.11737624]), array([0.12974542]), array([0.08589837]), array([0.11383548]), array([0.10101077]), array([0.02621537]), array([0.13472256]), array([0.03677654]), array([0.00052246])]
# correct_prediction: 10
# Accuracy: 100.0
# xi1_error_avg: [-0.00327095]
# xi2_error_avg: [0.01786835]
# xi3_error_avg: [0.02799721]
# xi4_error_avg: [0.08736851]
# xi_updated: [[0.        ]
#  [0.25327095]
#  [0.48213165]
#  [0.47200279]
#  [0.41263149]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# Finished

# %%
pde_Recover(xi_updated, library_coeffs, equation_form='u_t')
end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))
# Out:
# Burger equation:
# u_t = 0.2533u_{x} + 0.4821u_{y} + 0.4720u_{xx} + 0.4126u_{yy}
# Duration: 0:15:54.517737
