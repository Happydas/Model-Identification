# %% [markdown]
# # 2D Advection-Diffusion Equation
#
# $$u_t = 0.25u_{x} + 0.5 u_{y} + 0.5u_{xx} + 0.5 u_{yy}$$

# %%
import os
import numpy as np
import pandas as pd 
import scipy.io as sio
import matplotlib.pyplot as plt
import torch
import tensorflow as tf

from torch.autograd import grad
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ExponentialLR

from pdefind import *
from Model_Identification.PDE_Equation import pde_matrix_mul, sparse_coeff, normalized_xi_threshold, pde_Recover
from Model_Identification.build_Library import construct_Dictonary_2D
from datetime import datetime
import numba.cuda

# %%
start_time = datetime.now()
print('start_time:', start_time)

# Prepare dataset
data = sio.loadmat(os.path.join(os.getcwd(), "../data", "Advection_diffusion.mat"))
usol = np.real(data['Expression1'])
print('u.shape', usol.shape)
usol= usol.reshape((51,51,61,4))
#u = data["usol"]
x = usol[:,:,:,0]
y = usol[:,:,:,1]
t = usol[:,:,:,2]
u = usol[:,:,:,3]
print('u.shape', u.shape)
print('x.shape', x.shape)
print('t.shape', t.shape)
print('y.shape', y.shape)
print(x[:,:,10].shape)
# Out:
# start_time: 2020-04-15 20:41:26.071771
# u.shape (634644, 1)
# u.shape (51, 51, 61)
# x.shape (51, 51, 61)
# t.shape (51, 51, 61)
# y.shape (51, 51, 61)
# (51, 51)

# %%
fig, ax = plt.subplots()

im = ax.contourf(x[:,:,10], y[:,:,10], u[:,:,10], cmap='seismic')
ax.set_xlabel('x')
ax.set_ylabel('y')

fig.colorbar(mappable=im)

plt.show()

# %%
X = np.transpose((t.flatten(),x.flatten(), y.flatten()))
Y = u.reshape((u.size, 1))
print(X.shape, Y.shape)
print('X:', X)
# Out:
# (158661, 3) (158661, 1)
# X: [[ 3.  -5.  -5. ]
#  [ 3.1 -5.  -5. ]
#  [ 3.2 -5.  -5. ]
#  ...
#  [ 8.8  5.   5. ]
#  [ 8.9  5.   5. ]
#  [ 9.   5.   5. ]]

# %%
# Add noise
np.random.seed(0)
noise_level = 0.01
y = Y + noise_level * np.std(Y) * np.random.randn(Y.size, 1)

# %%
# Setup Network
net = PINN(sizes=[3,20,20,20,20,20,1], activation=torch.nn.Tanh())
print(net)
# Out:
# PINN(
#   (net): Sequential(
#     (0): Linear(in_features=3, out_features=20, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=20, out_features=20, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=20, out_features=20, bias=True)
#     (7): Tanh()
#     (8): Linear(in_features=20, out_features=20, bias=True)
#     (9): Tanh()
#     (10): Linear(in_features=20, out_features=1, bias=True)
#   )
# )

# %%
polynm = ['1', 'u']
spa_der = ['1', 'u_{x}', 'u_{y}','u_{xx}', 'u_{yy}','u_{xy}']
library_coeffs = pde_matrix_mul(polynm, spa_der)
print('library_coeffs:', library_coeffs)

tot_items = len(library_coeffs)
print('tot_items:', tot_items)

mask = torch.ones(tot_items, 1)
epochs = 10000
xi = nn.Parameter(torch.randn((tot_items, 1), requires_grad=True, device="cpu", dtype=torch.float32))
#params = [{'params': net.parameters(), 'lr': 3e-3}, {'params': xi, 'lr': 3e-2}]
params = [{'params': net.parameters(), 'lr': 1e-3}, {'params': xi, 'lr': 1e-2}]

optimizer = Adam(params)
scheduler = ExponentialLR(optimizer, .9998)
# Out:
# library_coeffs: ['1', 'u_{x}', 'u_{y}', 'u_{xx}', 'u_{yy}', 'u_{xy}', 'u', 'uu_{x}', 'uu_{y}', 'uu_{xx}', 'uu_{yy}', 'uu_{xy}']
# tot_items: 12

# %%
def model_identification(features, label, mask, poly_order, deriv_order):
    
    xi1 = []
    xi2 = []
    xi3 = []
    xi4 = []
    xi1_error_app = []
    xi2_error_app = []
    xi3_error_app = []
    xi4_error_app = []
    xi_update_app = []
    
    numbers = [0, 5, 26, 57, 73, 80, 95, 104, 129, 151]
    
    f1 = open("Results/Average_errors.txt", "a+", encoding="utf-8")
    f2 = open("Results/Average_xi.txt", "a+", encoding="utf-8")

    correct_prediction = 0
    # Using for loop
    for i in numbers:
        np.random.seed(i)
        print('seed:', i)
        idxs = np.random.choice(y.size, 3000, replace=False)
        X_train = torch.tensor(features[idxs], dtype=torch.float32, requires_grad=True)
        y_train = torch.tensor(label[idxs], dtype=torch.float32)
    
        lamb   = 0
        tolerance = 1e-6
        mask = torch.ones(tot_items, 1)
        #print('xi', xi)
        print('mask:', mask.shape)
        lambd  = 1e-6
    
        for epoch in range(epochs):
            optimizer.zero_grad()
            uhat = net(X_train)
    
            if epoch == 1000:
                lamb = 1
               
            dudt, theta = construct_Dictonary_2D(X_train, uhat, poly_order=1, deriv_order=2)
            #print('dudt:', dudt.shape)
            dudt_norm = torch.norm(dudt, dim=0)
    
            theta_scaling = (torch.norm(theta, dim=0))
            #Returns a new tensor with a dimension of size one inserted at the specified position. from 9 it will be 9,1
            theta_norm = torch.unsqueeze(theta_scaling, dim = 1) 
            xi_normalized = xi * (theta_norm / dudt_norm) 
            L1 = lambd * torch.sum(torch.abs(xi_normalized[1:, :]))
        
            l_u   = nn.MSELoss()(uhat, y_train)
            l_reg = lamb * torch.mean((dudt - theta @ xi)**2)
            #l_reg = torch.mean((dudt - theta @ xi)**2)

            loss = l_u + l_reg + L1

            gradient_loss = torch.max(torch.abs(grad(outputs=loss, inputs=xi, 
                  grad_outputs=torch.ones_like(loss), create_graph=True)[0]) / (theta_norm / dudt_norm))


            loss.backward(retain_graph=True)
            optimizer.step()
        
            if epoch % 1000 == 0:
                print('loss:', epoch, loss)
                if gradient_loss < tolerance:
                    print('Optimizer converged.')
                    break
 
        xi_list = sparse_coeff(mask, xi.detach().numpy())
        xi_normalized = sparse_coeff(mask, xi_normalized.detach().numpy())
        print('xi_normalized:', xi_normalized)
    

        sparsity = normalized_xi_threshold( xi_normalized, mode='auto')
        print('sparsity:', sparsity)
    
        xi_thresholded = np.expand_dims(xi_list[sparsity], axis=1) 
        print('xi_thresholded:', xi_thresholded)
        
        print('Coefficient xi:')
        xi_update = sparse_coeff(sparsity, xi_thresholded)
        print('xi_update:', xi_update)
        
    
        # Calculate Error in xi    
        if xi_update[1] != 0 and xi_update[2] != 0 and xi_update[3] != 0 and xi_update[4] != 0 and len(xi_thresholded) < 5:
            xi_update_app.append(xi_update)
            #print('xi_update_app:', xi_update_app)
            print('xi_update:', xi_update[1], xi_update[2], xi_update[3], xi_update[4])
            error_1 = np.subtract(np.array([0.25000]),xi_update[1])
            xi1_error = np.append(xi1, error_1)
            print('xi1_error', xi1_error)
            error_2 = np.subtract(np.array([0.50000]),xi_update[2])
            xi2_error = np.append(xi2, error_2)
            print('xi2_error', xi2_error)
            error_3 = np.subtract(np.array([0.50000]),xi_update[3])
            xi3_error = np.append(xi3, error_3)
            print('xi3_error', xi3_error)
            error_4 = np.subtract(np.array([0.50000]),xi_update[4])
            xi4_error = np.append(xi4, error_4)
            print('xi4_error', xi4_error)
            xi1_error_app.append(xi1_error)
            print('xi1_error_app:', xi1_error_app)
            xi2_error_app.append(xi2_error)
            print('xi2_error_app:', xi2_error_app)
            xi3_error_app.append(xi3_error)
            print('xi3_error_app:', xi3_error_app)
            xi4_error_app.append(xi4_error)
            print('xi4_error_app:', xi4_error_app)
            correct_prediction += 1
            
        else:
            print('PDE prediction not correct')
            
            
    print('correct_prediction:', correct_prediction)
    Accuracy = correct_prediction / len(numbers) * 100
    print('Accuracy:', Accuracy)
    xi1_error_avg = np.sum(xi1_error_app, axis = 0) / correct_prediction  
    print('xi1_error_avg:', xi1_error_avg)
    xi2_error_avg = np.sum(xi2_error_app, axis = 0) / correct_prediction 
    print('xi2_error_avg:', xi2_error_avg)
    xi3_error_avg = np.sum(xi3_error_app, axis = 0) / correct_prediction  
    print('xi3_error_avg:', xi3_error_avg)
    xi4_error_avg = np.sum(xi4_error_app, axis = 0) / correct_prediction 
    print('xi4_error_avg:', xi4_error_avg)
    f1.write(str(xi1_error_avg) + " " + str(xi2_error_avg) + " " + str(xi3_error_avg) + " " + str(xi4_error_avg) +  "\n")
    xi_updated = np.sum(xi_update_app, axis = 0) / correct_prediction  
    print('xi_updated:', xi_updated)
    f2.write(str(xi_updated[1]) + " " + str(xi_updated[2]) + " " + str(xi_updated[3]) + " " + str(xi_updated[4]) +  "\n")
    print('Finished')
    return xi_updated

# %%
xi_updated = model_identification(X, y, mask, poly_order=1, deriv_order=2)
# Out:
# seed: 0
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.6538, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.4427, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0004, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0002, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0004, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0001, grad_fn=<AddBackward0>)
# loss: 6000 tensor(8.6177e-05, grad_fn=<AddBackward0>)
# loss: 7000 tensor(6.8286e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.02062743]
#  [ 0.34739071]
#  [ 0.66514659]
#  [ 0.38751256]
#  [ 0.35851869]
#  [-0.00987007]
#  [-0.05089196]
#  [ 0.01087467]
#  [ 0.00838665]
#  [-0.00411574]
#  [ 0.0045734 ]
#  [ 0.01744151]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.24675867]
#  [0.48828402]
#  [0.4802115 ]
#  [0.44826522]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.24675867]
#  [0.48828402]
#  [0.4802115 ]
#  [0.44826522]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.24675867] [0.48828402] [0.4802115] [0.44826522]
# xi1_error [0.00324133]
# xi2_error [0.01171598]
# xi3_error [0.0197885]
# xi4_error [0.05173478]
# xi1_error_app: [array([0.00324133])]
# xi2_error_app: [array([0.01171598])]
# xi3_error_app: [array([0.0197885])]
# xi4_error_app: [array([0.05173478])]
# seed: 5
# mask: torch.Size([12, 1])
# loss: 0 tensor(3.9472e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0028, grad_fn=<AddBackward0>)
# loss: 2000 tensor(5.4863e-05, grad_fn=<AddBackward0>)
# loss: 3000 tensor(4.9635e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.01378174]
#  [ 0.3561081 ]
#  [ 0.6833427 ]
#  [ 0.38804519]
#  [ 0.35427174]
#  [-0.00748498]
#  [-0.0257488 ]
#  [-0.00315818]
#  [ 0.01177109]
#  [-0.01471963]
#  [ 0.01164204]
#  [ 0.01302307]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.25638348]
#  [0.49027634]
#  [0.5000661 ]
#  [0.46418265]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.25638348]
#  [0.49027634]
#  [0.5000661 ]
#  [0.46418265]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.25638348] [0.49027634] [0.5000661] [0.46418265]
# xi1_error [-0.00638348]
# xi2_error [0.00972366]
# xi3_error [-6.61015511e-05]
# xi4_error [0.03581735]
# xi1_error_app: [array([0.00324133]), array([-0.00638348])]
# xi2_error_app: [array([0.01171598]), array([0.00972366])]
# xi3_error_app: [array([0.0197885]), array([-6.61015511e-05])]
# xi4_error_app: [array([0.05173478]), array([0.03581735])]
# seed: 26
# mask: torch.Size([12, 1])
# loss: 0 tensor(3.3384e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0009, grad_fn=<AddBackward0>)
# loss: 2000 tensor(4.4617e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.0098226 ]
#  [ 0.3531357 ]
#  [ 0.6559577 ]
#  [ 0.38705605]
#  [ 0.36609715]
#  [-0.00302485]
#  [-0.02444013]
#  [ 0.00951362]
#  [ 0.00957217]
#  [-0.00247509]
#  [ 0.00648829]
#  [ 0.00539261]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.24863183]
#  [0.48865825]
#  [0.49024308]
#  [0.46799326]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.24863183]
#  [0.48865825]
#  [0.49024308]
#  [0.46799326]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.24863183] [0.48865825] [0.49024308] [0.46799326]
# xi1_error [0.00136817]
# xi2_error [0.01134175]
# xi3_error [0.00975692]
# xi4_error [0.03200674]
# xi1_error_app: [array([0.00324133]), array([-0.00638348]), array([0.00136817])]
# xi2_error_app: [array([0.01171598]), array([0.00972366]), array([0.01134175])]
# xi3_error_app: [array([0.0197885]), array([-6.61015511e-05]), array([0.00975692])]
# xi4_error_app: [array([0.05173478]), array([0.03581735]), array([0.03200674])]
# seed: 57
# mask: torch.Size([12, 1])
# loss: 0 tensor(3.1791e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0011, grad_fn=<AddBackward0>)
# loss: 2000 tensor(4.2120e-05, grad_fn=<AddBackward0>)
# loss: 3000 tensor(3.9484e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 9.53588169e-03]
#  [ 3.45899433e-01]
#  [ 6.51295424e-01]
#  [ 3.84536177e-01]
#  [ 3.63938063e-01]
#  [-2.73229461e-03]
#  [-1.71237253e-02]
#  [ 5.16492454e-03]
#  [ 6.31861854e-03]
#  [-2.52830796e-04]
#  [ 1.02177979e-02]
#  [ 7.61256134e-03]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.25200453]
#  [0.49254572]
#  [0.49431118]
#  [0.46958616]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.25200453]
#  [0.49254572]
#  [0.49431118]
#  [0.46958616]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.25200453] [0.49254572] [0.49431118] [0.46958616]
# xi1_error [-0.00200453]
# xi2_error [0.00745428]
# xi3_error [0.00568882]
# xi4_error [0.03041384]
# xi1_error_app: [array([0.00324133]), array([-0.00638348]), array([0.00136817]), array([-0.00200453])]
# xi2_error_app: [array([0.01171598]), array([0.00972366]), array([0.01134175]), array([0.00745428])]
# xi3_error_app: [array([0.0197885]), array([-6.61015511e-05]), array([0.00975692]), array([0.00568882])]
# xi4_error_app: [array([0.05173478]), array([0.03581735]), array([0.03200674]), array([0.03041384])]
# seed: 73
# mask: torch.Size([12, 1])
# loss: 0 tensor(3.1205e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0022, grad_fn=<AddBackward0>)
# loss: 2000 tensor(3.8676e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.00596711]
#  [ 0.34754393]
#  [ 0.64989471]
#  [ 0.3947278 ]
#  [ 0.37678394]
#  [-0.00591729]
#  [-0.01038784]
#  [ 0.00332926]
#  [ 0.00570642]
#  [-0.00354402]
#  [ 0.00434327]
#  [ 0.00963369]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.25194708]
#  [0.49438474]
#  [0.50083804]
#  [0.48352852]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.25194708]
#  [0.49438474]
#  [0.50083804]
#  [0.48352852]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.25194708] [0.49438474] [0.50083804] [0.48352852]
# xi1_error [-0.00194708]
# xi2_error [0.00561526]
# xi3_error [-0.00083804]
# xi4_error [0.01647148]
# xi1_error_app: [array([0.00324133]), array([-0.00638348]), array([0.00136817]), array([-0.00200453]), array([-0.00194708])]
# xi2_error_app: [array([0.01171598]), array([0.00972366]), array([0.01134175]), array([0.00745428]), array([0.00561526])]
# xi3_error_app: [array([0.0197885]), array([-6.61015511e-05]), array([0.00975692]), array([0.00568882]), array([-0.00083804])]
# xi4_error_app: [array([0.05173478]), array([0.03581735]), array([0.03200674]), array([0.03041384]), array([0.01647148])]
# seed: 80
# mask: torch.Size([12, 1])
# loss: 0 tensor(2.9885e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0005, grad_fn=<AddBackward0>)
# loss: 2000 tensor(3.8378e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.00632231]
#  [ 0.36484936]
#  [ 0.69652241]
#  [ 0.40745032]
#  [ 0.39271593]
#  [-0.00189596]
#  [-0.01022461]
#  [-0.00211066]
#  [ 0.00083933]
#  [ 0.00109184]
#  [-0.0076344 ]
#  [ 0.0067809 ]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.25444523]
#  [0.499313  ]
#  [0.50300974]
#  [0.48957103]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.25444523]
#  [0.499313  ]
#  [0.50300974]
#  [0.48957103]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.25444523] [0.499313] [0.50300974] [0.48957103]
# xi1_error [-0.00444523]
# xi2_error [0.000687]
# xi3_error [-0.00300974]
# xi4_error [0.01042897]
# xi1_error_app: [array([0.00324133]), array([-0.00638348]), array([0.00136817]), array([-0.00200453]), array([-0.00194708]), array([-0.00444523])]
# xi2_error_app: [array([0.01171598]), array([0.00972366]), array([0.01134175]), array([0.00745428]), array([0.00561526]), array([0.000687])]
# xi3_error_app: [array([0.0197885]), array([-6.61015511e-05]), array([0.00975692]), array([0.00568882]), array([-0.00083804]), array([-0.00300974])]
# xi4_error_app: [array([0.05173478]), array([0.03581735]), array([0.03200674]), array([0.03041384]), array([0.01647148]), array([0.01042897])]
# seed: 95
# mask: torch.Size([12, 1])
# loss: 0 tensor(3.0171e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0010, grad_fn=<AddBackward0>)
# loss: 2000 tensor(3.7513e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 4.06311778e-03]
#  [ 3.58761698e-01]
#  [ 6.85025215e-01]
#  [ 4.04270977e-01]
#  [ 3.82431716e-01]
#  [-3.45366402e-03]
#  [-1.04393866e-02]
#  [ 7.59126036e-04]
#  [ 1.72383327e-03]
#  [ 7.41593340e-06]
#  [-2.14307732e-03]
#  [ 5.69034507e-03]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.25105119]
#  [0.4972555 ]
#  [0.49737307]
#  [0.48881128]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.25105119]
#  [0.4972555 ]
#  [0.49737307]
#  [0.48881128]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.25105119] [0.4972555] [0.49737307] [0.48881128]
# xi1_error [-0.00105119]
# xi2_error [0.0027445]
# xi3_error [0.00262693]
# xi4_error [0.01118872]
# xi1_error_app: [array([0.00324133]), array([-0.00638348]), array([0.00136817]), array([-0.00200453]), array([-0.00194708]), array([-0.00444523]), array([-0.00105119])]
# xi2_error_app: [array([0.01171598]), array([0.00972366]), array([0.01134175]), array([0.00745428]), array([0.00561526]), array([0.000687]), array([0.0027445])]
# xi3_error_app: [array([0.0197885]), array([-6.61015511e-05]), array([0.00975692]), array([0.00568882]), array([-0.00083804]), array([-0.00300974]), array([0.00262693])]
# xi4_error_app: [array([0.05173478]), array([0.03581735]), array([0.03200674]), array([0.03041384]), array([0.01647148]), array([0.01042897]), array([0.01118872])]
# seed: 104
# mask: torch.Size([12, 1])
# loss: 0 tensor(2.8911e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0008, grad_fn=<AddBackward0>)
# loss: 2000 tensor(3.6506e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 5.18260663e-03]
#  [ 3.61323655e-01]
#  [ 6.51194811e-01]
#  [ 3.92380089e-01]
#  [ 3.77780914e-01]
#  [-2.51521240e-03]
#  [-9.91204754e-03]
#  [-1.18656799e-05]
#  [ 1.05901593e-02]
#  [ 1.00392674e-03]
#  [ 3.43862223e-03]
#  [ 4.67592711e-03]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.25282884]
#  [0.49202067]
#  [0.50017583]
#  [0.47879985]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.25282884]
#  [0.49202067]
#  [0.50017583]
#  [0.47879985]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.25282884] [0.49202067] [0.50017583] [0.47879985]
# xi1_error [-0.00282884]
# xi2_error [0.00797933]
# xi3_error [-0.00017583]
# xi4_error [0.02120015]
# xi1_error_app: [array([0.00324133]), array([-0.00638348]), array([0.00136817]), array([-0.00200453]), array([-0.00194708]), array([-0.00444523]), array([-0.00105119]), array([-0.00282884])]
# xi2_error_app: [array([0.01171598]), array([0.00972366]), array([0.01134175]), array([0.00745428]), array([0.00561526]), array([0.000687]), array([0.0027445]), array([0.00797933])]
# xi3_error_app: [array([0.0197885]), array([-6.61015511e-05]), array([0.00975692]), array([0.00568882]), array([-0.00083804]), array([-0.00300974]), array([0.00262693]), array([-0.00017583])]
# xi4_error_app: [array([0.05173478]), array([0.03581735]), array([0.03200674]), array([0.03041384]), array([0.01647148]), array([0.01042897]), array([0.01118872]), array([0.02120015])]
# seed: 129
# mask: torch.Size([12, 1])
# loss: 0 tensor(3.0409e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0010, grad_fn=<AddBackward0>)
# loss: 2000 tensor(3.6931e-05, grad_fn=<AddBackward0>)
# loss: 3000 tensor(3.5559e-05, grad_fn=<AddBackward0>)
# loss: 4000 tensor(4.4494e-05, grad_fn=<AddBackward0>)
# loss: 5000 tensor(3.3702e-05, grad_fn=<AddBackward0>)
# loss: 6000 tensor(3.3162e-05, grad_fn=<AddBackward0>)
# loss: 7000 tensor(3.2716e-05, grad_fn=<AddBackward0>)
# loss: 8000 tensor(8.5935e-05, grad_fn=<AddBackward0>)
# loss: 9000 tensor(3.1743e-05, grad_fn=<AddBackward0>)
# xi_normalized: [[ 6.03502011e-03]
#  [ 3.59897196e-01]
#  [ 7.08994150e-01]
#  [ 4.02937144e-01]
#  [ 3.95099372e-01]
#  [-9.29677219e-04]
#  [-3.29509913e-03]
#  [ 5.50576719e-04]
#  [-2.79312691e-04]
#  [-8.52763362e-04]
#  [ 1.29048608e-03]
#  [ 1.54972938e-03]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.24998511]
#  [0.50168991]
#  [0.50017881]
#  [0.49420476]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.24998511]
#  [0.50168991]
#  [0.50017881]
#  [0.49420476]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.24998511] [0.50168991] [0.50017881] [0.49420476]
# xi1_error [1.488626e-05]
# xi2_error [-0.00168991]
# xi3_error [-0.00017881]
# xi4_error [0.00579524]
# xi1_error_app: [array([0.00324133]), array([-0.00638348]), array([0.00136817]), array([-0.00200453]), array([-0.00194708]), array([-0.00444523]), array([-0.00105119]), array([-0.00282884]), array([1.488626e-05])]
# xi2_error_app: [array([0.01171598]), array([0.00972366]), array([0.01134175]), array([0.00745428]), array([0.00561526]), array([0.000687]), array([0.0027445]), array([0.00797933]), array([-0.00168991])]
# xi3_error_app: [array([0.0197885]), array([-6.61015511e-05]), array([0.00975692]), array([0.00568882]), array([-0.00083804]), array([-0.00300974]), array([0.00262693]), array([-0.00017583]), array([-0.00017881])]
# xi4_error_app: [array([0.05173478]), array([0.03581735]), array([0.03200674]), array([0.03041384]), array([0.01647148]), array([0.01042897]), array([0.01118872]), array([0.02120015]), array([0.00579524])]
# seed: 151
# mask: torch.Size([12, 1])
# loss: 0 tensor(3.4247e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0064, grad_fn=<AddBackward0>)
# loss: 2000 tensor(4.2744e-05, grad_fn=<AddBackward0>)
# loss: 3000 tensor(3.1311e-05, grad_fn=<AddBackward0>)
# loss: 4000 tensor(3.1083e-05, grad_fn=<AddBackward0>)
# loss: 5000 tensor(4.9631e-05, grad_fn=<AddBackward0>)
# loss: 6000 tensor(3.0513e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 2.65527819e-03]
#  [ 3.70780051e-01]
#  [ 6.81725800e-01]
#  [ 3.94867599e-01]
#  [ 3.88136894e-01]
#  [-3.36282561e-03]
#  [ 2.65519629e-04]
#  [-5.30307554e-03]
#  [ 1.63165235e-03]
#  [ 1.02186122e-03]
#  [ 9.21113824e-04]
#  [ 4.67553781e-03]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.25403795]
#  [0.49917775]
#  [0.50188911]
#  [0.49570373]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.25403795]
#  [0.49917775]
#  [0.50188911]
#  [0.49570373]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.25403795] [0.49917775] [0.50188911] [0.49570373]
# xi1_error [-0.00403795]
# xi2_error [0.00082225]
# xi3_error [-0.00188911]
# xi4_error [0.00429627]
# xi1_error_app: [array([0.00324133]), array([-0.00638348]), array([0.00136817]), array([-0.00200453]), array([-0.00194708]), array([-0.00444523]), array([-0.00105119]), array([-0.00282884]), array([1.488626e-05]), array([-0.00403795])]
# xi2_error_app: [array([0.01171598]), array([0.00972366]), array([0.01134175]), array([0.00745428]), array([0.00561526]), array([0.000687]), array([0.0027445]), array([0.00797933]), array([-0.00168991]), array([0.00082225])]
# xi3_error_app: [array([0.0197885]), array([-6.61015511e-05]), array([0.00975692]), array([0.00568882]), array([-0.00083804]), array([-0.00300974]), array([0.00262693]), array([-0.00017583]), array([-0.00017881]), array([-0.00188911])]
# xi4_error_app: [array([0.05173478]), array([0.03581735]), array([0.03200674]), array([0.03041384]), array([0.01647148]), array([0.01042897]), array([0.01118872]), array([0.02120015]), array([0.00579524]), array([0.00429627])]
# correct_prediction: 10
# Accuracy: 100.0
# xi1_error_avg: [-0.00180739]
# xi2_error_avg: [0.00563941]
# xi3_error_avg: [0.00317035]
# xi4_error_avg: [0.02193535]
# xi_updated: [[0.        ]
#  [0.25180739]
#  [0.49436059]
#  [0.49682965]
#  [0.47806465]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# Finished

# %%
pde_Recover(xi_updated, library_coeffs, equation_form='u_t')
end_time = datetime.now()
print('end_time:', end_time)
print('Duration: {}'.format(end_time - start_time))
# Out:
# Burger equation:
# u_t = 0.2518u_{x} + 0.4944u_{y} + 0.4968u_{xx} + 0.4781u_{yy}
# end_time: 2020-04-15 21:36:32.369858
# Duration: 0:55:06.298087
