# %% [markdown]
# # 2D Advection-Diffusion Equation
#
# $$u_t = 0.25u_{x} + 0.5 u_{y} + 0.5u_{xx} + 0.5 u_{yy}$$

# %%
import os
import numpy as np
import pandas as pd 
import scipy.io as sio
import matplotlib.pyplot as plt
import torch
import tensorflow as tf

from torch.autograd import grad
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ExponentialLR

from pdefind import *
from Model_Identification.PDE_Equation import pde_matrix_mul, sparse_coeff, normalized_xi_threshold, pde_Recover
from Model_Identification.build_Library import construct_Dictonary_2D
from datetime import datetime
import numba.cuda

# %%
start_time = datetime.now()
print('start_time:', start_time)

# Prepare dataset
data = sio.loadmat(os.path.join(os.getcwd(), "../data", "Advection_diffusion.mat"))
usol = np.real(data['Expression1'])
print('u.shape', usol.shape)
usol= usol.reshape((51,51,61,4))
#u = data["usol"]
x = usol[:,:,:,0]
y = usol[:,:,:,1]
t = usol[:,:,:,2]
u = usol[:,:,:,3]
print('u.shape', u.shape)
print('x.shape', x.shape)
print('t.shape', t.shape)
print('y.shape', y.shape)
print(x[:,:,10].shape)
# Out:
# start_time: 2020-04-15 20:03:36.186875
# u.shape (634644, 1)
# u.shape (51, 51, 61)
# x.shape (51, 51, 61)
# t.shape (51, 51, 61)
# y.shape (51, 51, 61)
# (51, 51)

# %%
fig, ax = plt.subplots()

im = ax.contourf(x[:,:,10], y[:,:,10], u[:,:,10], cmap='seismic')
ax.set_xlabel('x')
ax.set_ylabel('y')

fig.colorbar(mappable=im)

plt.show()

# %%
X = np.transpose((t.flatten(),x.flatten(), y.flatten()))
Y = u.reshape((u.size, 1))
print(X.shape, Y.shape)
print('X:', X)
# Out:
# (158661, 3) (158661, 1)
# X: [[ 3.  -5.  -5. ]
#  [ 3.1 -5.  -5. ]
#  [ 3.2 -5.  -5. ]
#  ...
#  [ 8.8  5.   5. ]
#  [ 8.9  5.   5. ]
#  [ 9.   5.   5. ]]

# %%
# Add noise
np.random.seed(0)
noise_level = 0.01
y = Y + noise_level * np.std(Y) * np.random.randn(Y.size, 1)

# %%
# Setup Network
net = PINN(sizes=[3,20,20,20,20,20,1], activation=torch.nn.Tanh())
print(net)
# Out:
# PINN(
#   (net): Sequential(
#     (0): Linear(in_features=3, out_features=20, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=20, out_features=20, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=20, out_features=20, bias=True)
#     (7): Tanh()
#     (8): Linear(in_features=20, out_features=20, bias=True)
#     (9): Tanh()
#     (10): Linear(in_features=20, out_features=1, bias=True)
#   )
# )

# %%
polynm = ['1', 'u']
spa_der = ['1', 'u_{x}', 'u_{y}','u_{xx}', 'u_{yy}','u_{xy}']
library_coeffs = pde_matrix_mul(polynm, spa_der)
print('library_coeffs:', library_coeffs)

tot_items = len(library_coeffs)
print('tot_items:', tot_items)

mask = torch.ones(tot_items, 1)
epochs = 10000
xi = nn.Parameter(torch.randn((tot_items, 1), requires_grad=True, device="cpu", dtype=torch.float32))
#params = [{'params': net.parameters(), 'lr': 3e-3}, {'params': xi, 'lr': 3e-2}]
params = [{'params': net.parameters(), 'lr': 1e-3}, {'params': xi, 'lr': 1e-2}]

optimizer = Adam(params)
scheduler = ExponentialLR(optimizer, .9998)
# Out:
# library_coeffs: ['1', 'u_{x}', 'u_{y}', 'u_{xx}', 'u_{yy}', 'u_{xy}', 'u', 'uu_{x}', 'uu_{y}', 'uu_{xx}', 'uu_{yy}', 'uu_{xy}']
# tot_items: 12

# %%
def model_identification(features, label, mask, poly_order, deriv_order):
    
    xi1 = []
    xi2 = []
    xi3 = []
    xi4 = []
    xi1_error_app = []
    xi2_error_app = []
    xi3_error_app = []
    xi4_error_app = []
    xi_update_app = []
    
    numbers = [0, 5, 26, 57, 73, 80, 95, 104, 129, 151]
    
    f1 = open("Results/Average_errors.txt", "a+", encoding="utf-8")
    f2 = open("Results/Average_xi.txt", "a+", encoding="utf-8")

    correct_prediction = 0
    # Using for loop
    for i in numbers:
        np.random.seed(i)
        print('seed:', i)
        idxs = np.random.choice(y.size, 2500, replace=False)
        X_train = torch.tensor(features[idxs], dtype=torch.float32, requires_grad=True)
        y_train = torch.tensor(label[idxs], dtype=torch.float32)
    
        lamb   = 0
        tolerance = 1e-6
        mask = torch.ones(tot_items, 1)
        #print('xi', xi)
        print('mask:', mask.shape)
        lambd  = 1e-6
    
        for epoch in range(epochs):
            optimizer.zero_grad()
            uhat = net(X_train)
    
            if epoch == 1000:
                lamb = 1
               
            dudt, theta = construct_Dictonary_2D(X_train, uhat, poly_order=1, deriv_order=2)
            #print('dudt:', dudt.shape)
            dudt_norm = torch.norm(dudt, dim=0)
    
            theta_scaling = (torch.norm(theta, dim=0))
            #Returns a new tensor with a dimension of size one inserted at the specified position. from 9 it will be 9,1
            theta_norm = torch.unsqueeze(theta_scaling, dim = 1) 
            xi_normalized = xi * (theta_norm / dudt_norm) 
            L1 = lambd * torch.sum(torch.abs(xi_normalized[1:, :]))
        
            l_u   = nn.MSELoss()(uhat, y_train)
            l_reg = lamb * torch.mean((dudt - theta @ xi)**2)
            #l_reg = torch.mean((dudt - theta @ xi)**2)

            loss = l_u + l_reg + L1

            gradient_loss = torch.max(torch.abs(grad(outputs=loss, inputs=xi, 
                  grad_outputs=torch.ones_like(loss), create_graph=True)[0]) / (theta_norm / dudt_norm))


            loss.backward(retain_graph=True)
            optimizer.step()
        
            if epoch % 1000 == 0:
                print('loss:', epoch, loss)
                if gradient_loss < tolerance:
                    print('Optimizer converged.')
                    break
 
        xi_list = sparse_coeff(mask, xi.detach().numpy())
        xi_normalized = sparse_coeff(mask, xi_normalized.detach().numpy())
        print('xi_normalized:', xi_normalized)
    

        sparsity = normalized_xi_threshold( xi_normalized, mode='auto')
        print('sparsity:', sparsity)
    
        xi_thresholded = np.expand_dims(xi_list[sparsity], axis=1) 
        print('xi_thresholded:', xi_thresholded)
        
        print('Coefficient xi:')
        xi_update = sparse_coeff(sparsity, xi_thresholded)
        print('xi_update:', xi_update)
        
    
        # Calculate Error in xi    
        if xi_update[1] != 0 and xi_update[2] != 0 and xi_update[3] != 0 and xi_update[4] != 0 and len(xi_thresholded) < 5:
            xi_update_app.append(xi_update)
            #print('xi_update_app:', xi_update_app)
            print('xi_update:', xi_update[1], xi_update[2], xi_update[3], xi_update[4])
            error_1 = np.subtract(np.array([0.25000]),xi_update[1])
            xi1_error = np.append(xi1, error_1)
            print('xi1_error', xi1_error)
            error_2 = np.subtract(np.array([0.50000]),xi_update[2])
            xi2_error = np.append(xi2, error_2)
            print('xi2_error', xi2_error)
            error_3 = np.subtract(np.array([0.50000]),xi_update[3])
            xi3_error = np.append(xi3, error_3)
            print('xi3_error', xi3_error)
            error_4 = np.subtract(np.array([0.50000]),xi_update[4])
            xi4_error = np.append(xi4, error_4)
            print('xi4_error', xi4_error)
            xi1_error_app.append(xi1_error)
            print('xi1_error_app:', xi1_error_app)
            xi2_error_app.append(xi2_error)
            print('xi2_error_app:', xi2_error_app)
            xi3_error_app.append(xi3_error)
            print('xi3_error_app:', xi3_error_app)
            xi4_error_app.append(xi4_error)
            print('xi4_error_app:', xi4_error_app)
            correct_prediction += 1
            
        else:
            print('PDE prediction not correct')
            
            
    print('correct_prediction:', correct_prediction)
    Accuracy = correct_prediction / len(numbers) * 100
    print('Accuracy:', Accuracy)
    xi1_error_avg = np.sum(xi1_error_app, axis = 0) / correct_prediction  
    print('xi1_error_avg:', xi1_error_avg)
    xi2_error_avg = np.sum(xi2_error_app, axis = 0) / correct_prediction 
    print('xi2_error_avg:', xi2_error_avg)
    xi3_error_avg = np.sum(xi3_error_app, axis = 0) / correct_prediction  
    print('xi3_error_avg:', xi3_error_avg)
    xi4_error_avg = np.sum(xi4_error_app, axis = 0) / correct_prediction 
    print('xi4_error_avg:', xi4_error_avg)
    f1.write(str(xi1_error_avg) + " " + str(xi2_error_avg) + " " + str(xi3_error_avg) + " " + str(xi4_error_avg) +  "\n")
    xi_updated = np.sum(xi_update_app, axis = 0) / correct_prediction  
    print('xi_updated:', xi_updated)
    f2.write(str(xi_updated[1]) + " " + str(xi_updated[2]) + " " + str(xi_updated[3]) + " " + str(xi_updated[4]) +  "\n")
    print('Finished')
    return xi_updated

# %%
xi_updated = model_identification(X, y, mask, poly_order=1, deriv_order=2)
# Out:
# seed: 0
# mask: torch.Size([12, 1])
# loss: 0 tensor(0.3373, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0289, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0004, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0002, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0001, grad_fn=<AddBackward0>)
# loss: 6000 tensor(9.2796e-05, grad_fn=<AddBackward0>)
# loss: 7000 tensor(7.9503e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.01970417]
#  [ 0.35049292]
#  [ 0.6477077 ]
#  [ 0.39762571]
#  [ 0.35028037]
#  [-0.02395272]
#  [-0.06357227]
#  [ 0.00258529]
#  [ 0.03171533]
#  [-0.02484328]
#  [ 0.00708437]
#  [ 0.02375212]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.25006446]
#  [0.47234532]
#  [0.49112049]
#  [0.4382056 ]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.25006446]
#  [0.47234532]
#  [0.49112049]
#  [0.4382056 ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.25006446] [0.47234532] [0.49112049] [0.4382056]
# xi1_error [-6.44624233e-05]
# xi2_error [0.02765468]
# xi3_error [0.00887951]
# xi4_error [0.0617944]
# xi1_error_app: [array([-6.44624233e-05])]
# xi2_error_app: [array([0.02765468])]
# xi3_error_app: [array([0.00887951])]
# xi4_error_app: [array([0.0617944])]
# seed: 5
# mask: torch.Size([12, 1])
# loss: 0 tensor(4.6832e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0037, grad_fn=<AddBackward0>)
# loss: 2000 tensor(6.9721e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.01826998]
#  [ 0.3591626 ]
#  [ 0.67636019]
#  [ 0.38046494]
#  [ 0.35424656]
#  [-0.01487735]
#  [-0.04140234]
#  [-0.00273037]
#  [ 0.01427133]
#  [-0.00901252]
#  [-0.0022055 ]
#  [ 0.01588187]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.25408804]
#  [0.48521173]
#  [0.49164835]
#  [0.46168339]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.25408804]
#  [0.48521173]
#  [0.49164835]
#  [0.46168339]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.25408804] [0.48521173] [0.49164835] [0.46168339]
# xi1_error [-0.00408804]
# xi2_error [0.01478827]
# xi3_error [0.00835165]
# xi4_error [0.03831661]
# xi1_error_app: [array([-6.44624233e-05]), array([-0.00408804])]
# xi2_error_app: [array([0.02765468]), array([0.01478827])]
# xi3_error_app: [array([0.00887951]), array([0.00835165])]
# xi4_error_app: [array([0.0617944]), array([0.03831661])]
# seed: 26
# mask: torch.Size([12, 1])
# loss: 0 tensor(3.9935e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0005, grad_fn=<AddBackward0>)
# loss: 2000 tensor(6.1541e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.0141688 ]
#  [ 0.34466803]
#  [ 0.64595127]
#  [ 0.39528739]
#  [ 0.36657965]
#  [-0.01244024]
#  [-0.03682533]
#  [ 0.00471308]
#  [ 0.01178096]
#  [-0.01622397]
#  [-0.00166176]
#  [ 0.01078252]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.24861489]
#  [0.48529953]
#  [0.4993619 ]
#  [0.46994153]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.24861489]
#  [0.48529953]
#  [0.4993619 ]
#  [0.46994153]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.24861489] [0.48529953] [0.4993619] [0.46994153]
# xi1_error [0.00138511]
# xi2_error [0.01470047]
# xi3_error [0.0006381]
# xi4_error [0.03005847]
# xi1_error_app: [array([-6.44624233e-05]), array([-0.00408804]), array([0.00138511])]
# xi2_error_app: [array([0.02765468]), array([0.01478827]), array([0.01470047])]
# xi3_error_app: [array([0.00887951]), array([0.00835165]), array([0.0006381])]
# xi4_error_app: [array([0.0617944]), array([0.03831661]), array([0.03005847])]
# seed: 57
# mask: torch.Size([12, 1])
# loss: 0 tensor(3.8569e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0010, grad_fn=<AddBackward0>)
# loss: 2000 tensor(5.6573e-05, grad_fn=<AddBackward0>)
# loss: 3000 tensor(5.2533e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.01229598]
#  [ 0.34202629]
#  [ 0.63826257]
#  [ 0.39800572]
#  [ 0.36203018]
#  [-0.00907599]
#  [-0.0351871 ]
#  [ 0.00366146]
#  [ 0.01918819]
#  [-0.02368868]
#  [ 0.0067318 ]
#  [ 0.01005882]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.25046787]
#  [0.48208728]
#  [0.50405896]
#  [0.46437669]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.25046787]
#  [0.48208728]
#  [0.50405896]
#  [0.46437669]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.25046787] [0.48208728] [0.50405896] [0.46437669]
# xi1_error [-0.00046787]
# xi2_error [0.01791272]
# xi3_error [-0.00405896]
# xi4_error [0.03562331]
# xi1_error_app: [array([-6.44624233e-05]), array([-0.00408804]), array([0.00138511]), array([-0.00046787])]
# xi2_error_app: [array([0.02765468]), array([0.01478827]), array([0.01470047]), array([0.01791272])]
# xi3_error_app: [array([0.00887951]), array([0.00835165]), array([0.0006381]), array([-0.00405896])]
# xi4_error_app: [array([0.0617944]), array([0.03831661]), array([0.03005847]), array([0.03562331])]
# seed: 73
# mask: torch.Size([12, 1])
# loss: 0 tensor(3.5914e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0018, grad_fn=<AddBackward0>)
# loss: 2000 tensor(5.0753e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.01169759]
#  [ 0.34626716]
#  [ 0.63517791]
#  [ 0.40368447]
#  [ 0.37148389]
#  [-0.01218024]
#  [-0.02773523]
#  [ 0.00530943]
#  [ 0.02228473]
#  [-0.01580619]
#  [ 0.00864399]
#  [ 0.0123238 ]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.24908215]
#  [0.48264775]
#  [0.50062668]
#  [0.46858194]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.24908215]
#  [0.48264775]
#  [0.50062668]
#  [0.46858194]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.24908215] [0.48264775] [0.50062668] [0.46858194]
# xi1_error [0.00091785]
# xi2_error [0.01735225]
# xi3_error [-0.00062668]
# xi4_error [0.03141806]
# xi1_error_app: [array([-6.44624233e-05]), array([-0.00408804]), array([0.00138511]), array([-0.00046787]), array([0.00091785])]
# xi2_error_app: [array([0.02765468]), array([0.01478827]), array([0.01470047]), array([0.01791272]), array([0.01735225])]
# xi3_error_app: [array([0.00887951]), array([0.00835165]), array([0.0006381]), array([-0.00405896]), array([-0.00062668])]
# xi4_error_app: [array([0.0617944]), array([0.03831661]), array([0.03005847]), array([0.03562331]), array([0.03141806])]
# seed: 80
# mask: torch.Size([12, 1])
# loss: 0 tensor(3.4681e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0006, grad_fn=<AddBackward0>)
# loss: 2000 tensor(4.6857e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.00847082]
#  [ 0.35356304]
#  [ 0.68678206]
#  [ 0.4083941 ]
#  [ 0.39030638]
#  [-0.0096991 ]
#  [-0.02336993]
#  [ 0.00364641]
#  [ 0.00663947]
#  [-0.01282692]
#  [-0.00837832]
#  [ 0.01032986]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.24901707]
#  [0.49196029]
#  [0.50515336]
#  [0.48434523]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.24901707]
#  [0.49196029]
#  [0.50515336]
#  [0.48434523]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.24901707] [0.49196029] [0.50515336] [0.48434523]
# xi1_error [0.00098293]
# xi2_error [0.00803971]
# xi3_error [-0.00515336]
# xi4_error [0.01565477]
# xi1_error_app: [array([-6.44624233e-05]), array([-0.00408804]), array([0.00138511]), array([-0.00046787]), array([0.00091785]), array([0.00098293])]
# xi2_error_app: [array([0.02765468]), array([0.01478827]), array([0.01470047]), array([0.01791272]), array([0.01735225]), array([0.00803971])]
# xi3_error_app: [array([0.00887951]), array([0.00835165]), array([0.0006381]), array([-0.00405896]), array([-0.00062668]), array([-0.00515336])]
# xi4_error_app: [array([0.0617944]), array([0.03831661]), array([0.03005847]), array([0.03562331]), array([0.03141806]), array([0.01565477])]
# seed: 95
# mask: torch.Size([12, 1])
# loss: 0 tensor(3.3195e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0011, grad_fn=<AddBackward0>)
# loss: 2000 tensor(4.4324e-05, grad_fn=<AddBackward0>)
# loss: 3000 tensor(4.1316e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.00452283]
#  [ 0.35378253]
#  [ 0.6904586 ]
#  [ 0.40816909]
#  [ 0.37824026]
#  [-0.00651936]
#  [-0.01417093]
#  [ 0.00182731]
#  [ 0.01079914]
#  [-0.00830319]
#  [-0.00112043]
#  [ 0.0052226 ]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.25080466]
#  [0.49116316]
#  [0.50295633]
#  [0.48782998]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.25080466]
#  [0.49116316]
#  [0.50295633]
#  [0.48782998]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.25080466] [0.49116316] [0.50295633] [0.48782998]
# xi1_error [-0.00080466]
# xi2_error [0.00883684]
# xi3_error [-0.00295633]
# xi4_error [0.01217002]
# xi1_error_app: [array([-6.44624233e-05]), array([-0.00408804]), array([0.00138511]), array([-0.00046787]), array([0.00091785]), array([0.00098293]), array([-0.00080466])]
# xi2_error_app: [array([0.02765468]), array([0.01478827]), array([0.01470047]), array([0.01791272]), array([0.01735225]), array([0.00803971]), array([0.00883684])]
# xi3_error_app: [array([0.00887951]), array([0.00835165]), array([0.0006381]), array([-0.00405896]), array([-0.00062668]), array([-0.00515336]), array([-0.00295633])]
# xi4_error_app: [array([0.0617944]), array([0.03831661]), array([0.03005847]), array([0.03562331]), array([0.03141806]), array([0.01565477]), array([0.01217002])]
# seed: 104
# mask: torch.Size([12, 1])
# loss: 0 tensor(3.2563e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0018, grad_fn=<AddBackward0>)
# loss: 2000 tensor(4.0164e-05, grad_fn=<AddBackward0>)
# loss: 3000 tensor(3.8244e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 4.32872586e-03]
#  [ 3.61966670e-01]
#  [ 6.45497501e-01]
#  [ 3.99025559e-01]
#  [ 3.88243824e-01]
#  [-5.08780312e-03]
#  [-1.08210435e-02]
#  [-2.92626628e-05]
#  [ 1.59003250e-02]
#  [-1.32429879e-04]
#  [ 2.71128840e-03]
#  [ 6.19365508e-03]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.2521981 ]
#  [0.48745471]
#  [0.50256228]
#  [0.47909063]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.2521981 ]
#  [0.48745471]
#  [0.50256228]
#  [0.47909063]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.2521981] [0.48745471] [0.50256228] [0.47909063]
# xi1_error [-0.0021981]
# xi2_error [0.01254529]
# xi3_error [-0.00256228]
# xi4_error [0.02090937]
# xi1_error_app: [array([-6.44624233e-05]), array([-0.00408804]), array([0.00138511]), array([-0.00046787]), array([0.00091785]), array([0.00098293]), array([-0.00080466]), array([-0.0021981])]
# xi2_error_app: [array([0.02765468]), array([0.01478827]), array([0.01470047]), array([0.01791272]), array([0.01735225]), array([0.00803971]), array([0.00883684]), array([0.01254529])]
# xi3_error_app: [array([0.00887951]), array([0.00835165]), array([0.0006381]), array([-0.00405896]), array([-0.00062668]), array([-0.00515336]), array([-0.00295633]), array([-0.00256228])]
# xi4_error_app: [array([0.0617944]), array([0.03831661]), array([0.03005847]), array([0.03562331]), array([0.03141806]), array([0.01565477]), array([0.01217002]), array([0.02090937])]
# seed: 129
# mask: torch.Size([12, 1])
# loss: 0 tensor(3.0844e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0012, grad_fn=<AddBackward0>)
# loss: 2000 tensor(3.6623e-05, grad_fn=<AddBackward0>)
# loss: 3000 tensor(3.5389e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.00401092]
#  [ 0.35921934]
#  [ 0.70587003]
#  [ 0.41012481]
#  [ 0.39957884]
#  [-0.00338794]
#  [-0.00915463]
#  [ 0.00447604]
#  [ 0.00461844]
#  [ 0.0008402 ]
#  [-0.00833534]
#  [ 0.00245842]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.24786097]
#  [0.49568987]
#  [0.50432503]
#  [0.49493814]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.24786097]
#  [0.49568987]
#  [0.50432503]
#  [0.49493814]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.24786097] [0.49568987] [0.50432503] [0.49493814]
# xi1_error [0.00213903]
# xi2_error [0.00431013]
# xi3_error [-0.00432503]
# xi4_error [0.00506186]
# xi1_error_app: [array([-6.44624233e-05]), array([-0.00408804]), array([0.00138511]), array([-0.00046787]), array([0.00091785]), array([0.00098293]), array([-0.00080466]), array([-0.0021981]), array([0.00213903])]
# xi2_error_app: [array([0.02765468]), array([0.01478827]), array([0.01470047]), array([0.01791272]), array([0.01735225]), array([0.00803971]), array([0.00883684]), array([0.01254529]), array([0.00431013])]
# xi3_error_app: [array([0.00887951]), array([0.00835165]), array([0.0006381]), array([-0.00405896]), array([-0.00062668]), array([-0.00515336]), array([-0.00295633]), array([-0.00256228]), array([-0.00432503])]
# xi4_error_app: [array([0.0617944]), array([0.03831661]), array([0.03005847]), array([0.03562331]), array([0.03141806]), array([0.01565477]), array([0.01217002]), array([0.02090937]), array([0.00506186])]
# seed: 151
# mask: torch.Size([12, 1])
# loss: 0 tensor(3.1875e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0015, grad_fn=<AddBackward0>)
# loss: 2000 tensor(3.7691e-05, grad_fn=<AddBackward0>)
# loss: 3000 tensor(3.4710e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[-1.77107926e-04]
#  [ 3.65704000e-01]
#  [ 6.74858212e-01]
#  [ 4.04521704e-01]
#  [ 3.97649795e-01]
#  [-3.89439939e-03]
#  [-3.73097049e-04]
#  [ 2.87829025e-04]
#  [ 8.43870384e-06]
#  [-1.85414497e-03]
#  [-8.75125639e-03]
#  [ 5.48463129e-03]]
# sparsity: [[False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[0.25090787]
#  [0.49771217]
#  [0.5076583 ]
#  [0.50327224]]
# Coefficient xi:
# xi_update: [[0.        ]
#  [0.25090787]
#  [0.49771217]
#  [0.5076583 ]
#  [0.50327224]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# xi_update: [0.25090787] [0.49771217] [0.5076583] [0.50327224]
# xi1_error [-0.00090787]
# xi2_error [0.00228783]
# xi3_error [-0.0076583]
# xi4_error [-0.00327224]
# xi1_error_app: [array([-6.44624233e-05]), array([-0.00408804]), array([0.00138511]), array([-0.00046787]), array([0.00091785]), array([0.00098293]), array([-0.00080466]), array([-0.0021981]), array([0.00213903]), array([-0.00090787])]
# xi2_error_app: [array([0.02765468]), array([0.01478827]), array([0.01470047]), array([0.01791272]), array([0.01735225]), array([0.00803971]), array([0.00883684]), array([0.01254529]), array([0.00431013]), array([0.00228783])]
# xi3_error_app: [array([0.00887951]), array([0.00835165]), array([0.0006381]), array([-0.00405896]), array([-0.00062668]), array([-0.00515336]), array([-0.00295633]), array([-0.00256228]), array([-0.00432503]), array([-0.0076583])]
# xi4_error_app: [array([0.0617944]), array([0.03831661]), array([0.03005847]), array([0.03562331]), array([0.03141806]), array([0.01565477]), array([0.01217002]), array([0.02090937]), array([0.00506186]), array([-0.00327224])]
# correct_prediction: 10
# Accuracy: 100.0
# xi1_error_avg: [-0.00031061]
# xi2_error_avg: [0.01284282]
# xi3_error_avg: [-0.00094717]
# xi4_error_avg: [0.02477346]
# xi_updated: [[0.        ]
#  [0.25031061]
#  [0.48715718]
#  [0.50094717]
#  [0.47522654]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]]
# Finished

# %%
pde_Recover(xi_updated, library_coeffs, equation_form='u_t')
end_time = datetime.now()
print('end_time:', end_time)
print('Duration: {}'.format(end_time - start_time))
# Out:
# Burger equation:
# u_t = 0.2503u_{x} + 0.4872u_{y} + 0.5009u_{xx} + 0.4752u_{yy}
# end_time: 2020-04-15 20:32:50.190736
# Duration: 0:29:14.003861
