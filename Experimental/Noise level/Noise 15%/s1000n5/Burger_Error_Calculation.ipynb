# %% [markdown]
# # Burgers Equation
#
# $$u_{t} = 0.1u_{xx} - 1.0uu_{x}$$

# %%
import os
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
import torch
import tensorflow as tf

import csv
from torch.autograd import grad
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ExponentialLR
from pylab import figure, text, scatter, show
from pdefind import *

from Model_Identification.PDE_Equation import pde_matrix_mul, sparse_coeff, normalized_xi_threshold, pde_Recover
from Model_Identification.build_Library import construct_Dictonary
from datetime import datetime

# %% [markdown]
# ## Data Setup

# %%
start_time = datetime.now()
print('start_time:', start_time)

data = sio.loadmat(os.path.join(os.getcwd(), "../data", "burgers.mat"))
u = data["usol"]
x = data["x"][0]
t = np.squeeze(data["t"], axis=1)

print("u shape", u.shape)
print("x shape", x.shape)
print("t shape", t.shape)

im = plt.imshow(u.real, cmap="seismic", aspect=0.4)
plt.colorbar(im)
plt.title("Burgers Equation")
plt.xlabel("t")
plt.ylabel("x")


xpos  = np.arange(len(t), step=25)
ypos  = np.where(x%4==0)[0].tolist()
ytick = x[ypos].tolist()
ypos  += [len(x)-1]
ytick += [8.0]

plt.xticks(xpos, t[xpos])
plt.yticks(ypos, ytick)
plt.gcf().set_size_inches(6,5)
plt.show()
# Out:
# start_time: 2020-04-02 13:47:25.624539
# u shape (256, 101)
# x shape (256,)
# t shape (101,)

# %%
# Add noise
np.random.seed(0)
noise_level = 0.15
u = u.real + noise_level*np.std(u.real)*np.random.randn(u.shape[0],u.shape[1])

im = plt.imshow(u.real, cmap="seismic", aspect=0.4)
plt.colorbar(im)
plt.title("Noisy Data")
plt.xlabel("t")
plt.ylabel("x")

plt.xticks(xpos, t[xpos])
plt.yticks(ypos, ytick)
plt.gcf().set_size_inches(6,5)
plt.show()

# %%
# Prepare Training Data
xx, tt = np.meshgrid(x,t)
X = np.vstack([xx.ravel(), tt.ravel()]).T
print("X shape", X.shape)
print(X)
# Out:
# X shape (25856, 2)
# [[-8.      0.    ]
#  [-7.9375  0.    ]
#  [-7.875   0.    ]
#  ...
#  [ 7.8125 10.    ]
#  [ 7.875  10.    ]
#  [ 7.9375 10.    ]]

# %%
y = np.zeros((u.size, 1), dtype=np.float)
for i,_x in enumerate(u.real.T):
    y[i*len(x):(i+1)*len(x)] = _x.reshape(len(x),1)
    
print("y shape", y.shape)
# Out:
# y shape (25856, 1)

# %%
# Setup Network
net = PINN(sizes=[2,20,20,20,20,20,1], activation=torch.nn.Tanh())
print(net)
# Out:
# PINN(
#   (net): Sequential(
#     (0): Linear(in_features=2, out_features=20, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=20, out_features=20, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=20, out_features=20, bias=True)
#     (7): Tanh()
#     (8): Linear(in_features=20, out_features=20, bias=True)
#     (9): Tanh()
#     (10): Linear(in_features=20, out_features=1, bias=True)
#   )
# )

# %%
polynm = ['1', 'u', 'uˆ2']
spa_der = ['1', 'u_{x}', 'u_{xx}']
library_coeffs = pde_matrix_mul(polynm, spa_der)
print('library_coeffs:', library_coeffs)

tot_items = len(library_coeffs)
print('tot_items:', tot_items)

mask = torch.ones(tot_items, 1)
epochs = 10000

xi = nn.Parameter(torch.randn((tot_items, 1), requires_grad=True, device="cpu", dtype=torch.float32))
params = [{'params': net.parameters(), 'lr': 1e-3}, {'params': xi, 'lr': 1e-2}]

optimizer = Adam(params)
scheduler = ExponentialLR(optimizer, .9998)
# Out:
# library_coeffs: ['1', 'u_{x}', 'u_{xx}', 'u', 'uu_{x}', 'uu_{xx}', 'uˆ2', 'uˆ2u_{x}', 'uˆ2u_{xx}']
# tot_items: 9

# %%
def model_identification(features, label, mask, poly_order, deriv_order):
    
    xi1 = []
    xi2 = []
    xi1_error_app = []
    xi2_error_app = []
    xi_update_app = []
    
    numbers = [0, 5, 26, 57, 73, 80, 95, 104, 129, 151]
    
    f1 = open("../Results/Value_of_xi.txt", "w+", encoding="utf-8")
    f2 = open("../Results/errors.txt", "w+", encoding="utf-8")
    f3 = open("../Results/avg_xi_n15.txt", "a+", encoding="utf-8")
    correct_prediction = 0
    # Using for loop
    for i in numbers:
        np.random.seed(i)
        print('seed:', i)
        idxs = np.random.choice(y.size, 1000, replace=False)
        X_train = torch.tensor(features[idxs], dtype=torch.float32, requires_grad=True)
        y_train = torch.tensor(label[idxs], dtype=torch.float32)
    
        lamb   = 0
        tolerance = 1e-6
        mask = torch.ones(tot_items, 1)
        #print('xi', xi)
        print('mask:', mask.shape)
        lambd  = 1e-6
    
        for epoch in range(epochs):
            optimizer.zero_grad()
            uhat = net(X_train)
    
            if epoch == 1000:
                lamb = 1
               
            dudt, theta = construct_Dictonary(X_train, uhat, poly_order=2, deriv_order=2)
            #print('dudt:', dudt.shape)
            dudt_norm = torch.norm(dudt, dim=0)
    
            theta_scaling = (torch.norm(theta, dim=0))
            #Returns a new tensor with a dimension of size one inserted at the specified position. from 9 it will be 9,1
            theta_norm = torch.unsqueeze(theta_scaling, dim = 1) 
            xi_normalized = xi * (theta_norm / dudt_norm) 
            L1 = lambd * torch.sum(torch.abs(xi_normalized[1:, :]))
        
            l_u   = nn.MSELoss()(uhat, y_train)
            l_reg = lamb * torch.mean((dudt - theta @ xi)**2)
            #l_reg = torch.mean((dudt - theta @ xi)**2)

            loss = l_u + l_reg + L1

            gradient_loss = torch.max(torch.abs(grad(outputs=loss, inputs=xi, 
                  grad_outputs=torch.ones_like(loss), create_graph=True)[0]) / (theta_norm / dudt_norm))


            loss.backward(retain_graph=True)
            optimizer.step()
        
            if epoch % 1000 == 0:
                print('loss:', epoch, loss)
                if gradient_loss < tolerance:
                    print('Optimizer converged.')
                    break
 
        xi_list = sparse_coeff(mask, xi.detach().numpy())
        xi_normalized = sparse_coeff(mask, xi_normalized.detach().numpy())
        print('xi_normalized:', xi_normalized)
    

        sparsity = normalized_xi_threshold( xi_normalized, mode='auto')
        print('sparsity:', sparsity)
    
        xi_thresholded = np.expand_dims(xi_list[sparsity], axis=1) 
        print('xi_thresholded:', xi_thresholded)
        
        print('Coefficient xi:')
        xi_update = sparse_coeff(sparsity, xi_thresholded)
        print('xi_update:', xi_update)
        
    
        # Calculate Error in xi    
        if xi_update[2] != 0 and xi_update[4] != 0 and len(xi_thresholded) < 3:
            xi_update_app.append(xi_update)
            #print('xi_update_app:', xi_update_app)
            print('xi_update:', xi_update[2], xi_update[4])
            error_1 = np.subtract(np.array([0.10000]),xi_update[2])
            xi1_error = np.append(xi1, error_1)
            print('xi1_error', xi1_error)
            error_2 = np.subtract(np.array([1.00000]),np.abs(xi_update[4]))
            xi2_error = np.append(xi2, error_2)
            print('xi2_error', xi2_error)
            f1.write(str(xi_update[2]) + " " + str(xi_update[4]) + "\n")
            f2.write(str(xi1_error) + " " + str(xi2_error) + "\n")
            xi1_error_app.append(xi1_error)
            print('xi1_error_app:', xi1_error_app)
            xi2_error_app.append(xi2_error)
            print('xi2_error_app:', xi2_error_app)
            correct_prediction += 1
            
        else:
            print('PDE prediction not correct')
            
            
    print('correct_prediction:', correct_prediction)
    Accuracy = correct_prediction / len(numbers) * 100
    print('Accuracy:', Accuracy)
    xi1_error_avg = np.sum(xi1_error_app, axis = 0) / correct_prediction  
    print('xi1_error_avg:', xi1_error_avg)
    xi2_error_avg = np.sum(xi2_error_app, axis = 0) / correct_prediction 
    print('xi2_error_avg:', xi2_error_avg)
    xi_updated = np.sum(xi_update_app, axis = 0) / correct_prediction  
    print('xi_updated:', xi_updated)
    f3.write(str(xi_updated[2]) + " " + str(xi_updated[4]) + "\n")
    print('Finished')
    return xi_updated

# %%
xi_updated = model_identification(X, y, mask, poly_order=2, deriv_order=2)
# Out:
# seed: 0
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0412, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0945, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0008, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0008, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0007, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[-0.01110968]
#  [-0.05736968]
#  [ 0.4319858 ]
#  [ 0.08315556]
#  [-0.90727466]
#  [-0.05813053]
#  [-0.11101885]
#  [-0.08702002]
#  [ 0.04717896]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.08902811]
#  [-0.86941868]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.08902811]
#  [ 0.        ]
#  [-0.86941868]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.08902811] [-0.86941868]
# xi1_error [0.01097189]
# xi2_error [0.13058132]
# xi1_error_app: [array([0.01097189])]
# xi2_error_app: [array([0.13058132])]
# seed: 5
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0008, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0020, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0007, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.00599137]
#  [-0.04769722]
#  [ 0.46101817]
#  [ 0.04685218]
#  [-0.88919574]
#  [ 0.02257815]
#  [-0.10613005]
#  [-0.01618925]
#  [-0.10414745]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09323266]
#  [-0.9081654 ]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.09323266]
#  [ 0.        ]
#  [-0.9081654 ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.09323266] [-0.9081654]
# xi1_error [0.00676734]
# xi2_error [0.0918346]
# xi1_error_app: [array([0.01097189]), array([0.00676734])]
# xi2_error_app: [array([0.13058132]), array([0.0918346])]
# seed: 26
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0016, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 7000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 8000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 9000 tensor(0.0007, grad_fn=<AddBackward0>)
# xi_normalized: [[ 8.94852355e-03]
#  [-7.22701401e-02]
#  [ 3.77572715e-01]
#  [ 3.29630040e-02]
#  [-9.43115175e-01]
#  [-4.47491475e-04]
#  [-7.94285014e-02]
#  [ 8.10912438e-03]
#  [ 3.08331195e-02]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.08278675]
#  [-0.90455931]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.08278675]
#  [ 0.        ]
#  [-0.90455931]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.08278675] [-0.90455931]
# xi1_error [0.01721325]
# xi2_error [0.09544069]
# xi1_error_app: [array([0.01097189]), array([0.00676734]), array([0.01721325])]
# xi2_error_app: [array([0.13058132]), array([0.0918346]), array([0.09544069])]
# seed: 57
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0008, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0042, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 7000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 8000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 9000 tensor(0.0007, grad_fn=<AddBackward0>)
# xi_normalized: [[-2.05857232e-02]
#  [-3.26767229e-02]
#  [ 5.00232518e-01]
#  [-1.47387967e-04]
#  [-9.58608329e-01]
#  [-7.09817279e-04]
#  [ 1.98614299e-02]
#  [-1.62539020e-01]
#  [ 1.82662886e-02]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.10133827]
#  [-0.89261878]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.10133827]
#  [ 0.        ]
#  [-0.89261878]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.10133827] [-0.89261878]
# xi1_error [-0.00133827]
# xi2_error [0.10738122]
# xi1_error_app: [array([0.01097189]), array([0.00676734]), array([0.01721325]), array([-0.00133827])]
# xi2_error_app: [array([0.13058132]), array([0.0918346]), array([0.09544069]), array([0.10738122])]
# seed: 73
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0008, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0031, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 7000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 8000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 9000 tensor(0.0007, grad_fn=<AddBackward0>)
# xi_normalized: [[ 1.29283685e-03]
#  [ 4.93205898e-02]
#  [ 4.49063480e-01]
#  [-3.04427405e-04]
#  [-9.17924225e-01]
#  [-8.59181657e-02]
#  [-1.37697123e-02]
#  [-2.67059896e-02]
#  [-1.99770730e-04]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.11093424]
#  [-1.03133929]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.11093424]
#  [ 0.        ]
#  [-1.03133929]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.11093424] [-1.03133929]
# xi1_error [-0.01093424]
# xi2_error [-0.03133929]
# xi1_error_app: [array([0.01097189]), array([0.00676734]), array([0.01721325]), array([-0.00133827]), array([-0.01093424])]
# xi2_error_app: [array([0.13058132]), array([0.0918346]), array([0.09544069]), array([0.10738122]), array([-0.03133929])]
# seed: 80
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0008, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0030, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0007, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[-0.00797057]
#  [-0.038486  ]
#  [ 0.42155066]
#  [ 0.07229335]
#  [-0.92799556]
#  [-0.05326234]
#  [-0.11391605]
#  [-0.03182885]
#  [ 0.00704007]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09846053]
#  [-0.91703665]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.09846053]
#  [ 0.        ]
#  [-0.91703665]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.09846053] [-0.91703665]
# xi1_error [0.00153947]
# xi2_error [0.08296335]
# xi1_error_app: [array([0.01097189]), array([0.00676734]), array([0.01721325]), array([-0.00133827]), array([-0.01093424]), array([0.00153947])]
# xi2_error_app: [array([0.13058132]), array([0.0918346]), array([0.09544069]), array([0.10738122]), array([-0.03133929]), array([0.08296335])]
# seed: 95
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0018, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 7000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 8000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 9000 tensor(0.0007, grad_fn=<AddBackward0>)
# xi_normalized: [[-0.00870385]
#  [-0.00550112]
#  [ 0.43226188]
#  [-0.05250778]
#  [-0.94114256]
#  [-0.08592652]
#  [ 0.09315053]
#  [-0.0869849 ]
#  [ 0.11399115]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.11442894]
#  [-0.9677552 ]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.11442894]
#  [ 0.        ]
#  [-0.9677552 ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.11442894] [-0.9677552]
# xi1_error [-0.01442894]
# xi2_error [0.0322448]
# xi1_error_app: [array([0.01097189]), array([0.00676734]), array([0.01721325]), array([-0.00133827]), array([-0.01093424]), array([0.00153947]), array([-0.01442894])]
# xi2_error_app: [array([0.13058132]), array([0.0918346]), array([0.09544069]), array([0.10738122]), array([-0.03133929]), array([0.08296335]), array([0.0322448])]
# seed: 104
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0008, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0027, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0007, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[-0.00498021]
#  [-0.02625303]
#  [ 0.42267799]
#  [ 0.00744581]
#  [-0.91620761]
#  [-0.02984319]
#  [-0.01118753]
#  [-0.0019288 ]
#  [-0.00205362]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.10742478]
#  [-0.97948354]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.10742478]
#  [ 0.        ]
#  [-0.97948354]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.10742478] [-0.97948354]
# xi1_error [-0.00742478]
# xi2_error [0.02051646]
# xi1_error_app: [array([0.01097189]), array([0.00676734]), array([0.01721325]), array([-0.00133827]), array([-0.01093424]), array([0.00153947]), array([-0.01442894]), array([-0.00742478])]
# xi2_error_app: [array([0.13058132]), array([0.0918346]), array([0.09544069]), array([0.10738122]), array([-0.03133929]), array([0.08296335]), array([0.0322448]), array([0.02051646])]
# seed: 129
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0008, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0016, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0007, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0007, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.00496074]
#  [-0.03971493]
#  [ 0.38374725]
#  [ 0.03491466]
#  [-1.00765097]
#  [-0.04740832]
#  [-0.08254584]
#  [ 0.11679737]
#  [ 0.00223844]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09576406]
#  [-1.02557075]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.09576406]
#  [ 0.        ]
#  [-1.02557075]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.09576406] [-1.02557075]
# xi1_error [0.00423594]
# xi2_error [-0.02557075]
# xi1_error_app: [array([0.01097189]), array([0.00676734]), array([0.01721325]), array([-0.00133827]), array([-0.01093424]), array([0.00153947]), array([-0.01442894]), array([-0.00742478]), array([0.00423594])]
# xi2_error_app: [array([0.13058132]), array([0.0918346]), array([0.09544069]), array([0.10738122]), array([-0.03133929]), array([0.08296335]), array([0.0322448]), array([0.02051646]), array([-0.02557075])]
# seed: 151
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0008, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0023, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0007, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.00114898]
#  [-0.08671059]
#  [ 0.32760894]
#  [ 0.0711976 ]
#  [-0.84619564]
#  [ 0.12023159]
#  [-0.09606916]
#  [-0.03735676]
#  [-0.11053644]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.08613289]
#  [-0.86979032]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.08613289]
#  [ 0.        ]
#  [-0.86979032]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.08613289] [-0.86979032]
# xi1_error [0.01386711]
# xi2_error [0.13020968]
# xi1_error_app: [array([0.01097189]), array([0.00676734]), array([0.01721325]), array([-0.00133827]), array([-0.01093424]), array([0.00153947]), array([-0.01442894]), array([-0.00742478]), array([0.00423594]), array([0.01386711])]
# xi2_error_app: [array([0.13058132]), array([0.0918346]), array([0.09544069]), array([0.10738122]), array([-0.03133929]), array([0.08296335]), array([0.0322448]), array([0.02051646]), array([-0.02557075]), array([0.13020968])]
# correct_prediction: 10
# Accuracy: 100.0
# xi1_error_avg: [0.00204688]
# xi2_error_avg: [0.06342621]
# xi_updated: [[ 0.        ]
#  [ 0.        ]
#  [ 0.09795312]
#  [ 0.        ]
#  [-0.93657379]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# Finished

# %%
pde_Recover(xi_updated, library_coeffs, equation_form='u_t')
end_time = datetime.now()
print('end_time:', end_time)
print('Duration: {}'.format(end_time - start_time))
# Out:
# Burger equation:
# u_t = 0.0980u_{xx} - 0.9366uu_{x}
# end_time: 2020-04-02 14:19:55.574708
# Duration: 0:32:29.950169
