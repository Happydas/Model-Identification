# %% [markdown]
# # Burgers Equation
#
# $$u_{t} = 0.1u_{xx} - 1.0uu_{x}$$

# %%
import os
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
import torch
import tensorflow as tf

import csv
from torch.autograd import grad
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ExponentialLR
from pylab import figure, text, scatter, show
from pdefind import *

from Model_Identification.PDE_Equation import pde_matrix_mul, sparse_coeff, normalized_xi_threshold, pde_Recover
from Model_Identification.build_Library import construct_Dictonary
from datetime import datetime

# %% [markdown]
# ## Data Setup

# %%
start_time = datetime.now()
print('start_time:', start_time)

data = sio.loadmat(os.path.join(os.getcwd(), "../data", "burgers.mat"))
u = data["usol"]
x = data["x"][0]
t = np.squeeze(data["t"], axis=1)

print("u shape", u.shape)
print("x shape", x.shape)
print("t shape", t.shape)

im = plt.imshow(u.real, cmap="seismic", aspect=0.4)
plt.colorbar(im)
plt.title("Burgers Equation")
plt.xlabel("t")
plt.ylabel("x")


xpos  = np.arange(len(t), step=25)
ypos  = np.where(x%4==0)[0].tolist()
ytick = x[ypos].tolist()
ypos  += [len(x)-1]
ytick += [8.0]

plt.xticks(xpos, t[xpos])
plt.yticks(ypos, ytick)
plt.gcf().set_size_inches(6,5)
plt.show()
# Out:
# start_time: 2020-04-01 12:27:15.795707
# u shape (256, 101)
# x shape (256,)
# t shape (101,)

# %%
# Add noise
np.random.seed(0)
noise_level = 0.05
u = u.real + noise_level*np.std(u.real)*np.random.randn(u.shape[0],u.shape[1])

im = plt.imshow(u.real, cmap="seismic", aspect=0.4)
plt.colorbar(im)
plt.title("Noisy Data")
plt.xlabel("t")
plt.ylabel("x")

plt.xticks(xpos, t[xpos])
plt.yticks(ypos, ytick)
plt.gcf().set_size_inches(6,5)
plt.show()

# %%
# Prepare Training Data
xx, tt = np.meshgrid(x,t)
X = np.vstack([xx.ravel(), tt.ravel()]).T
print("X shape", X.shape)
print(X)
# Out:
# X shape (25856, 2)
# [[-8.      0.    ]
#  [-7.9375  0.    ]
#  [-7.875   0.    ]
#  ...
#  [ 7.8125 10.    ]
#  [ 7.875  10.    ]
#  [ 7.9375 10.    ]]

# %%
y = np.zeros((u.size, 1), dtype=np.float)
for i,_x in enumerate(u.real.T):
    y[i*len(x):(i+1)*len(x)] = _x.reshape(len(x),1)
    
print("y shape", y.shape)
# Out:
# y shape (25856, 1)

# %%
# Setup Network
net = PINN(sizes=[2,20,20,20,20,20,1], activation=torch.nn.Tanh())
print(net)
# Out:
# PINN(
#   (net): Sequential(
#     (0): Linear(in_features=2, out_features=20, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=20, out_features=20, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=20, out_features=20, bias=True)
#     (7): Tanh()
#     (8): Linear(in_features=20, out_features=20, bias=True)
#     (9): Tanh()
#     (10): Linear(in_features=20, out_features=1, bias=True)
#   )
# )

# %%
polynm = ['1', 'u', 'uˆ2']
spa_der = ['1', 'u_{x}', 'u_{xx}']
library_coeffs = pde_matrix_mul(polynm, spa_der)
print('library_coeffs:', library_coeffs)

tot_items = len(library_coeffs)
print('tot_items:', tot_items)

mask = torch.ones(tot_items, 1)
epochs = 10000

xi = nn.Parameter(torch.randn((tot_items, 1), requires_grad=True, device="cpu", dtype=torch.float32))
params = [{'params': net.parameters(), 'lr': 1e-3}, {'params': xi, 'lr': 1e-2}]

optimizer = Adam(params)
scheduler = ExponentialLR(optimizer, .9998)
# Out:
# library_coeffs: ['1', 'u_{x}', 'u_{xx}', 'u', 'uu_{x}', 'uu_{xx}', 'uˆ2', 'uˆ2u_{x}', 'uˆ2u_{xx}']
# tot_items: 9

# %%
def model_identification(features, label, mask, poly_order, deriv_order):
    
    xi1 = []
    xi2 = []
    xi1_error_app = []
    xi2_error_app = []
    xi_update_app = []
    
    numbers = [0, 5, 26, 57, 73, 80, 95, 104, 129, 151]
    
    f1 = open("../Results/Value_of_xi.txt", "w+", encoding="utf-8")
    f2 = open("../Results/errors.txt", "w+", encoding="utf-8")
    f3 = open("../Results/avg_xi_n5.txt", "a+", encoding="utf-8")
    correct_prediction = 0
    # Using for loop
    for i in numbers:
        np.random.seed(i)
        print('seed:', i)
        idxs = np.random.choice(y.size, 500, replace=False)
        X_train = torch.tensor(features[idxs], dtype=torch.float32, requires_grad=True)
        y_train = torch.tensor(label[idxs], dtype=torch.float32)
    
        lamb   = 0
        tolerance = 1e-6
        mask = torch.ones(tot_items, 1)
        #print('xi', xi)
        print('mask:', mask.shape)
        lambd  = 1e-6
    
        for epoch in range(epochs):
            optimizer.zero_grad()
            uhat = net(X_train)
    
            if epoch == 1000:
                lamb = 1
               
            dudt, theta = construct_Dictonary(X_train, uhat, poly_order=2, deriv_order=2)
            #print('dudt:', dudt.shape)
            dudt_norm = torch.norm(dudt, dim=0)
    
            theta_scaling = (torch.norm(theta, dim=0))
            #Returns a new tensor with a dimension of size one inserted at the specified position. from 9 it will be 9,1
            theta_norm = torch.unsqueeze(theta_scaling, dim = 1) 
            xi_normalized = xi * (theta_norm / dudt_norm) 
            L1 = lambd * torch.sum(torch.abs(xi_normalized[1:, :]))
        
            l_u   = nn.MSELoss()(uhat, y_train)
            l_reg = lamb * torch.mean((dudt - theta @ xi)**2)
            #l_reg = torch.mean((dudt - theta @ xi)**2)

            loss = l_u + l_reg + L1

            gradient_loss = torch.max(torch.abs(grad(outputs=loss, inputs=xi, 
                  grad_outputs=torch.ones_like(loss), create_graph=True)[0]) / (theta_norm / dudt_norm))


            loss.backward(retain_graph=True)
            optimizer.step()
        
            if epoch % 1000 == 0:
                print('loss:', epoch, loss)
                if gradient_loss < tolerance:
                    print('Optimizer converged.')
                    break
 
        xi_list = sparse_coeff(mask, xi.detach().numpy())
        xi_normalized = sparse_coeff(mask, xi_normalized.detach().numpy())
        print('xi_normalized:', xi_normalized)
    

        sparsity = normalized_xi_threshold( xi_normalized, mode='auto')
        print('sparsity:', sparsity)
    
        xi_thresholded = np.expand_dims(xi_list[sparsity], axis=1) 
        print('xi_thresholded:', xi_thresholded)
        
        print('Coefficient xi:')
        xi_update = sparse_coeff(sparsity, xi_thresholded)
        print('xi_update:', xi_update)
        
    
        # Calculate Error in xi    
        if xi_update[2] != 0 and xi_update[4] != 0 and len(xi_thresholded) < 3:
            xi_update_app.append(xi_update)
            #print('xi_update_app:', xi_update_app)
            print('xi_update:', xi_update[2], xi_update[4])
            error_1 = np.subtract(np.array([0.10000]),xi_update[2])
            xi1_error = np.append(xi1, error_1)
            print('xi1_error', xi1_error)
            error_2 = np.subtract(np.array([1.00000]),np.abs(xi_update[4]))
            xi2_error = np.append(xi2, error_2)
            print('xi2_error', xi2_error)
            f1.write(str(xi_update[2]) + " " + str(xi_update[4]) + "\n")
            f2.write(str(xi1_error) + " " + str(xi2_error) + "\n")
            xi1_error_app.append(xi1_error)
            print('xi1_error_app:', xi1_error_app)
            xi2_error_app.append(xi2_error)
            print('xi2_error_app:', xi2_error_app)
            correct_prediction += 1
            
        else:
            print('PDE prediction not correct')
            
            
    print('correct_prediction:', correct_prediction)
    Accuracy = correct_prediction / len(numbers) * 100
    print('Accuracy:', Accuracy)
    xi1_error_avg = np.sum(xi1_error_app, axis = 0) / correct_prediction  
    print('xi1_error_avg:', xi1_error_avg)
    xi2_error_avg = np.sum(xi2_error_app, axis = 0) / correct_prediction 
    print('xi2_error_avg:', xi2_error_avg)
    xi_updated = np.sum(xi_update_app, axis = 0) / correct_prediction  
    print('xi_updated:', xi_updated)
    #f3.write(str(xi_updated[2]) + " " + str(xi_updated[4]) + "\n")
    print('Finished')
    return xi_updated

# %%
xi_updated = model_identification(X, y, mask, poly_order=2, deriv_order=2)
# Out:
# seed: 0
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0448, grad_fn=<AddBackward0>)
# loss: 1000 tensor(2.1684, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0010, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0002, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0001, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0001, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0001, grad_fn=<AddBackward0>)
# loss: 7000 tensor(9.2039e-05, grad_fn=<AddBackward0>)
# loss: 8000 tensor(8.2545e-05, grad_fn=<AddBackward0>)
# loss: 9000 tensor(7.9294e-05, grad_fn=<AddBackward0>)
# xi_normalized: [[-1.20366353e-03]
#  [-6.62957728e-02]
#  [ 4.84571129e-01]
#  [ 7.34509677e-02]
#  [-9.64314938e-01]
#  [-7.31096316e-06]
#  [-1.15802355e-01]
#  [ 2.62052100e-02]
#  [-3.75248231e-02]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09147116]
#  [-0.940759  ]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.09147116]
#  [ 0.        ]
#  [-0.940759  ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.09147116] [-0.940759]
# xi1_error [0.00852884]
# xi2_error [0.059241]
# xi1_error_app: [array([0.00852884])]
# xi2_error_app: [array([0.059241])]
# seed: 5
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0001, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0021, grad_fn=<AddBackward0>)
# loss: 2000 tensor(8.6064e-05, grad_fn=<AddBackward0>)
# loss: 3000 tensor(8.0578e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.00834861]
#  [-0.01333004]
#  [ 0.44176421]
#  [ 0.00695427]
#  [-0.95994174]
#  [ 0.10988924]
#  [-0.02120478]
#  [ 0.0010965 ]
#  [-0.10960791]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09557851]
#  [-0.99630451]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.09557851]
#  [ 0.        ]
#  [-0.99630451]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.09557851] [-0.99630451]
# xi1_error [0.00442149]
# xi2_error [0.00369549]
# xi1_error_app: [array([0.00852884]), array([0.00442149])]
# xi2_error_app: [array([0.059241]), array([0.00369549])]
# seed: 26
# mask: torch.Size([9, 1])
# loss: 0 tensor(8.3737e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0010, grad_fn=<AddBackward0>)
# loss: 2000 tensor(7.1648e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 9.75918199e-04]
#  [ 2.22209310e-05]
#  [ 3.95481199e-01]
#  [ 1.51497396e-02]
#  [-1.10081518e+00]
#  [ 1.47406273e-02]
#  [-1.42514482e-02]
#  [ 7.15865493e-02]
#  [ 1.32209258e-02]]
# sparsity: [[False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[-1.05552447]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [-1.05552447]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# PDE prediction not correct
# seed: 57
# mask: torch.Size([9, 1])
# loss: 0 tensor(8.9933e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0008, grad_fn=<AddBackward0>)
# loss: 2000 tensor(7.8969e-05, grad_fn=<AddBackward0>)
# loss: 3000 tensor(7.8436e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[-0.01221344]
#  [-0.03475541]
#  [ 0.62733626]
#  [ 0.0292233 ]
#  [-1.1107043 ]
#  [-0.16958274]
#  [-0.05600929]
#  [-0.0250483 ]
#  [ 0.11420525]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.10357671]
#  [-0.93536389]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.10357671]
#  [ 0.        ]
#  [-0.93536389]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.10357671] [-0.93536389]
# xi1_error [-0.00357671]
# xi2_error [0.06463611]
# xi1_error_app: [array([0.00852884]), array([0.00442149]), array([-0.00357671])]
# xi2_error_app: [array([0.059241]), array([0.00369549]), array([0.06463611])]
# seed: 73
# mask: torch.Size([9, 1])
# loss: 0 tensor(9.8319e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0010, grad_fn=<AddBackward0>)
# loss: 2000 tensor(8.8244e-05, grad_fn=<AddBackward0>)
# loss: 3000 tensor(8.1520e-05, grad_fn=<AddBackward0>)
# loss: 4000 tensor(8.1370e-05, grad_fn=<AddBackward0>)
# loss: 5000 tensor(8.1079e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 2.81139370e-03]
#  [ 1.41181902e-03]
#  [ 4.35168386e-01]
#  [ 2.05592122e-02]
#  [-9.46152925e-01]
#  [-3.83401966e-05]
#  [-3.24774086e-02]
#  [-1.36757398e-03]
#  [-1.04480181e-02]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.10021953]
#  [-1.00202119]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.10021953]
#  [ 0.        ]
#  [-1.00202119]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.10021953] [-1.00202119]
# xi1_error [-0.00021953]
# xi2_error [-0.00202119]
# xi1_error_app: [array([0.00852884]), array([0.00442149]), array([-0.00357671]), array([-0.00021953])]
# xi2_error_app: [array([0.059241]), array([0.00369549]), array([0.06463611]), array([-0.00202119])]
# seed: 80
# mask: torch.Size([9, 1])
# loss: 0 tensor(9.2102e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0027, grad_fn=<AddBackward0>)
# loss: 2000 tensor(7.6226e-05, grad_fn=<AddBackward0>)
# loss: 3000 tensor(7.5329e-05, grad_fn=<AddBackward0>)
# loss: 4000 tensor(7.4772e-05, grad_fn=<AddBackward0>)
# loss: 5000 tensor(7.4385e-05, grad_fn=<AddBackward0>)
# loss: 6000 tensor(7.3998e-05, grad_fn=<AddBackward0>)
# loss: 7000 tensor(7.4014e-05, grad_fn=<AddBackward0>)
# loss: 8000 tensor(7.4055e-05, grad_fn=<AddBackward0>)
# loss: 9000 tensor(7.3152e-05, grad_fn=<AddBackward0>)
# xi_normalized: [[-0.01220398]
#  [-0.01078645]
#  [ 0.35504934]
#  [ 0.01146391]
#  [-0.93759435]
#  [ 0.02363604]
#  [-0.00925477]
#  [-0.00245264]
#  [ 0.00177119]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09533179]
#  [-0.99565101]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.09533179]
#  [ 0.        ]
#  [-0.99565101]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.09533179] [-0.99565101]
# xi1_error [0.00466821]
# xi2_error [0.00434899]
# xi1_error_app: [array([0.00852884]), array([0.00442149]), array([-0.00357671]), array([-0.00021953]), array([0.00466821])]
# xi2_error_app: [array([0.059241]), array([0.00369549]), array([0.06463611]), array([-0.00202119]), array([0.00434899])]
# seed: 95
# mask: torch.Size([9, 1])
# loss: 0 tensor(9.4386e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0016, grad_fn=<AddBackward0>)
# loss: 2000 tensor(8.0165e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 1.51165994e-03]
#  [-3.63077223e-02]
#  [ 4.25907046e-01]
#  [-2.99599633e-05]
#  [-9.42263901e-01]
#  [-6.23151846e-02]
#  [ 2.99712294e-03]
#  [-3.95122096e-02]
#  [ 6.70725554e-02]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.10278909]
#  [-0.93120813]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.10278909]
#  [ 0.        ]
#  [-0.93120813]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.10278909] [-0.93120813]
# xi1_error [-0.00278909]
# xi2_error [0.06879187]
# xi1_error_app: [array([0.00852884]), array([0.00442149]), array([-0.00357671]), array([-0.00021953]), array([0.00466821]), array([-0.00278909])]
# xi2_error_app: [array([0.059241]), array([0.00369549]), array([0.06463611]), array([-0.00202119]), array([0.00434899]), array([0.06879187])]
# seed: 104
# mask: torch.Size([9, 1])
# loss: 0 tensor(8.9571e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0010, grad_fn=<AddBackward0>)
# loss: 2000 tensor(8.4384e-05, grad_fn=<AddBackward0>)
# loss: 3000 tensor(7.3335e-05, grad_fn=<AddBackward0>)
# loss: 4000 tensor(7.4595e-05, grad_fn=<AddBackward0>)
# loss: 5000 tensor(7.2704e-05, grad_fn=<AddBackward0>)
# loss: 6000 tensor(7.2474e-05, grad_fn=<AddBackward0>)
# loss: 7000 tensor(7.6437e-05, grad_fn=<AddBackward0>)
# loss: 8000 tensor(7.2618e-05, grad_fn=<AddBackward0>)
# loss: 9000 tensor(7.1850e-05, grad_fn=<AddBackward0>)
# xi_normalized: [[-9.93352011e-03]
#  [-2.95566637e-02]
#  [ 3.77355576e-01]
#  [-2.88516958e-03]
#  [-8.82248223e-01]
#  [ 1.67033151e-02]
#  [-9.55854822e-03]
#  [-3.04397254e-04]
#  [ 3.07108671e-03]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09451792]
#  [-0.95787078]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.09451792]
#  [ 0.        ]
#  [-0.95787078]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.09451792] [-0.95787078]
# xi1_error [0.00548208]
# xi2_error [0.04212922]
# xi1_error_app: [array([0.00852884]), array([0.00442149]), array([-0.00357671]), array([-0.00021953]), array([0.00466821]), array([-0.00278909]), array([0.00548208])]
# xi2_error_app: [array([0.059241]), array([0.00369549]), array([0.06463611]), array([-0.00202119]), array([0.00434899]), array([0.06879187]), array([0.04212922])]
# seed: 129
# mask: torch.Size([9, 1])
# loss: 0 tensor(9.9016e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0019, grad_fn=<AddBackward0>)
# loss: 2000 tensor(7.9115e-05, grad_fn=<AddBackward0>)
# loss: 3000 tensor(7.8464e-05, grad_fn=<AddBackward0>)
# loss: 4000 tensor(7.8209e-05, grad_fn=<AddBackward0>)
# loss: 5000 tensor(8.0122e-05, grad_fn=<AddBackward0>)
# loss: 6000 tensor(7.7665e-05, grad_fn=<AddBackward0>)
# loss: 7000 tensor(7.7521e-05, grad_fn=<AddBackward0>)
# loss: 8000 tensor(7.7527e-05, grad_fn=<AddBackward0>)
# loss: 9000 tensor(7.7411e-05, grad_fn=<AddBackward0>)
# xi_normalized: [[-6.56305871e-04]
#  [-4.08274159e-02]
#  [ 3.96745831e-01]
#  [-7.73682958e-03]
#  [-9.09799814e-01]
#  [ 3.87204753e-04]
#  [-3.04908818e-03]
#  [-3.71487699e-02]
#  [-2.51617208e-02]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.10091896]
#  [-0.92728549]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.10091896]
#  [ 0.        ]
#  [-0.92728549]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.10091896] [-0.92728549]
# xi1_error [-0.00091896]
# xi2_error [0.07271451]
# xi1_error_app: [array([0.00852884]), array([0.00442149]), array([-0.00357671]), array([-0.00021953]), array([0.00466821]), array([-0.00278909]), array([0.00548208]), array([-0.00091896])]
# xi2_error_app: [array([0.059241]), array([0.00369549]), array([0.06463611]), array([-0.00202119]), array([0.00434899]), array([0.06879187]), array([0.04212922]), array([0.07271451])]
# seed: 151
# mask: torch.Size([9, 1])
# loss: 0 tensor(9.2919e-05, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0027, grad_fn=<AddBackward0>)
# loss: 2000 tensor(7.8318e-05, grad_fn=<AddBackward0>)
# loss: 3000 tensor(7.4653e-05, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 6.05586451e-04]
#  [-1.84554569e-02]
#  [ 3.06925625e-01]
#  [ 2.12168191e-02]
#  [-9.08882618e-01]
#  [ 1.05180936e-02]
#  [-3.23179811e-02]
#  [-1.18273450e-02]
#  [-6.44170586e-03]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09786562]
#  [-0.97292519]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.09786562]
#  [ 0.        ]
#  [-0.97292519]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.09786562] [-0.97292519]
# xi1_error [0.00213438]
# xi2_error [0.02707481]
# xi1_error_app: [array([0.00852884]), array([0.00442149]), array([-0.00357671]), array([-0.00021953]), array([0.00466821]), array([-0.00278909]), array([0.00548208]), array([-0.00091896]), array([0.00213438])]
# xi2_error_app: [array([0.059241]), array([0.00369549]), array([0.06463611]), array([-0.00202119]), array([0.00434899]), array([0.06879187]), array([0.04212922]), array([0.07271451]), array([0.02707481])]
# correct_prediction: 9
# Accuracy: 90.0
# xi1_error_avg: [0.00197008]
# xi2_error_avg: [0.03784564]
# xi_updated: [[ 0.        ]
#  [ 0.        ]
#  [ 0.09802992]
#  [ 0.        ]
#  [-0.96215436]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# Finished

# %%
pde_Recover(xi_updated, library_coeffs, equation_form='u_t')
end_time = datetime.now()
print('end_time:', end_time)
print('Duration: {}'.format(end_time - start_time))
# Out:
# Burger equation:
# u_t = 0.0980u_{xx} - 0.9622uu_{x}
# end_time: 2020-04-01 12:45:28.077196
# Duration: 0:18:12.281489
