# %% [markdown]
# # Burgers Equation
#
# $$u_t+uu_x=0.1u_{xx}$$

# %%
import os
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
import torch
import tensorflow as tf

import csv
from torch.autograd import grad
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ExponentialLR
from pylab import figure, text, scatter, show
from pdefind import *

from Model_Identification.PDE_Equation import pde_matrix_mul, sparse_coeff, normalized_xi_threshold, pde_Recover
from Model_Identification.build_Library import construct_Dictonary

# %% [markdown]
# ## Data Setup

# %%
data = sio.loadmat(os.path.join(os.getcwd(), "../data", "burgers.mat"))
u = data["usol"]
x = data["x"][0]
t = np.squeeze(data["t"], axis=1)

print("u shape", u.shape)
print("x shape", x.shape)
print("t shape", t.shape)

im = plt.imshow(u.real, cmap="seismic", aspect=0.4)
plt.colorbar(im)
plt.title("Burgers Equation")
plt.xlabel("t")
plt.ylabel("x")


xpos  = np.arange(len(t), step=25)
ypos  = np.where(x%4==0)[0].tolist()
ytick = x[ypos].tolist()
ypos  += [len(x)-1]
ytick += [8.0]

plt.xticks(xpos, t[xpos])
plt.yticks(ypos, ytick)
plt.gcf().set_size_inches(6,5)
plt.show()
# Out:
# u shape (256, 101)
# x shape (256,)
# t shape (101,)

# %%
# Add noise
#np.random.seed(8)
noise_level = 0.1
u = u.real + noise_level*np.std(u.real)*np.random.randn(u.shape[0],u.shape[1])

im = plt.imshow(u.real, cmap="seismic", aspect=0.4)
plt.colorbar(im)
plt.title("Noisy Data")
plt.xlabel("t")
plt.ylabel("x")

plt.xticks(xpos, t[xpos])
plt.yticks(ypos, ytick)
plt.gcf().set_size_inches(6,5)
plt.show()

# %%
# Prepare Training Data
xx, tt = np.meshgrid(x,t)
X = np.vstack([xx.ravel(), tt.ravel()]).T
print("X shape", X.shape)
print(X)
# Out:
# X shape (25856, 2)
# [[-8.      0.    ]
#  [-7.9375  0.    ]
#  [-7.875   0.    ]
#  ...
#  [ 7.8125 10.    ]
#  [ 7.875  10.    ]
#  [ 7.9375 10.    ]]

# %%
y = np.zeros((u.size, 1), dtype=np.float)
for i,_x in enumerate(u.real.T):
    y[i*len(x):(i+1)*len(x)] = _x.reshape(len(x),1)
    
print("y shape", y.shape)
# Out:
# y shape (25856, 1)

# %%
# Setup Network
net = PINN(sizes=[2,20,20,20,20,20,1], activation=torch.nn.Tanh())
print(net)
# Out:
# PINN(
#   (net): Sequential(
#     (0): Linear(in_features=2, out_features=20, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=20, out_features=20, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=20, out_features=20, bias=True)
#     (7): Tanh()
#     (8): Linear(in_features=20, out_features=20, bias=True)
#     (9): Tanh()
#     (10): Linear(in_features=20, out_features=1, bias=True)
#   )
# )

# %%
polynm = ['1', 'u', 'uˆ2']
spa_der = ['1', 'u_{x}', 'u_{xx}']
library_coeffs = pde_matrix_mul(polynm, spa_der)
print('library_coeffs:', library_coeffs)

tot_items = len(library_coeffs)
print('tot_items:', tot_items)

mask = torch.ones(tot_items, 1)
epochs = 8000

xi = nn.Parameter(torch.randn((tot_items, 1), requires_grad=True, device="cpu", dtype=torch.float32))
params = [{'params': net.parameters(), 'lr': 3e-3}, {'params': xi, 'lr': 3e-2}]

optimizer = Adam(params)
scheduler = ExponentialLR(optimizer, .9998)
# Out:
# library_coeffs: ['1', 'u_{x}', 'u_{xx}', 'u', 'uu_{x}', 'uu_{xx}', 'uˆ2', 'uˆ2u_{x}', 'uˆ2u_{xx}']
# tot_items: 9

# %%
def model_identification(features, label, mask, poly_order, deriv_order):
    
    xi1 = []
    xi2 = []
    xi1_error_app = []
    xi2_error_app = []
    xi_update_app = []
    
    numbers = [0, 2, 13, 37, 5, 6, 20, 10, 43, 28]
    #numbers = [13, 0]
    #print('numbers:', len(numbers))
    
    f1 = open("../Results/Value_of_xi.txt", "w+", encoding="utf-8")
    f2 = open("../Results/errors.txt", "w+", encoding="utf-8")
    # Using for loop
    for i in numbers:
        np.random.seed(i)
        print('seed:', i)
        idxs = np.random.choice(y.size, 1000, replace=False)
        X_train = torch.tensor(features[idxs], dtype=torch.float32, requires_grad=True)
        y_train = torch.tensor(label[idxs], dtype=torch.float32)
    
        lamb   = 0
        tolerance = 1e-6
        mask = torch.ones(tot_items, 1)
        #print('xi', xi)
        print('mask:', mask.shape)
        lambd  = 1e-6
    
        for epoch in range(epochs):
            optimizer.zero_grad()
            uhat = net(X_train)
    
            if epoch == 1000:
                lamb = 1
               
            dudt, theta = construct_Dictonary(X_train, uhat, poly_order=2, deriv_order=2)
            #print('dudt:', dudt.shape)
            dudt_norm = torch.norm(dudt, dim=0)
    
            theta_scaling = (torch.norm(theta, dim=0))
            #Returns a new tensor with a dimension of size one inserted at the specified position. from 9 it will be 9,1
            theta_norm = torch.unsqueeze(theta_scaling, dim = 1) 
            xi_normalized = xi * (theta_norm / dudt_norm) 
            L1 = lambd * torch.sum(torch.abs(xi_normalized[1:, :]))
        
            l_u   = nn.MSELoss()(uhat, y_train)
            l_reg = lamb * torch.mean((dudt - theta @ xi)**2)
            #l_reg = torch.mean((dudt - theta @ xi)**2)

            loss = l_u + l_reg + L1

            gradient_loss = torch.max(torch.abs(grad(outputs=loss, inputs=xi, 
                  grad_outputs=torch.ones_like(loss), create_graph=True)[0]) / (theta_norm / dudt_norm))


            loss.backward(retain_graph=True)
            optimizer.step()
        
            if epoch % 1000 == 0:
                print('loss:', epoch, loss)
                if gradient_loss < tolerance:
                    print('Optimizer converged.')
                    break
 
        xi_list = sparse_coeff(mask, xi.detach().numpy())
        xi_normalized = sparse_coeff(mask, xi_normalized.detach().numpy())
        print('xi_normalized:', xi_normalized)
    

        sparsity = normalized_xi_threshold( xi_normalized, mode='auto')
        print('sparsity:', sparsity)
    
        xi_thresholded = np.expand_dims(xi_list[sparsity], axis=1) 
        print('xi_thresholded:', xi_thresholded)
        
        print('Coefficient xi:')
        xi_update = sparse_coeff(sparsity, xi_thresholded)
        #xi_add = np.add(xi_th, xi_update)
        xi_update_app.append(xi_update)
        print('xi_update_app:', xi_update_app)
    
        # Calculate Error in xi    
        if len(xi_thresholded) > 1:
            error_1 = np.subtract(np.array([0.10000]),xi_thresholded[0])
            #print('error_1', error_1)
            xi1_error = np.append(xi1, error_1)
            print('xi1_error', xi1_error)
            error_2 = np.subtract(np.array([1.00000]),np.abs(xi_thresholded[1]))
            xi2_error = np.append(xi2, error_2)
            #xi2_error.append(error_2)
            print('xi2_error', xi2_error)
            f1.write(str(xi_thresholded[0]) + " " + str(xi_thresholded[1]) + "\n")
            f2.write(str(xi1_error) + " " + str(xi2_error) + "\n")
            xi1_error_app.append(xi1_error)
            print('xi1_error_app:', xi1_error_app)
            xi2_error_app.append(xi2_error)
            print('xi2_error_app:', xi2_error_app)
            
        else:
            print('Error: Index out of bound')
            
    xi1_error_avg = np.sum(xi1_error_app, axis = 0) / len(numbers) 
    print('xi1_error_avg:', xi1_error_avg)
    xi2_error_avg = np.sum(xi2_error_app, axis = 0) / len(numbers) 
    print('xi2_error_avg:', xi2_error_avg)
    xi_updated = np.sum(xi_update_app, axis = 0) / len(numbers) 
    print('xi_updated:', xi_updated)
    print('Finished')
    return xi_updated

# %%
xi_updated = model_identification(X, y, mask, poly_order=2, deriv_order=2)
# Out:
# seed: 0
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0765, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.2792, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0003, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 2.90197111e-03]
#  [-5.71067482e-02]
#  [ 4.24413025e-01]
#  [ 4.53284048e-02]
#  [-9.64986682e-01]
#  [ 1.28575612e-05]
#  [-7.10687414e-02]
#  [-3.06507908e-02]
#  [ 3.71469208e-03]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.0858465 ]
#  [-0.92554194]]
# Coefficient xi:
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.0858465 ],
#        [ 0.        ],
#        [-0.92554194],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi1_error [0.0141535]
# xi2_error [0.07445806]
# xi1_error_app: [array([0.0141535])]
# xi2_error_app: [array([0.07445806])]
# seed: 2
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0004, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0013, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[-0.01184093]
#  [-0.01482546]
#  [ 0.42541695]
#  [ 0.03578786]
#  [-0.97605062]
#  [-0.00544686]
#  [-0.04487524]
#  [-0.01877166]
#  [-0.01461445]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09703041]
#  [-0.96391654]]
# Coefficient xi:
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.0858465 ],
#        [ 0.        ],
#        [-0.92554194],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09703041],
#        [ 0.        ],
#        [-0.96391654],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi1_error [0.00296959]
# xi2_error [0.03608346]
# xi1_error_app: [array([0.0141535]), array([0.00296959])]
# xi2_error_app: [array([0.07445806]), array([0.03608346])]
# seed: 13
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0016, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[-0.00983481]
#  [ 0.00963044]
#  [ 0.43940362]
#  [ 0.0257228 ]
#  [-0.98913336]
#  [-0.07190658]
#  [-0.04784933]
#  [ 0.02715621]
#  [ 0.02040467]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.10411837]
#  [-1.01849926]]
# Coefficient xi:
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.0858465 ],
#        [ 0.        ],
#        [-0.92554194],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09703041],
#        [ 0.        ],
#        [-0.96391654],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.10411837],
#        [ 0.        ],
#        [-1.01849926],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi1_error [-0.00411837]
# xi2_error [-0.01849926]
# xi1_error_app: [array([0.0141535]), array([0.00296959]), array([-0.00411837])]
# xi2_error_app: [array([0.07445806]), array([0.03608346]), array([-0.01849926])]
# seed: 37
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0004, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0014, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 3.35182194e-05]
#  [-3.72834839e-02]
#  [ 3.41813922e-01]
#  [ 4.91104536e-02]
#  [-9.84644294e-01]
#  [ 1.09712454e-03]
#  [-7.86778480e-02]
#  [ 1.57066388e-05]
#  [-2.05379836e-02]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09434769]
#  [-0.94335836]]
# Coefficient xi:
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.0858465 ],
#        [ 0.        ],
#        [-0.92554194],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09703041],
#        [ 0.        ],
#        [-0.96391654],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.10411837],
#        [ 0.        ],
#        [-1.01849926],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09434769],
#        [ 0.        ],
#        [-0.94335836],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi1_error [0.00565231]
# xi2_error [0.05664164]
# xi1_error_app: [array([0.0141535]), array([0.00296959]), array([-0.00411837]), array([0.00565231])]
# xi2_error_app: [array([0.07445806]), array([0.03608346]), array([-0.01849926]), array([0.05664164])]
# seed: 5
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0015, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 5.91937278e-04]
#  [ 8.16588290e-03]
#  [ 4.58994538e-01]
#  [-8.20450764e-03]
#  [-9.86721933e-01]
#  [ 1.07988045e-02]
#  [ 2.46636625e-02]
#  [ 2.68277852e-03]
#  [ 3.97629887e-02]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09623978]
#  [-1.0292753 ]]
# Coefficient xi:
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.0858465 ],
#        [ 0.        ],
#        [-0.92554194],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09703041],
#        [ 0.        ],
#        [-0.96391654],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.10411837],
#        [ 0.        ],
#        [-1.01849926],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09434769],
#        [ 0.        ],
#        [-0.94335836],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09623978],
#        [ 0.        ],
#        [-1.0292753 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi1_error [0.00376022]
# xi2_error [-0.0292753]
# xi1_error_app: [array([0.0141535]), array([0.00296959]), array([-0.00411837]), array([0.00565231]), array([0.00376022])]
# xi2_error_app: [array([0.07445806]), array([0.03608346]), array([-0.01849926]), array([0.05664164]), array([-0.0292753])]
# seed: 6
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0012, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 7000 tensor(0.0003, grad_fn=<AddBackward0>)
# xi_normalized: [[-1.37274209e-02]
#  [-4.77396976e-03]
#  [ 4.43935305e-01]
#  [-3.35843605e-03]
#  [-9.90075588e-01]
#  [-9.85973105e-02]
#  [-2.79505327e-02]
#  [-1.22414890e-03]
#  [ 3.97103548e-04]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.10738379]
#  [-0.96052712]]
# Coefficient xi:
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.0858465 ],
#        [ 0.        ],
#        [-0.92554194],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09703041],
#        [ 0.        ],
#        [-0.96391654],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.10411837],
#        [ 0.        ],
#        [-1.01849926],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09434769],
#        [ 0.        ],
#        [-0.94335836],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09623978],
#        [ 0.        ],
#        [-1.0292753 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.10738379],
#        [ 0.        ],
#        [-0.96052712],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi1_error [-0.00738379]
# xi2_error [0.03947288]
# xi1_error_app: [array([0.0141535]), array([0.00296959]), array([-0.00411837]), array([0.00565231]), array([0.00376022]), array([-0.00738379])]
# xi2_error_app: [array([0.07445806]), array([0.03608346]), array([-0.01849926]), array([0.05664164]), array([-0.0292753]), array([0.03947288])]
# seed: 20
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0004, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0059, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 7000 tensor(0.0003, grad_fn=<AddBackward0>)
# xi_normalized: [[ 1.83266005e-04]
#  [-2.24568397e-02]
#  [ 3.81496191e-01]
#  [-4.76879686e-05]
#  [-9.14838135e-01]
#  [ 3.90755758e-02]
#  [-1.06238741e-02]
#  [-9.35694916e-05]
#  [-6.95022121e-02]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.10032544]
#  [-0.96623009]]
# Coefficient xi:
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.0858465 ],
#        [ 0.        ],
#        [-0.92554194],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09703041],
#        [ 0.        ],
#        [-0.96391654],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.10411837],
#        [ 0.        ],
#        [-1.01849926],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09434769],
#        [ 0.        ],
#        [-0.94335836],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09623978],
#        [ 0.        ],
#        [-1.0292753 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.10738379],
#        [ 0.        ],
#        [-0.96052712],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.10032544],
#        [ 0.        ],
#        [-0.96623009],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi1_error [-0.00032544]
# xi2_error [0.03376991]
# xi1_error_app: [array([0.0141535]), array([0.00296959]), array([-0.00411837]), array([0.00565231]), array([0.00376022]), array([-0.00738379]), array([-0.00032544])]
# xi2_error_app: [array([0.07445806]), array([0.03608346]), array([-0.01849926]), array([0.05664164]), array([-0.0292753]), array([0.03947288]), array([0.03376991])]
# seed: 10
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0004, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0049, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[-0.0020815 ]
#  [-0.11280176]
#  [ 0.38969284]
#  [ 0.07336958]
#  [-0.80055034]
#  [-0.09757839]
#  [-0.13426869]
#  [-0.12968315]
#  [ 0.05666817]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.08950412]
#  [-0.75688219]]
# Coefficient xi:
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.0858465 ],
#        [ 0.        ],
#        [-0.92554194],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09703041],
#        [ 0.        ],
#        [-0.96391654],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.10411837],
#        [ 0.        ],
#        [-1.01849926],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09434769],
#        [ 0.        ],
#        [-0.94335836],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09623978],
#        [ 0.        ],
#        [-1.0292753 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.10738379],
#        [ 0.        ],
#        [-0.96052712],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.10032544],
#        [ 0.        ],
#        [-0.96623009],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08950412],
#        [ 0.        ],
#        [-0.75688219],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi1_error [0.01049588]
# xi2_error [0.24311781]
# xi1_error_app: [array([0.0141535]), array([0.00296959]), array([-0.00411837]), array([0.00565231]), array([0.00376022]), array([-0.00738379]), array([-0.00032544]), array([0.01049588])]
# xi2_error_app: [array([0.07445806]), array([0.03608346]), array([-0.01849926]), array([0.05664164]), array([-0.0292753]), array([0.03947288]), array([0.03376991]), array([0.24311781])]
# seed: 43
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0004, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0018, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0003, grad_fn=<AddBackward0>)
# loss: 7000 tensor(0.0003, grad_fn=<AddBackward0>)
# xi_normalized: [[-4.03365260e-03]
#  [-1.23719111e-01]
#  [ 4.09517318e-01]
#  [ 1.09564319e-01]
#  [-7.60445893e-01]
#  [-3.01185120e-02]
#  [-1.89199835e-01]
#  [ 1.01084914e-02]
#  [ 2.49382229e-05]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.07471464]
#  [-0.80639809]]
# Coefficient xi:
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.0858465 ],
#        [ 0.        ],
#        [-0.92554194],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09703041],
#        [ 0.        ],
#        [-0.96391654],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.10411837],
#        [ 0.        ],
#        [-1.01849926],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09434769],
#        [ 0.        ],
#        [-0.94335836],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09623978],
#        [ 0.        ],
#        [-1.0292753 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.10738379],
#        [ 0.        ],
#        [-0.96052712],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.10032544],
#        [ 0.        ],
#        [-0.96623009],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08950412],
#        [ 0.        ],
#        [-0.75688219],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.07471464],
#        [ 0.        ],
#        [-0.80639809],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi1_error [0.02528536]
# xi2_error [0.19360191]
# xi1_error_app: [array([0.0141535]), array([0.00296959]), array([-0.00411837]), array([0.00565231]), array([0.00376022]), array([-0.00738379]), array([-0.00032544]), array([0.01049588]), array([0.02528536])]
# xi2_error_app: [array([0.07445806]), array([0.03608346]), array([-0.01849926]), array([0.05664164]), array([-0.0292753]), array([0.03947288]), array([0.03376991]), array([0.24311781]), array([0.19360191])]
# seed: 28
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0004, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0063, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0003, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[-0.00132922]
#  [-0.07271484]
#  [ 0.37767214]
#  [ 0.05664435]
#  [-0.66898513]
#  [-0.12658195]
#  [-0.12770316]
#  [-0.22226827]
#  [ 0.05585616]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09471908]
#  [-0.70586723]]
# Coefficient xi:
# xi_update_app: [array([[ 0.        ],
#        [ 0.        ],
#        [ 0.0858465 ],
#        [ 0.        ],
#        [-0.92554194],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09703041],
#        [ 0.        ],
#        [-0.96391654],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.10411837],
#        [ 0.        ],
#        [-1.01849926],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09434769],
#        [ 0.        ],
#        [-0.94335836],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09623978],
#        [ 0.        ],
#        [-1.0292753 ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.10738379],
#        [ 0.        ],
#        [-0.96052712],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.10032544],
#        [ 0.        ],
#        [-0.96623009],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.08950412],
#        [ 0.        ],
#        [-0.75688219],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.07471464],
#        [ 0.        ],
#        [-0.80639809],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]]), array([[ 0.        ],
#        [ 0.        ],
#        [ 0.09471908],
#        [ 0.        ],
#        [-0.70586723],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])]
# xi1_error [0.00528092]
# xi2_error [0.29413277]
# xi1_error_app: [array([0.0141535]), array([0.00296959]), array([-0.00411837]), array([0.00565231]), array([0.00376022]), array([-0.00738379]), array([-0.00032544]), array([0.01049588]), array([0.02528536]), array([0.00528092])]
# xi2_error_app: [array([0.07445806]), array([0.03608346]), array([-0.01849926]), array([0.05664164]), array([-0.0292753]), array([0.03947288]), array([0.03376991]), array([0.24311781]), array([0.19360191]), array([0.29413277])]
# xi1_error_avg: [0.00557702]
# xi2_error_avg: [0.09235039]
# xi_updated: [[ 0.        ]
#  [ 0.        ]
#  [ 0.09442298]
#  [ 0.        ]
#  [-0.90764961]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# Finished

# %%
pde_Recover(xi_updated, library_coeffs, equation_form='u_t')
#print('Process Completed')
# Out:
# Burger equation:
# u_t = 0.0944u_{xx} - 0.9076uu_{x}
