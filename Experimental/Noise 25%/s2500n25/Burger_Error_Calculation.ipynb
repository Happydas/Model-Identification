# %% [markdown]
# # Burgers Equation
#
# $$u_{t} = 0.1u_{xx} - 1.0uu_{x}$$

# %%
import os
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
import torch
import tensorflow as tf

import csv
from torch.autograd import grad
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ExponentialLR
from pylab import figure, text, scatter, show
from pdefind import *

from Model_Identification.PDE_Equation import pde_matrix_mul, sparse_coeff, normalized_xi_threshold, pde_Recover
from Model_Identification.build_Library import construct_Dictonary
from datetime import datetime

# %% [markdown]
# ## Data Setup

# %%
start_time = datetime.now()
print('start_time:', start_time)

data = sio.loadmat(os.path.join(os.getcwd(), "../data", "burgers.mat"))
u = data["usol"]
x = data["x"][0]
t = np.squeeze(data["t"], axis=1)

print("u shape", u.shape)
print("x shape", x.shape)
print("t shape", t.shape)

im = plt.imshow(u.real, cmap="seismic", aspect=0.4)
plt.colorbar(im)
plt.title("Burgers Equation")
plt.xlabel("t")
plt.ylabel("x")


xpos  = np.arange(len(t), step=25)
ypos  = np.where(x%4==0)[0].tolist()
ytick = x[ypos].tolist()
ypos  += [len(x)-1]
ytick += [8.0]

plt.xticks(xpos, t[xpos])
plt.yticks(ypos, ytick)
plt.gcf().set_size_inches(6,5)
plt.show()
# Out:
# start_time: 2020-04-04 10:18:52.007680
# u shape (256, 101)
# x shape (256,)
# t shape (101,)

# %%
# Add noise
np.random.seed(0)
noise_level = 0.25
u = u.real + noise_level*np.std(u.real)*np.random.randn(u.shape[0],u.shape[1])

im = plt.imshow(u.real, cmap="seismic", aspect=0.4)
plt.colorbar(im)
plt.title("Noisy Data")
plt.xlabel("t")
plt.ylabel("x")

plt.xticks(xpos, t[xpos])
plt.yticks(ypos, ytick)
plt.gcf().set_size_inches(6,5)
plt.show()

# %%
# Prepare Training Data
xx, tt = np.meshgrid(x,t)
X = np.vstack([xx.ravel(), tt.ravel()]).T
print("X shape", X.shape)
print(X)
# Out:
# X shape (25856, 2)
# [[-8.      0.    ]
#  [-7.9375  0.    ]
#  [-7.875   0.    ]
#  ...
#  [ 7.8125 10.    ]
#  [ 7.875  10.    ]
#  [ 7.9375 10.    ]]

# %%
y = np.zeros((u.size, 1), dtype=np.float)
for i,_x in enumerate(u.real.T):
    y[i*len(x):(i+1)*len(x)] = _x.reshape(len(x),1)
    
print("y shape", y.shape)
# Out:
# y shape (25856, 1)

# %%
# Setup Network
net = PINN(sizes=[2,20,20,20,20,20,1], activation=torch.nn.Tanh())
print(net)
# Out:
# PINN(
#   (net): Sequential(
#     (0): Linear(in_features=2, out_features=20, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=20, out_features=20, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=20, out_features=20, bias=True)
#     (7): Tanh()
#     (8): Linear(in_features=20, out_features=20, bias=True)
#     (9): Tanh()
#     (10): Linear(in_features=20, out_features=1, bias=True)
#   )
# )

# %%
polynm = ['1', 'u', 'uˆ2']
spa_der = ['1', 'u_{x}', 'u_{xx}']
library_coeffs = pde_matrix_mul(polynm, spa_der)
print('library_coeffs:', library_coeffs)

tot_items = len(library_coeffs)
print('tot_items:', tot_items)

mask = torch.ones(tot_items, 1)
epochs = 10000

xi = nn.Parameter(torch.randn((tot_items, 1), requires_grad=True, device="cpu", dtype=torch.float32))
params = [{'params': net.parameters(), 'lr': 1e-3}, {'params': xi, 'lr': 1e-2}]

optimizer = Adam(params)
scheduler = ExponentialLR(optimizer, .9998)
# Out:
# library_coeffs: ['1', 'u_{x}', 'u_{xx}', 'u', 'uu_{x}', 'uu_{xx}', 'uˆ2', 'uˆ2u_{x}', 'uˆ2u_{xx}']
# tot_items: 9

# %%
def model_identification(features, label, mask, poly_order, deriv_order):
    
    xi1 = []
    xi2 = []
    xi1_error_app = []
    xi2_error_app = []
    xi_update_app = []
    
    numbers = [0, 5, 26, 57, 73, 80, 95, 104, 129, 151]
    
    f1 = open("../Results/Value_of_xi.txt", "w+", encoding="utf-8")
    f2 = open("../Results/errors.txt", "w+", encoding="utf-8")
    f3 = open("../Results/avg_xi_n25.txt", "a+", encoding="utf-8")
    correct_prediction = 0
    # Using for loop
    for i in numbers:
        np.random.seed(i)
        print('seed:', i)
        idxs = np.random.choice(y.size, 2500, replace=False)
        X_train = torch.tensor(features[idxs], dtype=torch.float32, requires_grad=True)
        y_train = torch.tensor(label[idxs], dtype=torch.float32)
    
        lamb   = 0
        tolerance = 1e-6
        mask = torch.ones(tot_items, 1)
        #print('xi', xi)
        print('mask:', mask.shape)
        lambd  = 1e-6
    
        for epoch in range(epochs):
            optimizer.zero_grad()
            uhat = net(X_train)
    
            if epoch == 1000:
                lamb = 1
               
            dudt, theta = construct_Dictonary(X_train, uhat, poly_order=2, deriv_order=2)
            #print('dudt:', dudt.shape)
            dudt_norm = torch.norm(dudt, dim=0)
    
            theta_scaling = (torch.norm(theta, dim=0))
            #Returns a new tensor with a dimension of size one inserted at the specified position. from 9 it will be 9,1
            theta_norm = torch.unsqueeze(theta_scaling, dim = 1) 
            xi_normalized = xi * (theta_norm / dudt_norm) 
            L1 = lambd * torch.sum(torch.abs(xi_normalized[1:, :]))
        
            l_u   = nn.MSELoss()(uhat, y_train)
            l_reg = lamb * torch.mean((dudt - theta @ xi)**2)
            #l_reg = torch.mean((dudt - theta @ xi)**2)

            loss = l_u + l_reg + L1

            gradient_loss = torch.max(torch.abs(grad(outputs=loss, inputs=xi, 
                  grad_outputs=torch.ones_like(loss), create_graph=True)[0]) / (theta_norm / dudt_norm))


            loss.backward(retain_graph=True)
            optimizer.step()
        
            if epoch % 1000 == 0:
                print('loss:', epoch, loss)
                if gradient_loss < tolerance:
                    print('Optimizer converged.')
                    break
 
        xi_list = sparse_coeff(mask, xi.detach().numpy())
        xi_normalized = sparse_coeff(mask, xi_normalized.detach().numpy())
        print('xi_normalized:', xi_normalized)
    

        sparsity = normalized_xi_threshold( xi_normalized, mode='auto')
        print('sparsity:', sparsity)
    
        xi_thresholded = np.expand_dims(xi_list[sparsity], axis=1) 
        print('xi_thresholded:', xi_thresholded)
        
        print('Coefficient xi:')
        xi_update = sparse_coeff(sparsity, xi_thresholded)
        print('xi_update:', xi_update)
        
    
        # Calculate Error in xi    
        if xi_update[2] != 0 and xi_update[4] != 0 and len(xi_thresholded) < 3:
            xi_update_app.append(xi_update)
            #print('xi_update_app:', xi_update_app)
            print('xi_update:', xi_update[2], xi_update[4])
            error_1 = np.subtract(np.array([0.10000]),xi_update[2])
            xi1_error = np.append(xi1, error_1)
            print('xi1_error', xi1_error)
            error_2 = np.subtract(np.array([1.00000]),np.abs(xi_update[4]))
            xi2_error = np.append(xi2, error_2)
            print('xi2_error', xi2_error)
            f1.write(str(xi_update[2]) + " " + str(xi_update[4]) + "\n")
            f2.write(str(xi1_error) + " " + str(xi2_error) + "\n")
            xi1_error_app.append(xi1_error)
            print('xi1_error_app:', xi1_error_app)
            xi2_error_app.append(xi2_error)
            print('xi2_error_app:', xi2_error_app)
            correct_prediction += 1
            
        else:
            print('PDE prediction not correct')
            
            
    print('correct_prediction:', correct_prediction)
    Accuracy = correct_prediction / len(numbers) * 100
    print('Accuracy:', Accuracy)
    xi1_error_avg = np.sum(xi1_error_app, axis = 0) / correct_prediction  
    print('xi1_error_avg:', xi1_error_avg)
    xi2_error_avg = np.sum(xi2_error_app, axis = 0) / correct_prediction 
    print('xi2_error_avg:', xi2_error_avg)
    xi_updated = np.sum(xi_update_app, axis = 0) / correct_prediction  
    print('xi_updated:', xi_updated)
    f3.write(str(xi_updated[2]) + " " + str(xi_updated[4]) + "\n")
    print('Finished')
    return xi_updated

# %%
xi_updated = model_identification(X, y, mask, poly_order=2, deriv_order=2)
# Out:
# seed: 0
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0342, grad_fn=<AddBackward0>)
# loss: 1000 tensor(4.6962, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0182, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0066, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0024, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0022, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0021, grad_fn=<AddBackward0>)
# loss: 7000 tensor(0.0021, grad_fn=<AddBackward0>)
# loss: 8000 tensor(0.0021, grad_fn=<AddBackward0>)
# loss: 9000 tensor(0.0020, grad_fn=<AddBackward0>)
# xi_normalized: [[-0.01578586]
#  [-0.07743134]
#  [ 0.43302909]
#  [ 0.18717819]
#  [-1.00926566]
#  [-0.18414547]
#  [-0.29783362]
#  [ 0.13167888]
#  [ 0.0189635 ]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09737287]
#  [-0.96051401]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.09737287]
#  [ 0.        ]
#  [-0.96051401]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.09737287] [-0.96051401]
# xi1_error [0.00262713]
# xi2_error [0.03948599]
# xi1_error_app: [array([0.00262713])]
# xi2_error_app: [array([0.03948599])]
# seed: 5
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0020, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0029, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0020, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.01413691]
#  [-0.04058045]
#  [ 0.44260728]
#  [-0.0030975 ]
#  [-0.96920896]
#  [ 0.08713501]
#  [-0.0327775 ]
#  [-0.00362957]
#  [-0.13794169]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09312478]
#  [-0.93397409]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.09312478]
#  [ 0.        ]
#  [-0.93397409]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.09312478] [-0.93397409]
# xi1_error [0.00687522]
# xi2_error [0.06602591]
# xi1_error_app: [array([0.00262713]), array([0.00687522])]
# xi2_error_app: [array([0.03948599]), array([0.06602591])]
# seed: 26
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0019, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0031, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0019, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 5.24309184e-03]
#  [-1.69761386e-02]
#  [ 3.75852972e-01]
#  [ 1.57227144e-02]
#  [-9.94470239e-01]
#  [ 7.79645741e-02]
#  [-1.79602485e-02]
#  [ 3.67979775e-03]
#  [-1.42901672e-06]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.08283573]
#  [-0.98343772]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.08283573]
#  [ 0.        ]
#  [-0.98343772]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.08283573] [-0.98343772]
# xi1_error [0.01716427]
# xi2_error [0.01656228]
# xi1_error_app: [array([0.00262713]), array([0.00687522]), array([0.01716427])]
# xi2_error_app: [array([0.03948599]), array([0.06602591]), array([0.01656228])]
# seed: 57
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0021, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0032, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0020, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0020, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[-1.26092797e-02]
#  [-3.47451009e-02]
#  [ 4.86717522e-01]
#  [-6.77625984e-02]
#  [-8.13856900e-01]
#  [ 7.62349009e-05]
#  [ 1.19792327e-01]
#  [-2.21291304e-01]
#  [ 9.60699394e-02]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.10403866]
#  [-0.81940615]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.10403866]
#  [ 0.        ]
#  [-0.81940615]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.10403866] [-0.81940615]
# xi1_error [-0.00403866]
# xi2_error [0.18059385]
# xi1_error_app: [array([0.00262713]), array([0.00687522]), array([0.01716427]), array([-0.00403866])]
# xi2_error_app: [array([0.03948599]), array([0.06602591]), array([0.01656228]), array([0.18059385])]
# seed: 73
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0021, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0032, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0020, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0021, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0020, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0020, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0020, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[-7.26782775e-04]
#  [ 1.45246424e-02]
#  [ 4.64075834e-01]
#  [ 6.81522768e-03]
#  [-9.79417205e-01]
#  [-2.52201911e-02]
#  [-1.59002524e-02]
#  [ 1.33502181e-05]
#  [-4.94028106e-02]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.11436231]
#  [-1.00126672]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.11436231]
#  [ 0.        ]
#  [-1.00126672]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.11436231] [-1.00126672]
# xi1_error [-0.01436231]
# xi2_error [-0.00126672]
# xi1_error_app: [array([0.00262713]), array([0.00687522]), array([0.01716427]), array([-0.00403866]), array([-0.01436231])]
# xi2_error_app: [array([0.03948599]), array([0.06602591]), array([0.01656228]), array([0.18059385]), array([-0.00126672])]
# seed: 80
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0020, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0031, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0019, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0019, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[-0.00463134]
#  [-0.11196832]
#  [ 0.39799872]
#  [ 0.01666241]
#  [-0.6601339 ]
#  [-0.18567318]
#  [-0.0551488 ]
#  [-0.23293875]
#  [ 0.1364173 ]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.1008564 ]
#  [-0.66352141]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.1008564 ]
#  [ 0.        ]
#  [-0.66352141]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.1008564] [-0.66352141]
# xi1_error [-0.0008564]
# xi2_error [0.33647859]
# xi1_error_app: [array([0.00262713]), array([0.00687522]), array([0.01716427]), array([-0.00403866]), array([-0.01436231]), array([-0.0008564])]
# xi2_error_app: [array([0.03948599]), array([0.06602591]), array([0.01656228]), array([0.18059385]), array([-0.00126672]), array([0.33647859])]
# seed: 95
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0020, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0036, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0020, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 4.85757040e-03]
#  [-6.82881251e-02]
#  [ 4.10695553e-01]
#  [-4.63298969e-02]
#  [-7.77297795e-01]
#  [-2.02539832e-05]
#  [ 8.43641087e-02]
#  [-1.88850746e-01]
#  [ 6.83076233e-02]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.10060032]
#  [-0.79526573]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.10060032]
#  [ 0.        ]
#  [-0.79526573]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.10060032] [-0.79526573]
# xi1_error [-0.00060032]
# xi2_error [0.20473427]
# xi1_error_app: [array([0.00262713]), array([0.00687522]), array([0.01716427]), array([-0.00403866]), array([-0.01436231]), array([-0.0008564]), array([-0.00060032])]
# xi2_error_app: [array([0.03948599]), array([0.06602591]), array([0.01656228]), array([0.18059385]), array([-0.00126672]), array([0.33647859]), array([0.20473427])]
# seed: 104
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0021, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0031, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0021, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0021, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[-3.55581404e-03]
#  [ 3.71703504e-06]
#  [ 4.67847377e-01]
#  [ 1.82450027e-03]
#  [-9.87199962e-01]
#  [-6.69561132e-07]
#  [ 8.24938715e-03]
#  [-2.00734735e-02]
#  [-2.51034126e-02]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.11138068]
#  [-0.97650379]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.11138068]
#  [ 0.        ]
#  [-0.97650379]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.11138068] [-0.97650379]
# xi1_error [-0.01138068]
# xi2_error [0.02349621]
# xi1_error_app: [array([0.00262713]), array([0.00687522]), array([0.01716427]), array([-0.00403866]), array([-0.01436231]), array([-0.0008564]), array([-0.00060032]), array([-0.01138068])]
# xi2_error_app: [array([0.03948599]), array([0.06602591]), array([0.01656228]), array([0.18059385]), array([-0.00126672]), array([0.33647859]), array([0.20473427]), array([0.02349621])]
# seed: 129
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0021, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0029, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0020, grad_fn=<AddBackward0>)
# loss: 3000 tensor(0.0020, grad_fn=<AddBackward0>)
# loss: 4000 tensor(0.0020, grad_fn=<AddBackward0>)
# loss: 5000 tensor(0.0020, grad_fn=<AddBackward0>)
# loss: 6000 tensor(0.0020, grad_fn=<AddBackward0>)
# loss: 7000 tensor(0.0020, grad_fn=<AddBackward0>)
# loss: 8000 tensor(0.0020, grad_fn=<AddBackward0>)
# loss: 9000 tensor(0.0020, grad_fn=<AddBackward0>)
# xi_normalized: [[ 1.14386529e-02]
#  [ 4.23308375e-04]
#  [ 4.21457857e-01]
#  [-6.30392518e-04]
#  [-1.04825735e+00]
#  [ 1.71365310e-03]
#  [-2.27663084e-03]
#  [ 8.48194733e-02]
#  [ 3.23976361e-04]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.09724377]
#  [-1.08244026]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.09724377]
#  [ 0.        ]
#  [-1.08244026]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.09724377] [-1.08244026]
# xi1_error [0.00275623]
# xi2_error [-0.08244026]
# xi1_error_app: [array([0.00262713]), array([0.00687522]), array([0.01716427]), array([-0.00403866]), array([-0.01436231]), array([-0.0008564]), array([-0.00060032]), array([-0.01138068]), array([0.00275623])]
# xi2_error_app: [array([0.03948599]), array([0.06602591]), array([0.01656228]), array([0.18059385]), array([-0.00126672]), array([0.33647859]), array([0.20473427]), array([0.02349621]), array([-0.08244026])]
# seed: 151
# mask: torch.Size([9, 1])
# loss: 0 tensor(0.0020, grad_fn=<AddBackward0>)
# loss: 1000 tensor(0.0031, grad_fn=<AddBackward0>)
# loss: 2000 tensor(0.0019, grad_fn=<AddBackward0>)
# Optimizer converged.
# xi_normalized: [[ 0.00485671]
#  [-0.03536538]
#  [ 0.33427116]
#  [-0.03286903]
#  [-0.9285177 ]
#  [ 0.12844782]
#  [ 0.07223379]
#  [-0.05389271]
#  [-0.02151152]]
# sparsity: [[False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]]
# xi_thresholded: [[ 0.08897289]
#  [-0.96360886]]
# Coefficient xi:
# xi_update: [[ 0.        ]
#  [ 0.        ]
#  [ 0.08897289]
#  [ 0.        ]
#  [-0.96360886]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# xi_update: [0.08897289] [-0.96360886]
# xi1_error [0.01102711]
# xi2_error [0.03639114]
# xi1_error_app: [array([0.00262713]), array([0.00687522]), array([0.01716427]), array([-0.00403866]), array([-0.01436231]), array([-0.0008564]), array([-0.00060032]), array([-0.01138068]), array([0.00275623]), array([0.01102711])]
# xi2_error_app: [array([0.03948599]), array([0.06602591]), array([0.01656228]), array([0.18059385]), array([-0.00126672]), array([0.33647859]), array([0.20473427]), array([0.02349621]), array([-0.08244026]), array([0.03639114])]
# correct_prediction: 10
# Accuracy: 100.0
# xi1_error_avg: [0.00092116]
# xi2_error_avg: [0.08200613]
# xi_updated: [[ 0.        ]
#  [ 0.        ]
#  [ 0.09907884]
#  [ 0.        ]
#  [-0.91799387]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  [ 0.        ]]
# Finished

# %%
pde_Recover(xi_updated, library_coeffs, equation_form='u_t')
end_time = datetime.now()
print('end_time:', end_time)
print('Duration: {}'.format(end_time - start_time))
# Out:
# Burger equation:
# u_t = 0.0991u_{xx} - 0.9180uu_{x}
# end_time: 2020-04-04 10:53:01.210268
# Duration: 0:34:09.202588
